# %% [markdown]
# # CAE

# %%
import math

from keras import backend as K
from keras import Model
from keras.layers import Layer, Softmax, Input
from keras.callbacks import EarlyStopping
from keras.initializers import Constant, glorot_normal
from tensorflow.keras.optimizers import Adam



class ConcreteSelect(Layer):
    
    def __init__(self, output_dim, start_temp = 10.0, min_temp = 0.1, alpha = 0.99999, **kwargs):
        self.output_dim = output_dim
        self.start_temp = start_temp
        self.min_temp = K.constant(min_temp)
        self.alpha = K.constant(alpha)
        super(ConcreteSelect, self).__init__(**kwargs)
        
    def build(self, input_shape):
        self.temp = self.add_weight(name = 'temp', shape = [], initializer = Constant(self.start_temp), trainable = False)
        self.logits = self.add_weight(name = 'logits', shape = [self.output_dim, input_shape[1]], initializer = glorot_normal(), trainable = True)
        super(ConcreteSelect, self).build(input_shape)
        
    def call(self, X, training=None):
        uniform = K.random_uniform(self.logits.shape, K.epsilon(), 1.0)
        gumbel = -K.log(-K.log(uniform))
        temp = K.update(self.temp, K.maximum(self.min_temp, self.temp * self.alpha))
        noisy_logits = (self.logits + gumbel) / temp
        samples = K.softmax(noisy_logits)
        
        discrete_logits = K.one_hot(K.argmax(self.logits), self.logits.shape[1])
        
        self.selections = K.in_train_phase(samples, discrete_logits, training)
        Y = K.dot(X, K.transpose(self.selections))
        
        return Y
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)
    
class StopperCallback(EarlyStopping):
    
    def __init__(self, mean_max_target = 0.998):
        self.mean_max_target = mean_max_target
        super(StopperCallback, self).__init__(monitor = '', patience = float('inf'), verbose = 1, mode = 'max', baseline = self.mean_max_target)
    
    def on_epoch_begin(self, epoch, logs = None):
        print('mean max of probabilities:', self.get_monitor_value(logs), '- temperature', K.get_value(self.model.get_layer('concrete_select').temp))
        #print( K.get_value(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        #print(K.get_value(K.max(self.model.get_layer('concrete_select').selections, axis = -1)))
    
    def get_monitor_value(self, logs):
        monitor_value = K.get_value(K.mean(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        return monitor_value


class ConcreteAutoencoderFeatureSelector():
    
    def __init__(self, K, output_function, num_epochs = 300, batch_size = None, learning_rate = 0.001, start_temp = 10.0, min_temp = 0.1, tryout_limit = 5):
        self.K = K
        self.output_function = output_function
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.start_temp = start_temp
        self.min_temp = min_temp
        self.tryout_limit = tryout_limit
        
    def fit(self, X, Y = None, val_X = None, val_Y = None):
        if Y is None:
            Y = X
        assert len(X) == len(Y)
        validation_data = None
        if val_X is not None and val_Y is not None:
            assert len(val_X) == len(val_Y)
            validation_data = (val_X, val_Y)
        
        if self.batch_size is None:
            self.batch_size = max(len(X) // 256, 16)
        
        num_epochs = self.num_epochs
        steps_per_epoch = (len(X) + self.batch_size - 1) // self.batch_size
        
        for i in range(self.tryout_limit):
            
            K.set_learning_phase(1)
            
            inputs = Input(shape = X.shape[1:])

            alpha = math.exp(math.log(self.min_temp / self.start_temp) / (num_epochs * steps_per_epoch))
            
            self.concrete_select = ConcreteSelect(self.K, self.start_temp, self.min_temp, alpha, name = 'concrete_select')

            selected_features = self.concrete_select(inputs)

            outputs = self.output_function(selected_features)

            self.model = Model(inputs, outputs)

            self.model.compile(Adam(self.learning_rate), loss = 'mean_squared_error')
            
            print(self.model.summary())
            
            stopper_callback = StopperCallback()
            
            hist = self.model.fit(X, Y, self.batch_size, num_epochs, verbose = 1, callbacks = [stopper_callback], validation_data = validation_data)#, validation_freq = 10)
            
            if K.get_value(K.mean(K.max(K.softmax(self.concrete_select.logits, axis = -1)))) >= stopper_callback.mean_max_target:
                break
            
            num_epochs *= 2
        
        self.probabilities = K.get_value(K.softmax(self.model.get_layer('concrete_select').logits))
        self.indices = K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
            
        return self
    
    def get_indices(self):
        return K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
    
    def get_mask(self):
        return K.get_value(K.sum(K.one_hot(K.argmax(self.model.get_layer('concrete_select').logits), self.model.get_layer('concrete_select').logits.shape[1]), axis = 0))
    
    def transform(self, X):
        return X[self.get_indices()]
    
    def fit_transform(self, X, y):
        self.fit(X, y)
        return self.transform(X)
    
    def get_support(self, indices = False):
        return self.get_indices() if indices else self.get_mask()
    
    def get_params(self):
        return self.model

# %% [markdown]
# # Experiment

# %%
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Softmax
import numpy as np
import os
import os.path as osp

from functools import reduce

# %%
import torch
from google.colab import drive

drive.mount('gdrive')
foldername = 'gdrive/MyDrive/Cambridge Work/group feature selection/group_lasso/chem_data'


chem_data_groups = {4: [np.array([40]), np.array([1])], # logic_4 = ether OR NOT alkyne
		    10: [np.array([56, 18]), np.array([40])], # logic_10 = (primary amine AND NOT ether) OR (NOT benzene AND NOT ether)
		    13: [np.array([18, 29]), np.array([1, 40])], # logic_13 = (benzene AND NOT carbonyl) OR (alkyne AND NOT ether)
                    }
chem_oracle_features = {1: np.array([18]), 4: np.array([1, 40]), 8: np.array([41, 55, 83]),
                        10: np.array([18, 40, 56]), 12: np.array([8, 41, 55, 56]),
                        13: np.array([1, 18, 29, 40])}


def make_syn_data(rule, train=True):
    is_train = 'train' if train else 'test'
    x_data = np.load(osp.join(foldername, 'logic_'+str(rule)+'_X_'+is_train+'.npy'))
    y_data = np.load(osp.join(foldername, 'logic_'+str(rule)+'_Y_'+is_train+'.npy'))
    return x_data, y_data


def set_seed(x):
    # set a consistent seed, so we can run across different runs
    x *= 10000
    np.random.seed(x)
    tf.random.set_seed(x)
    torch.manual_seed(x)
    torch.cuda.manual_seed(x)
    torch.cuda.manual_seed_all(x)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Out:
# Drive already mounted at gdrive; to attempt to forcibly remount, call drive.mount("gdrive", force_remount=True).

# %%
def get_jaccard_score(true_groups, predicted_groups):
    # get jaccard similarity score for a model
    jaccard_score = 0
    if len(true_groups) == 0: # i.e. we don't know the ground truth
       return -1, len(true_groups), len(predicted_groups)
    if len(predicted_groups)>0:
      for g in true_groups:
         current_max = 0
         for g_hat in predicted_groups:
            jac = np.intersect1d(g, g_hat).size / np.union1d(g, g_hat).size
            if jac == 1:
               current_max = 1
               break
            if jac > current_max:
               current_max = jac
         jaccard_score += current_max
      jaccard_score /= len(true_groups)
      return jaccard_score, len(true_groups), len(predicted_groups)
    else:   # we didn't find anything
      return 0, len(true_groups), len(predicted_groups)


def tpr_fdr(true_groups, predicted_groups):
   # true positive rate and false discovery rate
   
   if len(true_groups) == 0:  # ground truth not known
      return -1, -1
   if len(predicted_groups) == 0:
      return 0.0, 0.0

   predicted_features = np.unique(reduce(np.union1d, predicted_groups))
   true_features = np.unique(reduce(np.union1d, true_groups))

   overlap = np.intersect1d(predicted_features, true_features).size
   tpr = 100*overlap/len(true_features)
   fdr = 100*(len(predicted_features)-overlap)/len(predicted_features) #if len(predicted_features) != 0 else 0.0
   return tpr, fdr

# %%
experiment_no = 10
rule = 13
nhidden = 200
batchsize = 250
lr = 0.001
nepochs = 250
tryoutlimit = 1
nk = len(chem_oracle_features[rule])
set_seed(experiment_no)

x_train, y_train_ = make_syn_data(rule, train=True)
x_test, y_test_ = make_syn_data(rule, train=False)
y_train = to_categorical(y_train_)
y_test = to_categorical(y_test_)     # to_categorical turns to one-hot encoding
nfeatures = x_train.shape[-1]
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (14768, 84)
# (14768, 2)
# (1831, 84)
# (1831, 2)

# %%
def f(x):
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nfeatures, activation='sigmoid')(x)
    return x

def g(x):
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(2)(x)
    x = Softmax()(x)
    return x

# %%
supervised_selector = ConcreteAutoencoderFeatureSelector(K=nk, output_function=g, num_epochs=nepochs, tryout_limit=tryoutlimit, batch_size=batchsize)
supervised_selector.fit(x_train, y_train, x_test, y_test)
# Out:
# Model: "model_63"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_65 (InputLayer)       [(None, 84)]              0
#
#  concrete_select (ConcreteSe  (None, 4)                337
#  lect)
#
#  dense_191 (Dense)           (None, 200)               1000
#
#  dense_192 (Dense)           (None, 200)               40200
#
#  dense_193 (Dense)           (None, 2)                 402
#
#  softmax_32 (Softmax)        (None, 2)                 0
#
# =================================================================
# Total params: 41,939
# Trainable params: 41,938
# Non-trainable params: 1
# _________________________________________________________________
# None
# mean max of probabilities: 0.016124733 - temperature 10.0
# Epoch 1/250
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 60/60 [==============================] - 1s 7ms/step - loss: 0.2298 - val_loss: 0.2174
# mean max of probabilities: 0.016718855 - temperature 9.793396
# Epoch 2/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2090 - val_loss: 0.2171
# mean max of probabilities: 0.017873576 - temperature 9.591061
# Epoch 3/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2079 - val_loss: 0.2177
# mean max of probabilities: 0.018851046 - temperature 9.392906
# Epoch 4/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2074 - val_loss: 0.3016
# mean max of probabilities: 0.019924726 - temperature 9.198845
# Epoch 5/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2056 - val_loss: 0.3013
# mean max of probabilities: 0.021004586 - temperature 9.008794
# Epoch 6/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2048 - val_loss: 0.2811
# mean max of probabilities: 0.022159971 - temperature 8.822669
# Epoch 7/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2057 - val_loss: 0.2801
# mean max of probabilities: 0.023324315 - temperature 8.640389
# Epoch 8/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2034 - val_loss: 0.2813
# mean max of probabilities: 0.024732048 - temperature 8.461877
# Epoch 9/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2036 - val_loss: 0.2818
# mean max of probabilities: 0.026132058 - temperature 8.287052
# Epoch 10/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2025 - val_loss: 0.2841
# mean max of probabilities: 0.027650526 - temperature 8.115838
# Epoch 11/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2009 - val_loss: 0.2850
# mean max of probabilities: 0.029208882 - temperature 7.948164
# Epoch 12/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2012 - val_loss: 0.2871
# mean max of probabilities: 0.030839983 - temperature 7.7839518
# Epoch 13/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1994 - val_loss: 0.2884
# mean max of probabilities: 0.032487124 - temperature 7.6231327
# Epoch 14/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1977 - val_loss: 0.2902
# mean max of probabilities: 0.03422574 - temperature 7.4656386
# Epoch 15/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1975 - val_loss: 0.2934
# mean max of probabilities: 0.035941545 - temperature 7.3113956
# Epoch 16/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1961 - val_loss: 0.2954
# mean max of probabilities: 0.037600603 - temperature 7.16034
# Epoch 17/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1967 - val_loss: 0.2502
# mean max of probabilities: 0.03953222 - temperature 7.012405
# Epoch 18/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1950 - val_loss: 0.2548
# mean max of probabilities: 0.041616913 - temperature 6.867527
# Epoch 19/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1942 - val_loss: 0.2514
# mean max of probabilities: 0.043763615 - temperature 6.7256413
# Epoch 20/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1932 - val_loss: 0.2498
# mean max of probabilities: 0.045866936 - temperature 6.5866876
# Epoch 21/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1930 - val_loss: 0.2562
# mean max of probabilities: 0.048358507 - temperature 6.4506044
# Epoch 22/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1912 - val_loss: 0.2545
# mean max of probabilities: 0.050724845 - temperature 6.3173323
# Epoch 23/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1903 - val_loss: 0.2567
# mean max of probabilities: 0.053100284 - temperature 6.186814
# Epoch 24/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1897 - val_loss: 0.2548
# mean max of probabilities: 0.05574783 - temperature 6.0589924
# Epoch 25/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1884 - val_loss: 0.2580
# mean max of probabilities: 0.058288615 - temperature 5.9338117
# Epoch 26/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1872 - val_loss: 0.2618
# mean max of probabilities: 0.061145544 - temperature 5.8112164
# Epoch 27/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1866 - val_loss: 0.2605
# mean max of probabilities: 0.06394146 - temperature 5.691154
# Epoch 28/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1855 - val_loss: 0.2629
# mean max of probabilities: 0.066847175 - temperature 5.573573
# Epoch 29/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1841 - val_loss: 0.2665
# mean max of probabilities: 0.069825515 - temperature 5.458421
# Epoch 30/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1833 - val_loss: 0.2689
# mean max of probabilities: 0.07291289 - temperature 5.3456483
# Epoch 31/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1832 - val_loss: 0.2605
# mean max of probabilities: 0.07595682 - temperature 5.2352057
# Epoch 32/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1816 - val_loss: 0.2641
# mean max of probabilities: 0.07943637 - temperature 5.127042
# Epoch 33/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1805 - val_loss: 0.2658
# mean max of probabilities: 0.08285405 - temperature 5.0211244
# Epoch 34/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1800 - val_loss: 0.2647
# mean max of probabilities: 0.08637461 - temperature 4.9173875
# Epoch 35/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1794 - val_loss: 0.2645
# mean max of probabilities: 0.08990031 - temperature 4.815791
# Epoch 36/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1786 - val_loss: 0.2667
# mean max of probabilities: 0.093769394 - temperature 4.716295
# Epoch 37/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1770 - val_loss: 0.2566
# mean max of probabilities: 0.09745313 - temperature 4.6188545
# Epoch 38/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1763 - val_loss: 0.2631
# mean max of probabilities: 0.101131596 - temperature 4.5234275
# Epoch 39/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1751 - val_loss: 0.2608
# mean max of probabilities: 0.105815545 - temperature 4.4299726
# Epoch 40/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1743 - val_loss: 0.2633
# mean max of probabilities: 0.11086618 - temperature 4.338448
# Epoch 41/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1732 - val_loss: 0.2614
# mean max of probabilities: 0.115672104 - temperature 4.2488146
# Epoch 42/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1724 - val_loss: 0.2667
# mean max of probabilities: 0.12127831 - temperature 4.1610336
# Epoch 43/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1717 - val_loss: 0.2640
# mean max of probabilities: 0.12578826 - temperature 4.075065
# Epoch 44/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1700 - val_loss: 0.2665
# mean max of probabilities: 0.13107479 - temperature 3.9908736
# Epoch 45/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1692 - val_loss: 0.2698
# mean max of probabilities: 0.13641581 - temperature 3.9084206
# Epoch 46/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1673 - val_loss: 0.2627
# mean max of probabilities: 0.14197123 - temperature 3.8276713
# Epoch 47/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1678 - val_loss: 0.2643
# mean max of probabilities: 0.14738272 - temperature 3.7485907
# Epoch 48/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1656 - val_loss: 0.2668
# mean max of probabilities: 0.15379615 - temperature 3.6711438
# Epoch 49/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1636 - val_loss: 0.2727
# mean max of probabilities: 0.16046998 - temperature 3.5952969
# Epoch 50/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1639 - val_loss: 0.2762
# mean max of probabilities: 0.16711056 - temperature 3.5210168
# Epoch 51/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1620 - val_loss: 0.2713
# mean max of probabilities: 0.17331026 - temperature 3.4482715
# Epoch 52/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1613 - val_loss: 0.2679
# mean max of probabilities: 0.18090092 - temperature 3.377029
# Epoch 53/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1600 - val_loss: 0.2830
# mean max of probabilities: 0.18805915 - temperature 3.3072584
# Epoch 54/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1578 - val_loss: 0.2771
# mean max of probabilities: 0.19531986 - temperature 3.238929
# Epoch 55/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1577 - val_loss: 0.2693
# mean max of probabilities: 0.20147574 - temperature 3.1720116
# Epoch 56/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1574 - val_loss: 0.2758
# mean max of probabilities: 0.20770891 - temperature 3.106477
# Epoch 57/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1541 - val_loss: 0.2779
# mean max of probabilities: 0.21415848 - temperature 3.0422962
# Epoch 58/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1544 - val_loss: 0.2694
# mean max of probabilities: 0.21871781 - temperature 2.9794412
# Epoch 59/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1553 - val_loss: 0.2625
# mean max of probabilities: 0.22376223 - temperature 2.9178848
# Epoch 60/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1526 - val_loss: 0.2989
# mean max of probabilities: 0.22703138 - temperature 2.8576005
# Epoch 61/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1517 - val_loss: 0.2906
# mean max of probabilities: 0.23012573 - temperature 2.7985613
# Epoch 62/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1558 - val_loss: 0.2974
# mean max of probabilities: 0.23330732 - temperature 2.740742
# Epoch 63/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1503 - val_loss: 0.2932
# mean max of probabilities: 0.2366347 - temperature 2.6841176
# Epoch 64/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1509 - val_loss: 0.3121
# mean max of probabilities: 0.23906669 - temperature 2.6286623
# Epoch 65/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1499 - val_loss: 0.3205
# mean max of probabilities: 0.2396864 - temperature 2.5743527
# Epoch 66/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1461 - val_loss: 0.2736
# mean max of probabilities: 0.24003528 - temperature 2.5211678
# Epoch 67/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1488 - val_loss: 0.2993
# mean max of probabilities: 0.24175021 - temperature 2.4690802
# Epoch 68/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1472 - val_loss: 0.3139
# mean max of probabilities: 0.24175452 - temperature 2.4180684
# Epoch 69/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1495 - val_loss: 0.2984
# mean max of probabilities: 0.24333104 - temperature 2.3681102
# Epoch 70/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1506 - val_loss: 0.2914
# mean max of probabilities: 0.24488401 - temperature 2.3191843
# Epoch 71/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1500 - val_loss: 0.2497
# mean max of probabilities: 0.24507132 - temperature 2.2712693
# Epoch 72/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1423 - val_loss: 0.3091
# mean max of probabilities: 0.24524242 - temperature 2.2243443
# Epoch 73/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1455 - val_loss: 0.3182
# mean max of probabilities: 0.24396911 - temperature 2.1783888
# Epoch 74/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1426 - val_loss: 0.3453
# mean max of probabilities: 0.24362093 - temperature 2.1333823
# Epoch 75/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1477 - val_loss: 0.3054
# mean max of probabilities: 0.24431467 - temperature 2.0893056
# Epoch 76/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1438 - val_loss: 0.3167
# mean max of probabilities: 0.24476187 - temperature 2.0461395
# Epoch 77/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1517 - val_loss: 0.2340
# mean max of probabilities: 0.24430683 - temperature 2.0038657
# Epoch 78/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1476 - val_loss: 0.2785
# mean max of probabilities: 0.24366634 - temperature 1.962465
# Epoch 79/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1444 - val_loss: 0.3426
# mean max of probabilities: 0.24364382 - temperature 1.92192
# Epoch 80/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1476 - val_loss: 0.3408
# mean max of probabilities: 0.24168685 - temperature 1.8822116
# Epoch 81/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1389 - val_loss: 0.3296
# mean max of probabilities: 0.24054655 - temperature 1.8433245
# Epoch 82/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1425 - val_loss: 0.3305
# mean max of probabilities: 0.23910086 - temperature 1.8052408
# Epoch 83/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1391 - val_loss: 0.3181
# mean max of probabilities: 0.23942111 - temperature 1.767944
# Epoch 84/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1412 - val_loss: 0.3172
# mean max of probabilities: 0.23757666 - temperature 1.7314177
# Epoch 85/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1381 - val_loss: 0.3189
# mean max of probabilities: 0.23751959 - temperature 1.695646
# Epoch 86/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1460 - val_loss: 0.3220
# mean max of probabilities: 0.23482825 - temperature 1.6606132
# Epoch 87/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1392 - val_loss: 0.2704
# mean max of probabilities: 0.23438808 - temperature 1.6263044
# Epoch 88/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1467 - val_loss: 0.4151
# mean max of probabilities: 0.23439844 - temperature 1.5927044
# Epoch 89/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1392 - val_loss: 0.2579
# mean max of probabilities: 0.23393531 - temperature 1.5597987
# Epoch 90/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1372 - val_loss: 0.2382
# mean max of probabilities: 0.2338477 - temperature 1.5275728
# Epoch 91/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1370 - val_loss: 0.2433
# mean max of probabilities: 0.23280424 - temperature 1.4960128
# Epoch 92/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1391 - val_loss: 0.2607
# mean max of probabilities: 0.2337281 - temperature 1.4651046
# Epoch 93/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1269 - val_loss: 0.2568
# mean max of probabilities: 0.23405582 - temperature 1.4348351
# Epoch 94/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1349 - val_loss: 0.2533
# mean max of probabilities: 0.23227355 - temperature 1.405191
# Epoch 95/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1384 - val_loss: 0.2479
# mean max of probabilities: 0.23230417 - temperature 1.3761593
# Epoch 96/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1364 - val_loss: 0.2601
# mean max of probabilities: 0.23146403 - temperature 1.3477273
# Epoch 97/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1390 - val_loss: 0.2575
# mean max of probabilities: 0.23180237 - temperature 1.3198829
# Epoch 98/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1356 - val_loss: 0.1408
# mean max of probabilities: 0.23476687 - temperature 1.2926131
# Epoch 99/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1369 - val_loss: 0.1548
# mean max of probabilities: 0.23751095 - temperature 1.2659072
# Epoch 100/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1375 - val_loss: 0.1691
# mean max of probabilities: 0.23969817 - temperature 1.2397524
# Epoch 101/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1470 - val_loss: 0.1146
# mean max of probabilities: 0.24319224 - temperature 1.2141387
# Epoch 102/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1401 - val_loss: 0.1089
# mean max of probabilities: 0.24618441 - temperature 1.189054
# Epoch 103/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1428 - val_loss: 0.1620
# mean max of probabilities: 0.24970749 - temperature 1.164488
# Epoch 104/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1395 - val_loss: 0.0888
# mean max of probabilities: 0.25315866 - temperature 1.140429
# Epoch 105/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1435 - val_loss: 0.0960
# mean max of probabilities: 0.2561365 - temperature 1.1168672
# Epoch 106/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1473 - val_loss: 0.1455
# mean max of probabilities: 0.25888586 - temperature 1.0937924
# Epoch 107/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1460 - val_loss: 0.0937
# mean max of probabilities: 0.2616535 - temperature 1.0711942
# Epoch 108/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1463 - val_loss: 0.1058
# mean max of probabilities: 0.26375112 - temperature 1.0490632
# Epoch 109/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1415 - val_loss: 0.0953
# mean max of probabilities: 0.26652306 - temperature 1.0273892
# Epoch 110/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1446 - val_loss: 0.1125
# mean max of probabilities: 0.2695786 - temperature 1.0061631
# Epoch 111/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1363 - val_loss: 0.1395
# mean max of probabilities: 0.27290276 - temperature 0.9853754
# Epoch 112/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1452 - val_loss: 0.0940
# mean max of probabilities: 0.27633992 - temperature 0.9650172
# Epoch 113/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1414 - val_loss: 0.0892
# mean max of probabilities: 0.28017715 - temperature 0.94507945
# Epoch 114/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1422 - val_loss: 0.0870
# mean max of probabilities: 0.28308505 - temperature 0.92555386
# Epoch 115/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1476 - val_loss: 0.1009
# mean max of probabilities: 0.28595048 - temperature 0.90643156
# Epoch 116/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1425 - val_loss: 0.0862
# mean max of probabilities: 0.2895667 - temperature 0.8877044
# Epoch 117/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1304 - val_loss: 0.0807
# mean max of probabilities: 0.29502472 - temperature 0.86936414
# Epoch 118/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1401 - val_loss: 0.0949
# mean max of probabilities: 0.29985428 - temperature 0.85140276
# Epoch 119/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1444 - val_loss: 0.1233
# mean max of probabilities: 0.30366367 - temperature 0.83381224
# Epoch 120/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1372 - val_loss: 0.1001
# mean max of probabilities: 0.3063253 - temperature 0.81658536
# Epoch 121/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1517 - val_loss: 0.1212
# mean max of probabilities: 0.31096593 - temperature 0.7997144
# Epoch 122/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1388 - val_loss: 0.0861
# mean max of probabilities: 0.31354785 - temperature 0.7831918
# Epoch 123/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1475 - val_loss: 0.1132
# mean max of probabilities: 0.31778032 - temperature 0.7670108
# Epoch 124/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1369 - val_loss: 0.0922
# mean max of probabilities: 0.3231541 - temperature 0.75116414
# Epoch 125/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1375 - val_loss: 0.0866
# mean max of probabilities: 0.32797086 - temperature 0.7356448
# Epoch 126/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1360 - val_loss: 0.0959
# mean max of probabilities: 0.33255348 - temperature 0.72044617
# Epoch 127/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1391 - val_loss: 0.0836
# mean max of probabilities: 0.33707875 - temperature 0.70556146
# Epoch 128/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1423 - val_loss: 0.0894
# mean max of probabilities: 0.34238848 - temperature 0.69098425
# Epoch 129/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1368 - val_loss: 0.0840
# mean max of probabilities: 0.34767783 - temperature 0.67670834
# Epoch 130/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1429 - val_loss: 0.0885
# mean max of probabilities: 0.3519299 - temperature 0.66272736
# Epoch 131/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1397 - val_loss: 0.0854
# mean max of probabilities: 0.3577061 - temperature 0.64903504
# Epoch 132/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1417 - val_loss: 0.0878
# mean max of probabilities: 0.36373097 - temperature 0.6356255
# Epoch 133/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1427 - val_loss: 0.0969
# mean max of probabilities: 0.3677808 - temperature 0.62249357
# Epoch 134/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1284 - val_loss: 0.0822
# mean max of probabilities: 0.37261117 - temperature 0.60963273
# Epoch 135/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1461 - val_loss: 0.0853
# mean max of probabilities: 0.37720418 - temperature 0.59703743
# Epoch 136/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1322 - val_loss: 0.0900
# mean max of probabilities: 0.38273546 - temperature 0.5847025
# Epoch 137/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1379 - val_loss: 0.0999
# mean max of probabilities: 0.38775766 - temperature 0.5726223
# Epoch 138/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1274 - val_loss: 0.0808
# mean max of probabilities: 0.39120725 - temperature 0.56079173
# Epoch 139/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1424 - val_loss: 0.0856
# mean max of probabilities: 0.39605215 - temperature 0.54920566
# Epoch 140/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1478 - val_loss: 0.0965
# mean max of probabilities: 0.39979494 - temperature 0.5378589
# Epoch 141/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1453 - val_loss: 0.0915
# mean max of probabilities: 0.40444472 - temperature 0.52674663
# Epoch 142/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1401 - val_loss: 0.0987
# mean max of probabilities: 0.40951747 - temperature 0.51586384
# Epoch 143/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1401 - val_loss: 0.0899
# mean max of probabilities: 0.4130826 - temperature 0.505206
# Epoch 144/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1328 - val_loss: 0.0871
# mean max of probabilities: 0.41517907 - temperature 0.49476826
# Epoch 145/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1327 - val_loss: 0.0927
# mean max of probabilities: 0.42062834 - temperature 0.48454624
# Epoch 146/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1388 - val_loss: 0.0886
# mean max of probabilities: 0.42521065 - temperature 0.47453538
# Epoch 147/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1475 - val_loss: 0.0928
# mean max of probabilities: 0.42971677 - temperature 0.4647313
# Epoch 148/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1371 - val_loss: 0.0851
# mean max of probabilities: 0.43598258 - temperature 0.4551298
# Epoch 149/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1404 - val_loss: 0.0894
# mean max of probabilities: 0.44156808 - temperature 0.44572666
# Epoch 150/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1290 - val_loss: 0.0831
# mean max of probabilities: 0.44594032 - temperature 0.43651778
# Epoch 151/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1394 - val_loss: 0.0880
# mean max of probabilities: 0.44971332 - temperature 0.4274992
# Epoch 152/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1410 - val_loss: 0.0885
# mean max of probabilities: 0.45408252 - temperature 0.41866687
# Epoch 153/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1417 - val_loss: 0.0854
# mean max of probabilities: 0.4581614 - temperature 0.4100171
# Epoch 154/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1276 - val_loss: 0.0853
# mean max of probabilities: 0.46379676 - temperature 0.40154603
# Epoch 155/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1456 - val_loss: 0.0949
# mean max of probabilities: 0.46741873 - temperature 0.39325
# Epoch 156/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1408 - val_loss: 0.0927
# mean max of probabilities: 0.4739387 - temperature 0.3851253
# Epoch 157/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1376 - val_loss: 0.0886
# mean max of probabilities: 0.478046 - temperature 0.37716848
# Epoch 158/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1489 - val_loss: 0.0856
# mean max of probabilities: 0.48316595 - temperature 0.36937606
# Epoch 159/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1275 - val_loss: 0.0910
# mean max of probabilities: 0.4879061 - temperature 0.36174464
# Epoch 160/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1342 - val_loss: 0.0852
# mean max of probabilities: 0.491926 - temperature 0.3542709
# Epoch 161/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1451 - val_loss: 0.0844
# mean max of probabilities: 0.49423838 - temperature 0.3469515
# Epoch 162/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1381 - val_loss: 0.0819
# mean max of probabilities: 0.4992681 - temperature 0.3397834
# Epoch 163/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1316 - val_loss: 0.0910
# mean max of probabilities: 0.5040091 - temperature 0.3327633
# Epoch 164/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1401 - val_loss: 0.0904
# mean max of probabilities: 0.50934356 - temperature 0.32588834
# Epoch 165/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1310 - val_loss: 0.0907
# mean max of probabilities: 0.5123713 - temperature 0.3191554
# Epoch 166/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1331 - val_loss: 0.0892
# mean max of probabilities: 0.5171723 - temperature 0.312562
# Epoch 167/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1372 - val_loss: 0.0883
# mean max of probabilities: 0.52165276 - temperature 0.30610427
# Epoch 168/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1362 - val_loss: 0.0835
# mean max of probabilities: 0.5259876 - temperature 0.2997801
# Epoch 169/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1262 - val_loss: 0.0858
# mean max of probabilities: 0.52955073 - temperature 0.29358652
# Epoch 170/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1318 - val_loss: 0.0894
# mean max of probabilities: 0.53415525 - temperature 0.28752095
# Epoch 171/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1410 - val_loss: 0.0876
# mean max of probabilities: 0.53964174 - temperature 0.28158063
# Epoch 172/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1402 - val_loss: 0.0839
# mean max of probabilities: 0.54398096 - temperature 0.27576306
# Epoch 173/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1353 - val_loss: 0.0860
# mean max of probabilities: 0.5473183 - temperature 0.27006567
# Epoch 174/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1248 - val_loss: 0.0865
# mean max of probabilities: 0.5524611 - temperature 0.264486
# Epoch 175/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1282 - val_loss: 0.0857
# mean max of probabilities: 0.5563904 - temperature 0.2590216
# Epoch 176/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1342 - val_loss: 0.0951
# mean max of probabilities: 0.56171453 - temperature 0.25367016
# Epoch 177/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1449 - val_loss: 0.0941
# mean max of probabilities: 0.5651391 - temperature 0.24842925
# Epoch 178/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1356 - val_loss: 0.0826
# mean max of probabilities: 0.5670499 - temperature 0.2432966
# Epoch 179/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1259 - val_loss: 0.0894
# mean max of probabilities: 0.57020175 - temperature 0.23827001
# Epoch 180/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1328 - val_loss: 0.0822
# mean max of probabilities: 0.57081014 - temperature 0.23334733
# Epoch 181/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1258 - val_loss: 0.0858
# mean max of probabilities: 0.5743756 - temperature 0.2285263
# Epoch 182/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1187 - val_loss: 0.0808
# mean max of probabilities: 0.57743603 - temperature 0.22380486
# Epoch 183/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1321 - val_loss: 0.0838
# mean max of probabilities: 0.5808698 - temperature 0.21918094
# Epoch 184/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1300 - val_loss: 0.0873
# mean max of probabilities: 0.5832663 - temperature 0.2146526
# Epoch 185/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1453 - val_loss: 0.0845
# mean max of probabilities: 0.58556855 - temperature 0.21021783
# Epoch 186/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1378 - val_loss: 0.0863
# mean max of probabilities: 0.58721405 - temperature 0.20587464
# Epoch 187/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1420 - val_loss: 0.0919
# mean max of probabilities: 0.58982533 - temperature 0.20162117
# Epoch 188/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1290 - val_loss: 0.0832
# mean max of probabilities: 0.59227014 - temperature 0.19745561
# Epoch 189/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1187 - val_loss: 0.0825
# mean max of probabilities: 0.59728897 - temperature 0.19337612
# Epoch 190/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1412 - val_loss: 0.0964
# mean max of probabilities: 0.5994396 - temperature 0.18938091
# Epoch 191/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1325 - val_loss: 0.0855
# mean max of probabilities: 0.6039511 - temperature 0.18546824
# Epoch 192/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1298 - val_loss: 0.0822
# mean max of probabilities: 0.6051173 - temperature 0.18163642
# Epoch 193/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1422 - val_loss: 0.0814
# mean max of probabilities: 0.6074964 - temperature 0.17788371
# Epoch 194/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1272 - val_loss: 0.0824
# mean max of probabilities: 0.60906047 - temperature 0.17420858
# Epoch 195/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1216 - val_loss: 0.0852
# mean max of probabilities: 0.6124419 - temperature 0.17060937
# Epoch 196/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1266 - val_loss: 0.0898
# mean max of probabilities: 0.6162973 - temperature 0.16708454
# Epoch 197/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1260 - val_loss: 0.0881
# mean max of probabilities: 0.6186446 - temperature 0.16363253
# Epoch 198/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1137 - val_loss: 0.0833
# mean max of probabilities: 0.6226055 - temperature 0.16025186
# Epoch 199/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1222 - val_loss: 0.0816
# mean max of probabilities: 0.62698334 - temperature 0.15694097
# Epoch 200/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1185 - val_loss: 0.0800
# mean max of probabilities: 0.6294354 - temperature 0.15369855
# Epoch 201/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1323 - val_loss: 0.0846
# mean max of probabilities: 0.63189477 - temperature 0.1505231
# Epoch 202/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1160 - val_loss: 0.0812
# mean max of probabilities: 0.63435566 - temperature 0.14741324
# Epoch 203/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1327 - val_loss: 0.0837
# mean max of probabilities: 0.63625145 - temperature 0.14436764
# Epoch 204/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1370 - val_loss: 0.0862
# mean max of probabilities: 0.64011955 - temperature 0.14138497
# Epoch 205/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1291 - val_loss: 0.0804
# mean max of probabilities: 0.64295584 - temperature 0.13846391
# Epoch 206/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1194 - val_loss: 0.0858
# mean max of probabilities: 0.6449083 - temperature 0.13560322
# Epoch 207/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1184 - val_loss: 0.0814
# mean max of probabilities: 0.64780855 - temperature 0.13280162
# Epoch 208/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1350 - val_loss: 0.0842
# mean max of probabilities: 0.65057343 - temperature 0.13005792
# Epoch 209/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1310 - val_loss: 0.0819
# mean max of probabilities: 0.652205 - temperature 0.12737088
# Epoch 210/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1222 - val_loss: 0.0827
# mean max of probabilities: 0.65539026 - temperature 0.12473936
# Epoch 211/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1255 - val_loss: 0.0814
# mean max of probabilities: 0.658422 - temperature 0.122162186
# Epoch 212/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1196 - val_loss: 0.0788
# mean max of probabilities: 0.66029274 - temperature 0.11963827
# Epoch 213/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1266 - val_loss: 0.0800
# mean max of probabilities: 0.662752 - temperature 0.11716653
# Epoch 214/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1336 - val_loss: 0.0789
# mean max of probabilities: 0.66445124 - temperature 0.11474583
# Epoch 215/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1231 - val_loss: 0.0826
# mean max of probabilities: 0.6667403 - temperature 0.11237513
# Epoch 216/250
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1391 - val_loss: 0.0845
# mean max of probabilities: 0.66915673 - temperature 0.11005341
# Epoch 217/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1320 - val_loss: 0.0854
# mean max of probabilities: 0.67191094 - temperature 0.107779674
# Epoch 218/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1453 - val_loss: 0.0809
# mean max of probabilities: 0.6754817 - temperature 0.10555291
# Epoch 219/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1080 - val_loss: 0.0806
# mean max of probabilities: 0.6801257 - temperature 0.103372164
# Epoch 220/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1231 - val_loss: 0.0825
# mean max of probabilities: 0.6825206 - temperature 0.10123647
# Epoch 221/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1119 - val_loss: 0.0793
# mean max of probabilities: 0.6859623 - temperature 0.1
# Epoch 222/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1314 - val_loss: 0.0819
# mean max of probabilities: 0.68813974 - temperature 0.1
# Epoch 223/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1248 - val_loss: 0.0789
# mean max of probabilities: 0.69037145 - temperature 0.1
# Epoch 224/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1217 - val_loss: 0.0778
# mean max of probabilities: 0.6914967 - temperature 0.1
# Epoch 225/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1413 - val_loss: 0.0812
# mean max of probabilities: 0.6932958 - temperature 0.1
# Epoch 226/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1255 - val_loss: 0.0802
# mean max of probabilities: 0.6952623 - temperature 0.1
# Epoch 227/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1246 - val_loss: 0.0790
# mean max of probabilities: 0.69662744 - temperature 0.1
# Epoch 228/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1292 - val_loss: 0.0801
# mean max of probabilities: 0.69785506 - temperature 0.1
# Epoch 229/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1119 - val_loss: 0.0814
# mean max of probabilities: 0.69987607 - temperature 0.1
# Epoch 230/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1234 - val_loss: 0.0872
# mean max of probabilities: 0.7015504 - temperature 0.1
# Epoch 231/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1244 - val_loss: 0.0815
# mean max of probabilities: 0.7025603 - temperature 0.1
# Epoch 232/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1169 - val_loss: 0.0797
# mean max of probabilities: 0.70327175 - temperature 0.1
# Epoch 233/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1273 - val_loss: 0.0803
# mean max of probabilities: 0.7053567 - temperature 0.1
# Epoch 234/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1151 - val_loss: 0.0822
# mean max of probabilities: 0.70778465 - temperature 0.1
# Epoch 235/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1158 - val_loss: 0.0821
# mean max of probabilities: 0.70983714 - temperature 0.1
# Epoch 236/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1105 - val_loss: 0.0794
# mean max of probabilities: 0.7129998 - temperature 0.1
# Epoch 237/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1159 - val_loss: 0.0809
# mean max of probabilities: 0.7146994 - temperature 0.1
# Epoch 238/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1214 - val_loss: 0.0786
# mean max of probabilities: 0.7159654 - temperature 0.1
# Epoch 239/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1143 - val_loss: 0.0799
# mean max of probabilities: 0.71746093 - temperature 0.1
# Epoch 240/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1229 - val_loss: 0.0810
# mean max of probabilities: 0.71982265 - temperature 0.1
# Epoch 241/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1175 - val_loss: 0.0781
# mean max of probabilities: 0.7220477 - temperature 0.1
# Epoch 242/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1128 - val_loss: 0.0809
# mean max of probabilities: 0.72325945 - temperature 0.1
# Epoch 243/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1137 - val_loss: 0.0800
# mean max of probabilities: 0.7244668 - temperature 0.1
# Epoch 244/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1155 - val_loss: 0.0795
# mean max of probabilities: 0.72525966 - temperature 0.1
# Epoch 245/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1193 - val_loss: 0.0809
# mean max of probabilities: 0.7275747 - temperature 0.1
# Epoch 246/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1108 - val_loss: 0.0809
# mean max of probabilities: 0.7281946 - temperature 0.1
# Epoch 247/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1121 - val_loss: 0.0797
# mean max of probabilities: 0.72890466 - temperature 0.1
# Epoch 248/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1161 - val_loss: 0.0817
# mean max of probabilities: 0.730496 - temperature 0.1
# Epoch 249/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1138 - val_loss: 0.0792
# mean max of probabilities: 0.732718 - temperature 0.1
# Epoch 250/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1039 - val_loss: 0.0782

# %%
unsupervised_selector = ConcreteAutoencoderFeatureSelector(K=nk, output_function=f, num_epochs=nepochs, tryout_limit=tryoutlimit, batch_size=batchsize)
unsupervised_selector.fit(x_train, x_train, x_test, x_test)
# Out:
# Model: "model_64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_66 (InputLayer)       [(None, 84)]              0
#
#  concrete_select (ConcreteSe  (None, 4)                337
#  lect)
#
#  dense_194 (Dense)           (None, 200)               1000
#
#  dense_195 (Dense)           (None, 200)               40200
#
#  dense_196 (Dense)           (None, 84)                16884
#
# =================================================================
# Total params: 58,421
# Trainable params: 58,420
# Non-trainable params: 1
# _________________________________________________________________
# None
# mean max of probabilities: 0.01583195 - temperature 10.0
# Epoch 1/250
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 60/60 [==============================] - 1s 7ms/step - loss: 0.1479 - val_loss: 0.0465
# mean max of probabilities: 0.017005224 - temperature 9.793396
# Epoch 2/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0433 - val_loss: 0.0454
# mean max of probabilities: 0.017104924 - temperature 9.591061
# Epoch 3/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0427 - val_loss: 0.0450
# mean max of probabilities: 0.01708558 - temperature 9.392906
# Epoch 4/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0424 - val_loss: 0.0448
# mean max of probabilities: 0.017063752 - temperature 9.198845
# Epoch 5/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0417 - val_loss: 0.0467
# mean max of probabilities: 0.017119579 - temperature 9.008794
# Epoch 6/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0393 - val_loss: 0.0622
# mean max of probabilities: 0.017933462 - temperature 8.822669
# Epoch 7/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0364 - val_loss: 0.0488
# mean max of probabilities: 0.019889345 - temperature 8.640389
# Epoch 8/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0355 - val_loss: 0.0514
# mean max of probabilities: 0.0222531 - temperature 8.461877
# Epoch 9/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0353 - val_loss: 0.0490
# mean max of probabilities: 0.024587234 - temperature 8.287052
# Epoch 10/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0351 - val_loss: 0.0505
# mean max of probabilities: 0.02691557 - temperature 8.115838
# Epoch 11/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0350 - val_loss: 0.0496
# mean max of probabilities: 0.029272536 - temperature 7.948164
# Epoch 12/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0350 - val_loss: 0.0498
# mean max of probabilities: 0.031743933 - temperature 7.7839518
# Epoch 13/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0349 - val_loss: 0.0492
# mean max of probabilities: 0.034266964 - temperature 7.6231327
# Epoch 14/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0347 - val_loss: 0.0494
# mean max of probabilities: 0.036846086 - temperature 7.4656386
# Epoch 15/250
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0346 - val_loss: 0.0491
# mean max of probabilities: 0.039434027 - temperature 7.3113956
# Epoch 16/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0345 - val_loss: 0.0505
# mean max of probabilities: 0.04212083 - temperature 7.16034
# Epoch 17/250
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0344 - val_loss: 0.0495
# mean max of probabilities: 0.04488899 - temperature 7.012405
# Epoch 18/250
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0343 - val_loss: 0.0496
# mean max of probabilities: 0.047721334 - temperature 6.867527
# Epoch 19/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0342 - val_loss: 0.0496
# mean max of probabilities: 0.050861478 - temperature 6.7256413
# Epoch 20/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0342 - val_loss: 0.0488
# mean max of probabilities: 0.054121852 - temperature 6.5866876
# Epoch 21/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0341 - val_loss: 0.0499
# mean max of probabilities: 0.05741062 - temperature 6.4506044
# Epoch 22/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0339 - val_loss: 0.0493
# mean max of probabilities: 0.060830086 - temperature 6.3173323
# Epoch 23/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0338 - val_loss: 0.0489
# mean max of probabilities: 0.06424479 - temperature 6.186814
# Epoch 24/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0336 - val_loss: 0.0483
# mean max of probabilities: 0.06812032 - temperature 6.0589924
# Epoch 25/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0336 - val_loss: 0.0484
# mean max of probabilities: 0.07239422 - temperature 5.9338117
# Epoch 26/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0334 - val_loss: 0.0483
# mean max of probabilities: 0.07690348 - temperature 5.8112164
# Epoch 27/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0333 - val_loss: 0.0480
# mean max of probabilities: 0.081508026 - temperature 5.691154
# Epoch 28/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0332 - val_loss: 0.0482
# mean max of probabilities: 0.086116396 - temperature 5.573573
# Epoch 29/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0331 - val_loss: 0.0486
# mean max of probabilities: 0.091208376 - temperature 5.458421
# Epoch 30/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0330 - val_loss: 0.0492
# mean max of probabilities: 0.09645888 - temperature 5.3456483
# Epoch 31/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0329 - val_loss: 0.0491
# mean max of probabilities: 0.10200382 - temperature 5.2352057
# Epoch 32/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0328 - val_loss: 0.0492
# mean max of probabilities: 0.10733144 - temperature 5.127042
# Epoch 33/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0328 - val_loss: 0.0464
# mean max of probabilities: 0.11375138 - temperature 5.0211244
# Epoch 34/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0465
# mean max of probabilities: 0.121028274 - temperature 4.9173875
# Epoch 35/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0536
# mean max of probabilities: 0.12949097 - temperature 4.815791
# Epoch 36/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0324 - val_loss: 0.0534
# mean max of probabilities: 0.13918501 - temperature 4.716295
# Epoch 37/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0524
# mean max of probabilities: 0.15018684 - temperature 4.6188545
# Epoch 38/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0540
# mean max of probabilities: 0.16119778 - temperature 4.5234275
# Epoch 39/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0523
# mean max of probabilities: 0.17305207 - temperature 4.4299726
# Epoch 40/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0534
# mean max of probabilities: 0.18647699 - temperature 4.338448
# Epoch 41/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0319 - val_loss: 0.0534
# mean max of probabilities: 0.19955374 - temperature 4.2488146
# Epoch 42/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0534
# mean max of probabilities: 0.2126616 - temperature 4.1610336
# Epoch 43/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0529
# mean max of probabilities: 0.22606413 - temperature 4.075065
# Epoch 44/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0531
# mean max of probabilities: 0.24063304 - temperature 3.9908736
# Epoch 45/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0538
# mean max of probabilities: 0.25461406 - temperature 3.9084206
# Epoch 46/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0313 - val_loss: 0.0531
# mean max of probabilities: 0.26973426 - temperature 3.8276713
# Epoch 47/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0539
# mean max of probabilities: 0.28425235 - temperature 3.7485907
# Epoch 48/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0521
# mean max of probabilities: 0.29873288 - temperature 3.6711438
# Epoch 49/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.0523
# mean max of probabilities: 0.3124956 - temperature 3.5952969
# Epoch 50/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0306 - val_loss: 0.0520
# mean max of probabilities: 0.3249844 - temperature 3.5210168
# Epoch 51/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0307 - val_loss: 0.0521
# mean max of probabilities: 0.33665413 - temperature 3.4482715
# Epoch 52/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0305 - val_loss: 0.0514
# mean max of probabilities: 0.34721422 - temperature 3.377029
# Epoch 53/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0303 - val_loss: 0.0519
# mean max of probabilities: 0.35692802 - temperature 3.3072584
# Epoch 54/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0301 - val_loss: 0.0524
# mean max of probabilities: 0.36633676 - temperature 3.238929
# Epoch 55/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0528
# mean max of probabilities: 0.37418935 - temperature 3.1720116
# Epoch 56/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0298 - val_loss: 0.0517
# mean max of probabilities: 0.3795371 - temperature 3.106477
# Epoch 57/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0500
# mean max of probabilities: 0.3855345 - temperature 3.0422962
# Epoch 58/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0299 - val_loss: 0.0507
# mean max of probabilities: 0.39069334 - temperature 2.9794412
# Epoch 59/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0304 - val_loss: 0.0496
# mean max of probabilities: 0.39719045 - temperature 2.9178848
# Epoch 60/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0296 - val_loss: 0.0505
# mean max of probabilities: 0.4017838 - temperature 2.8576005
# Epoch 61/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0498
# mean max of probabilities: 0.40641144 - temperature 2.7985613
# Epoch 62/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0296 - val_loss: 0.0502
# mean max of probabilities: 0.40966108 - temperature 2.740742
# Epoch 63/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0296 - val_loss: 0.0498
# mean max of probabilities: 0.41389054 - temperature 2.6841176
# Epoch 64/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0505
# mean max of probabilities: 0.4172304 - temperature 2.6286623
# Epoch 65/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0294 - val_loss: 0.0505
# mean max of probabilities: 0.42008474 - temperature 2.5743527
# Epoch 66/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0294 - val_loss: 0.0495
# mean max of probabilities: 0.4208318 - temperature 2.5211678
# Epoch 67/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0295 - val_loss: 0.0499
# mean max of probabilities: 0.42332685 - temperature 2.4690802
# Epoch 68/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0500
# mean max of probabilities: 0.42402416 - temperature 2.4180684
# Epoch 69/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0294 - val_loss: 0.0495
# mean max of probabilities: 0.42605668 - temperature 2.3681102
# Epoch 70/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0494
# mean max of probabilities: 0.427181 - temperature 2.3191843
# Epoch 71/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0493
# mean max of probabilities: 0.42799318 - temperature 2.2712693
# Epoch 72/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0294 - val_loss: 0.0498
# mean max of probabilities: 0.42958567 - temperature 2.2243443
# Epoch 73/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0294 - val_loss: 0.0499
# mean max of probabilities: 0.4311311 - temperature 2.1783888
# Epoch 74/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0506
# mean max of probabilities: 0.43277937 - temperature 2.1333823
# Epoch 75/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0301 - val_loss: 0.0497
# mean max of probabilities: 0.4322702 - temperature 2.0893056
# Epoch 76/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0296 - val_loss: 0.0498
# mean max of probabilities: 0.4328193 - temperature 2.0461395
# Epoch 77/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0487
# mean max of probabilities: 0.43246052 - temperature 2.0038657
# Epoch 78/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0478
# mean max of probabilities: 0.4323782 - temperature 1.962465
# Epoch 79/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0493
# mean max of probabilities: 0.43328512 - temperature 1.92192
# Epoch 80/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0297 - val_loss: 0.0478
# mean max of probabilities: 0.43211162 - temperature 1.8822116
# Epoch 81/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0297 - val_loss: 0.0474
# mean max of probabilities: 0.43172562 - temperature 1.8433245
# Epoch 82/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0299 - val_loss: 0.0481
# mean max of probabilities: 0.43130594 - temperature 1.8052408
# Epoch 83/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0297 - val_loss: 0.0482
# mean max of probabilities: 0.43127295 - temperature 1.767944
# Epoch 84/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0303 - val_loss: 0.0481
# mean max of probabilities: 0.43095815 - temperature 1.7314177
# Epoch 85/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0299 - val_loss: 0.0481
# mean max of probabilities: 0.42788327 - temperature 1.695646
# Epoch 86/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0458
# mean max of probabilities: 0.42414784 - temperature 1.6606132
# Epoch 87/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0464
# mean max of probabilities: 0.42409405 - temperature 1.6263044
# Epoch 88/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0299 - val_loss: 0.0465
# mean max of probabilities: 0.42487928 - temperature 1.5927044
# Epoch 89/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0456
# mean max of probabilities: 0.42592847 - temperature 1.5597987
# Epoch 90/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0449
# mean max of probabilities: 0.42640486 - temperature 1.5275728
# Epoch 91/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0297 - val_loss: 0.0458
# mean max of probabilities: 0.42633852 - temperature 1.4960128
# Epoch 92/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0458
# mean max of probabilities: 0.42532992 - temperature 1.4651046
# Epoch 93/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0297 - val_loss: 0.0459
# mean max of probabilities: 0.42595816 - temperature 1.4348351
# Epoch 94/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0302 - val_loss: 0.0447
# mean max of probabilities: 0.42659715 - temperature 1.405191
# Epoch 95/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0299 - val_loss: 0.0452
# mean max of probabilities: 0.4278087 - temperature 1.3761593
# Epoch 96/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0301 - val_loss: 0.0464
# mean max of probabilities: 0.42860585 - temperature 1.3477273
# Epoch 97/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0300 - val_loss: 0.0436
# mean max of probabilities: 0.42680997 - temperature 1.3198829
# Epoch 98/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0302 - val_loss: 0.0443
# mean max of probabilities: 0.42762962 - temperature 1.2926131
# Epoch 99/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0304 - val_loss: 0.0438
# mean max of probabilities: 0.4276126 - temperature 1.2659072
# Epoch 100/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0301 - val_loss: 0.0439
# mean max of probabilities: 0.4281404 - temperature 1.2397524
# Epoch 101/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0302 - val_loss: 0.0427
# mean max of probabilities: 0.42803496 - temperature 1.2141387
# Epoch 102/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0305 - val_loss: 0.0424
# mean max of probabilities: 0.42907277 - temperature 1.189054
# Epoch 103/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0307 - val_loss: 0.0432
# mean max of probabilities: 0.42973226 - temperature 1.164488
# Epoch 104/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0304 - val_loss: 0.0432
# mean max of probabilities: 0.42735562 - temperature 1.140429
# Epoch 105/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0430
# mean max of probabilities: 0.42771095 - temperature 1.1168672
# Epoch 106/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0304 - val_loss: 0.0427
# mean max of probabilities: 0.4277355 - temperature 1.0937924
# Epoch 107/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 0.0437
# mean max of probabilities: 0.4285849 - temperature 1.0711942
# Epoch 108/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0305 - val_loss: 0.0429
# mean max of probabilities: 0.4283607 - temperature 1.0490632
# Epoch 109/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0310 - val_loss: 0.0427
# mean max of probabilities: 0.42889768 - temperature 1.0273892
# Epoch 110/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0311 - val_loss: 0.0430
# mean max of probabilities: 0.42625058 - temperature 1.0061631
# Epoch 111/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.0432
# mean max of probabilities: 0.4278149 - temperature 0.9853754
# Epoch 112/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0306 - val_loss: 0.0428
# mean max of probabilities: 0.42846656 - temperature 0.9650172
# Epoch 113/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0303 - val_loss: 0.0421
# mean max of probabilities: 0.42723465 - temperature 0.94507945
# Epoch 114/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0423
# mean max of probabilities: 0.42650694 - temperature 0.92555386
# Epoch 115/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0304 - val_loss: 0.0422
# mean max of probabilities: 0.42751375 - temperature 0.90643156
# Epoch 116/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0301 - val_loss: 0.0416
# mean max of probabilities: 0.4279971 - temperature 0.8877044
# Epoch 117/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0307 - val_loss: 0.0423
# mean max of probabilities: 0.42789668 - temperature 0.86936414
# Epoch 118/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0304 - val_loss: 0.0416
# mean max of probabilities: 0.42649373 - temperature 0.85140276
# Epoch 119/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0307 - val_loss: 0.0418
# mean max of probabilities: 0.4260206 - temperature 0.83381224
# Epoch 120/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0412
# mean max of probabilities: 0.425888 - temperature 0.81658536
# Epoch 121/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0415
# mean max of probabilities: 0.42528874 - temperature 0.7997144
# Epoch 122/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0305 - val_loss: 0.0417
# mean max of probabilities: 0.42407277 - temperature 0.7831918
# Epoch 123/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0305 - val_loss: 0.0415
# mean max of probabilities: 0.42282894 - temperature 0.7670108
# Epoch 124/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0310 - val_loss: 0.0412
# mean max of probabilities: 0.4221858 - temperature 0.75116414
# Epoch 125/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0309 - val_loss: 0.0418
# mean max of probabilities: 0.42256576 - temperature 0.7356448
# Epoch 126/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0311 - val_loss: 0.0415
# mean max of probabilities: 0.42247525 - temperature 0.72044617
# Epoch 127/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0310 - val_loss: 0.0417
# mean max of probabilities: 0.42144227 - temperature 0.70556146
# Epoch 128/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.0414
# mean max of probabilities: 0.42219612 - temperature 0.69098425
# Epoch 129/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0309 - val_loss: 0.0416
# mean max of probabilities: 0.42224395 - temperature 0.67670834
# Epoch 130/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0410
# mean max of probabilities: 0.42065352 - temperature 0.66272736
# Epoch 131/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.0414
# mean max of probabilities: 0.4222548 - temperature 0.64903504
# Epoch 132/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0312 - val_loss: 0.0416
# mean max of probabilities: 0.42305496 - temperature 0.6356255
# Epoch 133/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0410
# mean max of probabilities: 0.4235004 - temperature 0.62249357
# Epoch 134/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0311 - val_loss: 0.0411
# mean max of probabilities: 0.42158788 - temperature 0.60963273
# Epoch 135/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0307 - val_loss: 0.0409
# mean max of probabilities: 0.4208489 - temperature 0.59703743
# Epoch 136/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0306 - val_loss: 0.0414
# mean max of probabilities: 0.4222668 - temperature 0.5847025
# Epoch 137/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0312 - val_loss: 0.0411
# mean max of probabilities: 0.42249426 - temperature 0.5726223
# Epoch 138/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0405
# mean max of probabilities: 0.42216852 - temperature 0.56079173
# Epoch 139/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0409
# mean max of probabilities: 0.42106032 - temperature 0.54920566
# Epoch 140/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0402
# mean max of probabilities: 0.4214943 - temperature 0.5378589
# Epoch 141/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0420
# mean max of probabilities: 0.421433 - temperature 0.52674663
# Epoch 142/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0406
# mean max of probabilities: 0.42158043 - temperature 0.51586384
# Epoch 143/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0412
# mean max of probabilities: 0.4219134 - temperature 0.505206
# Epoch 144/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0404
# mean max of probabilities: 0.42186525 - temperature 0.49476826
# Epoch 145/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0383
# mean max of probabilities: 0.42187524 - temperature 0.48454624
# Epoch 146/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0403
# mean max of probabilities: 0.42099518 - temperature 0.47453538
# Epoch 147/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0315 - val_loss: 0.0401
# mean max of probabilities: 0.42158675 - temperature 0.4647313
# Epoch 148/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0414
# mean max of probabilities: 0.42348444 - temperature 0.4551298
# Epoch 149/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0391
# mean max of probabilities: 0.42335388 - temperature 0.44572666
# Epoch 150/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0311 - val_loss: 0.0404
# mean max of probabilities: 0.4235925 - temperature 0.43651778
# Epoch 151/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0402
# mean max of probabilities: 0.42391643 - temperature 0.4274992
# Epoch 152/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0409
# mean max of probabilities: 0.4243284 - temperature 0.41866687
# Epoch 153/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0401
# mean max of probabilities: 0.4252104 - temperature 0.4100171
# Epoch 154/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0411
# mean max of probabilities: 0.4247007 - temperature 0.40154603
# Epoch 155/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0309 - val_loss: 0.0406
# mean max of probabilities: 0.42479628 - temperature 0.39325
# Epoch 156/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0409
# mean max of probabilities: 0.42467514 - temperature 0.3851253
# Epoch 157/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0309 - val_loss: 0.0417
# mean max of probabilities: 0.42726806 - temperature 0.37716848
# Epoch 158/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0395
# mean max of probabilities: 0.4260146 - temperature 0.36937606
# Epoch 159/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0300
# mean max of probabilities: 0.42546633 - temperature 0.36174464
# Epoch 160/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0322
# mean max of probabilities: 0.42689723 - temperature 0.3542709
# Epoch 161/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0320
# mean max of probabilities: 0.4293421 - temperature 0.3469515
# Epoch 162/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0316
# mean max of probabilities: 0.43252918 - temperature 0.3397834
# Epoch 163/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0320
# mean max of probabilities: 0.43413633 - temperature 0.3327633
# Epoch 164/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.0317
# mean max of probabilities: 0.43539286 - temperature 0.32588834
# Epoch 165/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0313
# mean max of probabilities: 0.43668574 - temperature 0.3191554
# Epoch 166/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0320
# mean max of probabilities: 0.4403626 - temperature 0.312562
# Epoch 167/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0317
# mean max of probabilities: 0.44106555 - temperature 0.30610427
# Epoch 168/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0316
# mean max of probabilities: 0.44404525 - temperature 0.2997801
# Epoch 169/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0313
# mean max of probabilities: 0.44733244 - temperature 0.29358652
# Epoch 170/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0313
# mean max of probabilities: 0.44699413 - temperature 0.28752095
# Epoch 171/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0319
# mean max of probabilities: 0.44760132 - temperature 0.28158063
# Epoch 172/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0315
# mean max of probabilities: 0.4501403 - temperature 0.27576306
# Epoch 173/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0320
# mean max of probabilities: 0.4536016 - temperature 0.27006567
# Epoch 174/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0318
# mean max of probabilities: 0.45394585 - temperature 0.264486
# Epoch 175/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0315 - val_loss: 0.0319
# mean max of probabilities: 0.45561057 - temperature 0.2590216
# Epoch 176/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0319
# mean max of probabilities: 0.45506638 - temperature 0.25367016
# Epoch 177/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0319
# mean max of probabilities: 0.45575148 - temperature 0.24842925
# Epoch 178/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0320
# mean max of probabilities: 0.45613477 - temperature 0.2432966
# Epoch 179/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0315
# mean max of probabilities: 0.45746517 - temperature 0.23827001
# Epoch 180/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0313
# mean max of probabilities: 0.45884007 - temperature 0.23334733
# Epoch 181/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0318
# mean max of probabilities: 0.45977873 - temperature 0.2285263
# Epoch 182/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0312
# mean max of probabilities: 0.4577489 - temperature 0.22380486
# Epoch 183/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0317
# mean max of probabilities: 0.4579271 - temperature 0.21918094
# Epoch 184/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0317
# mean max of probabilities: 0.45973048 - temperature 0.2146526
# Epoch 185/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0307 - val_loss: 0.0316
# mean max of probabilities: 0.46035507 - temperature 0.21021783
# Epoch 186/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0315
# mean max of probabilities: 0.461694 - temperature 0.20587464
# Epoch 187/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0316
# mean max of probabilities: 0.46226263 - temperature 0.20162117
# Epoch 188/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0309 - val_loss: 0.0314
# mean max of probabilities: 0.46364254 - temperature 0.19745561
# Epoch 189/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0318
# mean max of probabilities: 0.46270633 - temperature 0.19337612
# Epoch 190/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0316
# mean max of probabilities: 0.4641616 - temperature 0.18938091
# Epoch 191/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0313
# mean max of probabilities: 0.46505776 - temperature 0.18546824
# Epoch 192/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0298
# mean max of probabilities: 0.46482027 - temperature 0.18163642
# Epoch 193/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0298
# mean max of probabilities: 0.46755442 - temperature 0.17788371
# Epoch 194/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0296
# mean max of probabilities: 0.46840304 - temperature 0.17420858
# Epoch 195/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0297
# mean max of probabilities: 0.46998936 - temperature 0.17060937
# Epoch 196/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0324 - val_loss: 0.0297
# mean max of probabilities: 0.47180232 - temperature 0.16708454
# Epoch 197/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0299
# mean max of probabilities: 0.47244322 - temperature 0.16363253
# Epoch 198/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0324 - val_loss: 0.0300
# mean max of probabilities: 0.47387686 - temperature 0.16025186
# Epoch 199/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0299
# mean max of probabilities: 0.4760187 - temperature 0.15694097
# Epoch 200/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0296
# mean max of probabilities: 0.4773224 - temperature 0.15369855
# Epoch 201/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0313
# mean max of probabilities: 0.47746554 - temperature 0.1505231
# Epoch 202/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0312
# mean max of probabilities: 0.47949347 - temperature 0.14741324
# Epoch 203/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0310 - val_loss: 0.0313
# mean max of probabilities: 0.47973436 - temperature 0.14436764
# Epoch 204/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0310 - val_loss: 0.0300
# mean max of probabilities: 0.48089796 - temperature 0.14138497
# Epoch 205/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0304
# mean max of probabilities: 0.48093084 - temperature 0.13846391
# Epoch 206/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0315
# mean max of probabilities: 0.4828996 - temperature 0.13560322
# Epoch 207/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0312
# mean max of probabilities: 0.4841361 - temperature 0.13280162
# Epoch 208/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0312
# mean max of probabilities: 0.4855016 - temperature 0.13005792
# Epoch 209/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0311
# mean max of probabilities: 0.4882627 - temperature 0.12737088
# Epoch 210/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0318
# mean max of probabilities: 0.48898807 - temperature 0.12473936
# Epoch 211/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0312 - val_loss: 0.0310
# mean max of probabilities: 0.49087134 - temperature 0.122162186
# Epoch 212/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0311
# mean max of probabilities: 0.49436715 - temperature 0.11963827
# Epoch 213/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0311
# mean max of probabilities: 0.4953789 - temperature 0.11716653
# Epoch 214/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0310
# mean max of probabilities: 0.4965388 - temperature 0.11474583
# Epoch 215/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0309
# mean max of probabilities: 0.4987003 - temperature 0.11237513
# Epoch 216/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0316
# mean max of probabilities: 0.4984478 - temperature 0.11005341
# Epoch 217/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0314 - val_loss: 0.0313
# mean max of probabilities: 0.49976933 - temperature 0.107779674
# Epoch 218/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0319
# mean max of probabilities: 0.5009363 - temperature 0.10555291
# Epoch 219/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0321 - val_loss: 0.0297
# mean max of probabilities: 0.5014406 - temperature 0.103372164
# Epoch 220/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0296
# mean max of probabilities: 0.5022483 - temperature 0.10123647
# Epoch 221/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0321 - val_loss: 0.0304
# mean max of probabilities: 0.5030292 - temperature 0.1
# Epoch 222/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0321 - val_loss: 0.0298
# mean max of probabilities: 0.5034389 - temperature 0.1
# Epoch 223/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0299
# mean max of probabilities: 0.50554544 - temperature 0.1
# Epoch 224/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0318
# mean max of probabilities: 0.5058556 - temperature 0.1
# Epoch 225/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0322 - val_loss: 0.0303
# mean max of probabilities: 0.5063102 - temperature 0.1
# Epoch 226/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0319 - val_loss: 0.0300
# mean max of probabilities: 0.5079424 - temperature 0.1
# Epoch 227/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0321 - val_loss: 0.0312
# mean max of probabilities: 0.5084952 - temperature 0.1
# Epoch 228/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0311 - val_loss: 0.0298
# mean max of probabilities: 0.50966805 - temperature 0.1
# Epoch 229/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0300
# mean max of probabilities: 0.5107329 - temperature 0.1
# Epoch 230/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0296
# mean max of probabilities: 0.51287717 - temperature 0.1
# Epoch 231/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0312 - val_loss: 0.0296
# mean max of probabilities: 0.51475483 - temperature 0.1
# Epoch 232/250
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0319 - val_loss: 0.0299
# mean max of probabilities: 0.5161965 - temperature 0.1
# Epoch 233/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0313 - val_loss: 0.0298
# mean max of probabilities: 0.5150988 - temperature 0.1
# Epoch 234/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0310 - val_loss: 0.0297
# mean max of probabilities: 0.5172112 - temperature 0.1
# Epoch 235/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0310 - val_loss: 0.0298
# mean max of probabilities: 0.51711035 - temperature 0.1
# Epoch 236/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0309 - val_loss: 0.0296
# mean max of probabilities: 0.5186973 - temperature 0.1
# Epoch 237/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0310 - val_loss: 0.0297
# mean max of probabilities: 0.51843137 - temperature 0.1
# Epoch 238/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0314 - val_loss: 0.0299
# mean max of probabilities: 0.5202429 - temperature 0.1
# Epoch 239/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0312 - val_loss: 0.0296
# mean max of probabilities: 0.52237153 - temperature 0.1
# Epoch 240/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0312 - val_loss: 0.0299
# mean max of probabilities: 0.5226937 - temperature 0.1
# Epoch 241/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0311 - val_loss: 0.0297
# mean max of probabilities: 0.5242757 - temperature 0.1
# Epoch 242/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0311 - val_loss: 0.0297
# mean max of probabilities: 0.5258177 - temperature 0.1
# Epoch 243/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0312 - val_loss: 0.0297
# mean max of probabilities: 0.52646804 - temperature 0.1
# Epoch 244/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0298
# mean max of probabilities: 0.5274065 - temperature 0.1
# Epoch 245/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0296
# mean max of probabilities: 0.5310828 - temperature 0.1
# Epoch 246/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.0298
# mean max of probabilities: 0.5321456 - temperature 0.1
# Epoch 247/250
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0296
# mean max of probabilities: 0.5326817 - temperature 0.1
# Epoch 248/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0297
# mean max of probabilities: 0.5341194 - temperature 0.1
# Epoch 249/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0315 - val_loss: 0.0296
# mean max of probabilities: 0.53537494 - temperature 0.1
# Epoch 250/250
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0297

# %% [markdown]
# # Test Models

# %%
y_pred = supervised_selector.model(x_test)
y_pred = tf.math.argmax(y_pred, axis=-1)
acc = 100*np.mean((y_pred==y_test_).numpy())

x_pred = unsupervised_selector.model(x_test)
reconstruction_error = np.mean((x_pred.numpy() - x_test)**2)

# %%
supervised_selected = supervised_selector.get_indices()
unsupervised_selected = unsupervised_selector.get_indices()

selected = supervised_selected
tpr, fdr = tpr_fdr(chem_data_groups[rule], [selected])

print('Supervised:')
print(get_jaccard_score(chem_data_groups[rule], [np.unique(selected)]))
print(acc)
print(selected)
print(tpr)
print(fdr)


selected = unsupervised_selected
tpr, fdr = tpr_fdr(chem_data_groups[rule], [selected])

print('\nUnsupervised:')
print(get_jaccard_score(chem_data_groups[rule], [np.unique(selected)]))
print(reconstruction_error)
print(selected)
print(tpr)
print(fdr)
# Out:
# Supervised:
# (0.35, 2, 1)
# 77.22555980338612
# [32 40 18 29]
# 75.0
# 25.0
#
# Unsupervised:
# (0.125, 2, 1)
# 0.02903564594223849
# [29 32 39 32]
# 25.0
# 66.66666666666667
