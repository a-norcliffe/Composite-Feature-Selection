# %% [markdown]
# # CAE Notebook
#
# To use this notebook, put the appropriate Chemistry Data in a folder in Google Drive, after mounting the drive it is crucial to select the correct folder, which is the first line of this notebook:
#
# foldername = 'gdrive/MyDrive/'
#
# Edit this to have the correct foldername.
#
# After that it is fairly easy to run. Hyperparameters can be changed, and in the Run Experiment part of the notebook one can run a synthetic or chemistry experiment easily by commenting out which experiment to run later.

# %%
foldername = 'gdrive/MyDrive/'

# %% [markdown]
# # CAE - Code from the Concrete Autoencoder Repo

# %%
import math

from keras import backend as K
from keras import Model
from keras.layers import Layer, Softmax, Input
from keras.callbacks import EarlyStopping
from keras.initializers import Constant, glorot_normal
from tensorflow.keras.optimizers import Adam



class ConcreteSelect(Layer):
    
    def __init__(self, output_dim, start_temp = 10.0, min_temp = 0.1, alpha = 0.99999, **kwargs):
        self.output_dim = output_dim
        self.start_temp = start_temp
        self.min_temp = K.constant(min_temp)
        self.alpha = K.constant(alpha)
        super(ConcreteSelect, self).__init__(**kwargs)
        
    def build(self, input_shape):
        self.temp = self.add_weight(name = 'temp', shape = [], initializer = Constant(self.start_temp), trainable = False)
        self.logits = self.add_weight(name = 'logits', shape = [self.output_dim, input_shape[1]], initializer = glorot_normal(), trainable = True)
        super(ConcreteSelect, self).build(input_shape)
        
    def call(self, X, training=None):
        uniform = K.random_uniform(self.logits.shape, K.epsilon(), 1.0)
        gumbel = -K.log(-K.log(uniform))
        temp = K.update(self.temp, K.maximum(self.min_temp, self.temp * self.alpha))
        noisy_logits = (self.logits + gumbel) / temp
        samples = K.softmax(noisy_logits)
        
        discrete_logits = K.one_hot(K.argmax(self.logits), self.logits.shape[1])
        
        self.selections = K.in_train_phase(samples, discrete_logits, training)
        Y = K.dot(X, K.transpose(self.selections))
        
        return Y
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)
    
class StopperCallback(EarlyStopping):
    
    def __init__(self, mean_max_target = 0.998):
        self.mean_max_target = mean_max_target
        super(StopperCallback, self).__init__(monitor = '', patience = float('inf'), verbose = 1, mode = 'max', baseline = self.mean_max_target)
    
    def on_epoch_begin(self, epoch, logs = None):
        print('mean max of probabilities:', self.get_monitor_value(logs), '- temperature', K.get_value(self.model.get_layer('concrete_select').temp))
        #print( K.get_value(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        #print(K.get_value(K.max(self.model.get_layer('concrete_select').selections, axis = -1)))
    
    def get_monitor_value(self, logs):
        monitor_value = K.get_value(K.mean(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        return monitor_value


class ConcreteAutoencoderFeatureSelector():
    
    def __init__(self, K, output_function, num_epochs = 300, batch_size = None, learning_rate = 0.001, start_temp = 10.0, min_temp = 0.1, tryout_limit = 5):
        self.K = K
        self.output_function = output_function
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.start_temp = start_temp
        self.min_temp = min_temp
        self.tryout_limit = tryout_limit
        
    def fit(self, X, Y = None, val_X = None, val_Y = None):
        if Y is None:
            Y = X
        assert len(X) == len(Y)
        validation_data = None
        if val_X is not None and val_Y is not None:
            assert len(val_X) == len(val_Y)
            validation_data = (val_X, val_Y)
        
        if self.batch_size is None:
            self.batch_size = max(len(X) // 256, 16)
        
        num_epochs = self.num_epochs
        steps_per_epoch = (len(X) + self.batch_size - 1) // self.batch_size
        
        for i in range(self.tryout_limit):
            
            K.set_learning_phase(1)
            
            inputs = Input(shape = X.shape[1:])

            alpha = math.exp(math.log(self.min_temp / self.start_temp) / (num_epochs * steps_per_epoch))
            
            self.concrete_select = ConcreteSelect(self.K, self.start_temp, self.min_temp, alpha, name = 'concrete_select')

            selected_features = self.concrete_select(inputs)

            outputs = self.output_function(selected_features)

            self.model = Model(inputs, outputs)

            self.model.compile(Adam(self.learning_rate), loss = 'mean_squared_error')
            
            print(self.model.summary())
            
            stopper_callback = StopperCallback()
            
            hist = self.model.fit(X, Y, self.batch_size, num_epochs, verbose = 1, callbacks = [stopper_callback], validation_data = validation_data)#, validation_freq = 10)
            
            if K.get_value(K.mean(K.max(K.softmax(self.concrete_select.logits, axis = -1)))) >= stopper_callback.mean_max_target:
                break
            
            num_epochs *= 2
        
        self.probabilities = K.get_value(K.softmax(self.model.get_layer('concrete_select').logits))
        self.indices = K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
            
        return self
    
    def get_indices(self):
        return K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
    
    def get_mask(self):
        return K.get_value(K.sum(K.one_hot(K.argmax(self.model.get_layer('concrete_select').logits), self.model.get_layer('concrete_select').logits.shape[1]), axis = 0))
    
    def transform(self, X):
        return X[self.get_indices()]
    
    def fit_transform(self, X, y):
        self.fit(X, y)
        return self.transform(X)
    
    def get_support(self, indices = False):
        return self.get_indices() if indices else self.get_mask()
    
    def get_params(self):
        return self.model

# %% [markdown]
# # Experiment

# %%
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Softmax
from keras.layers.convolutional.conv1d import regularizers
import numpy as np
import os
import os.path as osp

from functools import reduce


def set_seed(x):
    # set a consistent seed, so we can run across different runs
    x *= 10000
    np.random.seed(x)
    tf.random.set_seed(x)

# %% [markdown]
# #Syn Data Specific

# %%
# Logic Rules.

def rule1(x_sample):
    return (x_sample[0] > 0.55) or (x_sample[1] > 0.55)

def rule2(x_sample):
    return (x_sample[0]*x_sample[1] > 0.30) or (x_sample[2]*x_sample[3] > 0.30)

def rule3(x_sample):
    return (x_sample[0]*x_sample[1] > 0.30) or (x_sample[0]*x_sample[2] > 0.30)

def rule4(x_sample):
    return (x_sample[0]*x_sample[3] > 0.30) or (x_sample[6]*x_sample[9] > 0.30)

# Sampling rules

def normal_sample(nsamples, nfeatures):
    return np.random.normal(size=(nsamples, nfeatures))

def correlated_sample(nsamples, nfeatures):
    mean = np.array([0.0, 0.0, 0.0])
    cov = np.array([[1, 0.99, 0.99],
                    [0.99, 1, 0.99],
                    [0.99, 0.99, 1]])

    x123 = np.random.multivariate_normal(mean, cov, size=nsamples)
    x456 = np.random.multivariate_normal(mean, cov, size=nsamples)
    x789 = np.random.multivariate_normal(mean, cov, size=nsamples)
    x101112 = np.random.multivariate_normal(mean, cov, size=nsamples)
    xrest = np.random.normal(size=(nsamples, nfeatures-4*3))
    return np.concatenate([x123, x456, x789, x101112, xrest], axis=1)

sampling_rules = {
        1: normal_sample,
        2: normal_sample,
        3: normal_sample,
        4: correlated_sample
    }

logic_rules = {
    1: rule1,
    2: rule2,
    3: rule3,
    4: rule4
}

gauss_groups = {1: [np.array([0]), np.array([1])], 2: [np.array([0, 1]), np.array([2, 3])],
                3: [np.array([0, 1]), np.array([0, 2])], 4: [np.array([0, 3]), np.array([6, 9])]}
gauss_oracle_features = {1: np.array([0, 1]), 2: np.array([0, 1, 2, 3]),
                         3: np.array([0, 1, 2]), 4: np.array([0, 3, 6, 9])}



def make_syn_data(rule, nsamples, nfeatures, train):
    x_data = sampling_rules[rule](nsamples, nfeatures)
    y_data = np.array([logic_rules[rule](x) for x in x_data])
    return x_data, y_data

# %% [markdown]
# # Chem Data Specific

# %%
from google.colab import drive
drive.mount('gdrive')


chem_data_groups = {4: [np.array([40]), np.array([1])], # logic_4 = ether OR NOT alkyne
		            10: [np.array([56, 18]), np.array([40])], # logic_10 = (primary amine AND NOT ether) OR (NOT benzene AND NOT ether)
		            13: [np.array([18, 29]), np.array([1, 40])], # logic_13 = (benzene AND NOT carbonyl) OR (alkyne AND NOT ether)
                    }
chem_oracle_features = {4: np.array([1, 40]),
                        10: np.array([18, 40, 56]),
                        13: np.array([1, 18, 29, 40])}


def make_chem_data(rule, train=True):
    is_train = 'train' if train else 'test'
    x_data = np.load(osp.join(foldername, 'logic_'+str(rule)+'_X_'+is_train+'.npy'))
    y_data = np.load(osp.join(foldername, 'logic_'+str(rule)+'_Y_'+is_train+'.npy'))
    return x_data, y_data
# Out:
# Mounted at gdrive

# %% [markdown]
# # Metrics

# %%
def gsim(true_groups, predicted_groups):
    # Returns gsim, number of true groups, and number of discovered groups, given
    # true groups and predicted groups as input.
    gsim = 0
    if len(true_groups) == 0: # i.e. we don't know the ground truth.
       return -1, len(true_groups), len(predicted_groups)
    if len(predicted_groups)>0:
      for g in true_groups:
         current_max = 0
         for g_hat in predicted_groups:
            jac = np.intersect1d(g, g_hat).size / np.union1d(g, g_hat).size
            if jac == 1:
               current_max = 1
               break
            if jac > current_max:
               current_max = jac
         gsim += current_max
      gsim /= max(len(true_groups), len(predicted_groups))
      return gsim, len(true_groups), len(predicted_groups)
    else:   # We didn't find anything.
      return 0, len(true_groups), len(predicted_groups)


def tpr_fdr(true_groups, predicted_groups):
   # True positive rate and false discovery rate.
   
   if len(true_groups) == 0:  # Ground truth not known.
      return -1, -1

   if len(predicted_groups) == 0:
      return 0.0, 0.0

   predicted_features = np.unique(reduce(np.union1d, predicted_groups))
   true_features = np.unique(reduce(np.union1d, true_groups))

   overlap = np.intersect1d(predicted_features, true_features).size
   tpr = 100*overlap/len(true_features)
   fdr = 100*(len(predicted_features)-overlap)/len(predicted_features) # If len(predicted_features) != 0 else 0.0.
   return tpr, fdr

# %% [markdown]
# # Setup Data
#
# Edit the first cell below to choose which data to use.

# %%
# Edit these lines, choice of experiment is syn or chem

choice = 'syn'     # Uncomment one of these 
#choice = 'chem'     # Uncomment one of these
rule = 2
experiment_no = 1

# %%
set_seed(experiment_no)

if choice == 'syn':
    train_size = 20000
    test_size = 200
    nfeatures = 500
    nhidden = 200
    batchsize = 250
    lr = 0.001
    nepochs = 250
    tryoutlimit = 1
    nk = len(gauss_oracle_features[rule])


    x_train, y_train_ = make_syn_data(rule, train_size, nfeatures, train=True)
    x_test, y_test_ = make_syn_data(rule, test_size, nfeatures, train=False)
    y_train = to_categorical(y_train_)
    y_test = to_categorical(y_test_)
    true_groups = gauss_groups[rule]

if choice == 'chem':
    nhidden = 200
    batchsize = 250
    lr = 0.001
    nepochs = 250
    tryoutlimit = 1

    rules = {
        1: 4,
        2: 10,
        3: 13
    }
    rule = rules[rule]

    nk = len(chem_oracle_features[rule])
    

    x_train, y_train_ = make_chem_data(rule, train=True)
    x_test, y_test_ = make_chem_data(rule, train=False)
    y_train = to_categorical(y_train_)
    y_test = to_categorical(y_test_)
    nfeatures = x_train.shape[-1]
    true_groups = chem_data_groups[rule]
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (20000, 500)
# (20000, 2)
# (200, 500)
# (200, 2)

# %% [markdown]
# # Train Models

# %%
final_activation = 'sigmoid' if choice == 'chem' else 'linear' 
def f(x):
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nfeatures, activation=final_activation)(x)
    return x

def g(x):
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(2)(x)
    x = Softmax()(x)
    return x

# %%
supervised_selector = ConcreteAutoencoderFeatureSelector(K=nk, output_function=g, num_epochs=nepochs, tryout_limit=tryoutlimit, batch_size=batchsize)
supervised_selector.fit(x_train, y_train, x_test, y_test)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 500)]             0
#
#  concrete_select (ConcreteSe  (None, 4)                2001
#  lect)
#
#  dense_24 (Dense)            (None, 200)               1000
#
#  dense_25 (Dense)            (None, 200)               40200
#
#  dense_26 (Dense)            (None, 2)                 402
#
#  softmax_4 (Softmax)         (None, 2)                 0
#
# =================================================================
# Total params: 43,603
# Trainable params: 43,602
# Non-trainable params: 1
# _________________________________________________________________
# None
# mean max of probabilities: 0.0023020254 - temperature 10.0
# Epoch 1/250
# 80/80 [==============================] - 1s 5ms/step - loss: 0.2497 - val_loss: 0.2624
# mean max of probabilities: 0.0023091792 - temperature 9.815204
# Epoch 2/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2609
# mean max of probabilities: 0.0023161308 - temperature 9.6338215
# Epoch 3/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2604
# mean max of probabilities: 0.00233413 - temperature 9.4557905
# Epoch 4/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2580
# mean max of probabilities: 0.0023500877 - temperature 9.281052
# Epoch 5/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2555
# mean max of probabilities: 0.002359585 - temperature 9.10954
# Epoch 6/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2564
# mean max of probabilities: 0.0023800675 - temperature 8.941198
# Epoch 7/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2525
# mean max of probabilities: 0.0024021352 - temperature 8.775969
# Epoch 8/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2530
# mean max of probabilities: 0.0024204594 - temperature 8.613791
# Epoch 9/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2567
# mean max of probabilities: 0.0024427476 - temperature 8.454611
# Epoch 10/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2545
# mean max of probabilities: 0.0024656593 - temperature 8.298373
# Epoch 11/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2567
# mean max of probabilities: 0.0024999087 - temperature 8.1450205
# Epoch 12/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2597
# mean max of probabilities: 0.002538228 - temperature 7.994502
# Epoch 13/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2622
# mean max of probabilities: 0.0025798688 - temperature 7.8467665
# Epoch 14/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2596
# mean max of probabilities: 0.0026176726 - temperature 7.7017603
# Epoch 15/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2591
# mean max of probabilities: 0.002653358 - temperature 7.5594344
# Epoch 16/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2651
# mean max of probabilities: 0.0026835937 - temperature 7.419739
# Epoch 17/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2632
# mean max of probabilities: 0.002721819 - temperature 7.2826233
# Epoch 18/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2659
# mean max of probabilities: 0.0027979298 - temperature 7.1480412
# Epoch 19/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2675
# mean max of probabilities: 0.0028355853 - temperature 7.015947
# Epoch 20/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2720
# mean max of probabilities: 0.0028733842 - temperature 6.8862944
# Epoch 21/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2807
# mean max of probabilities: 0.0029292167 - temperature 6.759037
# Epoch 22/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2835
# mean max of probabilities: 0.0029665986 - temperature 6.63413
# Epoch 23/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3004
# mean max of probabilities: 0.0030239993 - temperature 6.511533
# Epoch 24/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3057
# mean max of probabilities: 0.0031260878 - temperature 6.391201
# Epoch 25/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3103
# mean max of probabilities: 0.003198403 - temperature 6.2730927
# Epoch 26/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3193
# mean max of probabilities: 0.0032652817 - temperature 6.1571674
# Epoch 27/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3222
# mean max of probabilities: 0.0033458192 - temperature 6.0433846
# Epoch 28/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3317
# mean max of probabilities: 0.003402594 - temperature 5.9317064
# Epoch 29/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3261
# mean max of probabilities: 0.003476258 - temperature 5.82209
# Epoch 30/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3371
# mean max of probabilities: 0.0035389415 - temperature 5.7145
# Epoch 31/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3409
# mean max of probabilities: 0.00363172 - temperature 5.608897
# Epoch 32/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3333
# mean max of probabilities: 0.0037128562 - temperature 5.505246
# Epoch 33/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3423
# mean max of probabilities: 0.0037874368 - temperature 5.403511
# Epoch 34/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3434
# mean max of probabilities: 0.0038646928 - temperature 5.303656
# Epoch 35/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3637
# mean max of probabilities: 0.003968548 - temperature 5.205646
# Epoch 36/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3352
# mean max of probabilities: 0.0040430073 - temperature 5.109448
# Epoch 37/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3475
# mean max of probabilities: 0.0041168835 - temperature 5.015027
# Epoch 38/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3562
# mean max of probabilities: 0.0041935504 - temperature 4.9223495
# Epoch 39/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3529
# mean max of probabilities: 0.0042562685 - temperature 4.831385
# Epoch 40/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3695
# mean max of probabilities: 0.0043462445 - temperature 4.7421026
# Epoch 41/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3561
# mean max of probabilities: 0.0044683684 - temperature 4.654469
# Epoch 42/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3533
# mean max of probabilities: 0.0045951465 - temperature 4.5684547
# Epoch 43/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3619
# mean max of probabilities: 0.0046871575 - temperature 4.4840326
# Epoch 44/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3733
# mean max of probabilities: 0.004789654 - temperature 4.4011693
# Epoch 45/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3797
# mean max of probabilities: 0.0049100695 - temperature 4.319837
# Epoch 46/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3850
# mean max of probabilities: 0.005004746 - temperature 4.2400074
# Epoch 47/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.4006
# mean max of probabilities: 0.005137938 - temperature 4.1616535
# Epoch 48/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3875
# mean max of probabilities: 0.0052380636 - temperature 4.084747
# Epoch 49/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3591
# mean max of probabilities: 0.0053550173 - temperature 4.009262
# Epoch 50/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3696
# mean max of probabilities: 0.00544504 - temperature 3.9351718
# Epoch 51/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3668
# mean max of probabilities: 0.0055525764 - temperature 3.8624508
# Epoch 52/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3785
# mean max of probabilities: 0.005659466 - temperature 3.7910738
# Epoch 53/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3868
# mean max of probabilities: 0.005791955 - temperature 3.7210162
# Epoch 54/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3922
# mean max of probabilities: 0.005913995 - temperature 3.6522527
# Epoch 55/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3981
# mean max of probabilities: 0.00605491 - temperature 3.58476
# Epoch 56/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3951
# mean max of probabilities: 0.0062020235 - temperature 3.5185146
# Epoch 57/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3969
# mean max of probabilities: 0.0063595567 - temperature 3.453493
# Epoch 58/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3990
# mean max of probabilities: 0.0064685587 - temperature 3.3896737
# Epoch 59/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3904
# mean max of probabilities: 0.006566843 - temperature 3.3270326
# Epoch 60/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.4191
# mean max of probabilities: 0.0067048413 - temperature 3.2655501
# Epoch 61/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.4367
# mean max of probabilities: 0.006781392 - temperature 3.2052035
# Epoch 62/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.4281
# mean max of probabilities: 0.006911349 - temperature 3.1459723
# Epoch 63/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.4282
# mean max of probabilities: 0.0069662463 - temperature 3.0878353
# Epoch 64/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.4124
# mean max of probabilities: 0.0070954207 - temperature 3.030773
# Epoch 65/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.4174
# mean max of probabilities: 0.007179689 - temperature 2.9747655
# Epoch 66/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.4292
# mean max of probabilities: 0.0073055835 - temperature 2.9197924
# Epoch 67/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2489 - val_loss: 0.4055
# mean max of probabilities: 0.0073894383 - temperature 2.8658352
# Epoch 68/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.4265
# mean max of probabilities: 0.007444012 - temperature 2.8128753
# Epoch 69/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2489 - val_loss: 0.4012
# mean max of probabilities: 0.00756994 - temperature 2.760894
# Epoch 70/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.3993
# mean max of probabilities: 0.007763794 - temperature 2.7098737
# Epoch 71/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.4088
# mean max of probabilities: 0.007772563 - temperature 2.6597965
# Epoch 72/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2489 - val_loss: 0.4249
# mean max of probabilities: 0.007918334 - temperature 2.610644
# Epoch 73/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3923
# mean max of probabilities: 0.008132658 - temperature 2.5624006
# Epoch 74/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.4104
# mean max of probabilities: 0.008315324 - temperature 2.515048
# Epoch 75/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2488 - val_loss: 0.4238
# mean max of probabilities: 0.008383749 - temperature 2.4685702
# Epoch 76/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.4155
# mean max of probabilities: 0.008526123 - temperature 2.4229515
# Epoch 77/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.3838
# mean max of probabilities: 0.008596305 - temperature 2.378176
# Epoch 78/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.4032
# mean max of probabilities: 0.008653131 - temperature 2.334228
# Epoch 79/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2489 - val_loss: 0.4077
# mean max of probabilities: 0.008645846 - temperature 2.291092
# Epoch 80/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.3671
# mean max of probabilities: 0.008748058 - temperature 2.2487538
# Epoch 81/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3564
# mean max of probabilities: 0.008832682 - temperature 2.207198
# Epoch 82/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3604
# mean max of probabilities: 0.008918937 - temperature 2.1664093
# Epoch 83/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3675
# mean max of probabilities: 0.008961495 - temperature 2.1263747
# Epoch 84/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2489 - val_loss: 0.3595
# mean max of probabilities: 0.009034523 - temperature 2.0870795
# Epoch 85/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3499
# mean max of probabilities: 0.009052301 - temperature 2.048511
# Epoch 86/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3613
# mean max of probabilities: 0.0091336705 - temperature 2.010655
# Epoch 87/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.3489
# mean max of probabilities: 0.009137277 - temperature 1.9734986
# Epoch 88/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3470
# mean max of probabilities: 0.009262501 - temperature 1.9370288
# Epoch 89/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3282
# mean max of probabilities: 0.00934702 - temperature 1.9012331
# Epoch 90/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3395
# mean max of probabilities: 0.009430701 - temperature 1.8660985
# Epoch 91/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3282
# mean max of probabilities: 0.009482043 - temperature 1.8316135
# Epoch 92/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.3317
# mean max of probabilities: 0.009649691 - temperature 1.7977657
# Epoch 93/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3155
# mean max of probabilities: 0.009723352 - temperature 1.7645434
# Epoch 94/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3188
# mean max of probabilities: 0.009768182 - temperature 1.731935
# Epoch 95/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3326
# mean max of probabilities: 0.009750941 - temperature 1.6999295
# Epoch 96/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3283
# mean max of probabilities: 0.009783596 - temperature 1.6685151
# Epoch 97/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.2972
# mean max of probabilities: 0.009827822 - temperature 1.6376812
# Epoch 98/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2493 - val_loss: 0.2870
# mean max of probabilities: 0.009879128 - temperature 1.6074175
# Epoch 99/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.2833
# mean max of probabilities: 0.009941975 - temperature 1.5777129
# Epoch 100/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.2963
# mean max of probabilities: 0.010012057 - temperature 1.5485573
# Epoch 101/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2671
# mean max of probabilities: 0.01012291 - temperature 1.5199404
# Epoch 102/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.2751
# mean max of probabilities: 0.0101565495 - temperature 1.4918525
# Epoch 103/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.2659
# mean max of probabilities: 0.01026573 - temperature 1.4642832
# Epoch 104/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.2731
# mean max of probabilities: 0.010309944 - temperature 1.4372237
# Epoch 105/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.2683
# mean max of probabilities: 0.010371446 - temperature 1.4106642
# Epoch 106/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2626
# mean max of probabilities: 0.0103767235 - temperature 1.3845954
# Epoch 107/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2578
# mean max of probabilities: 0.010381303 - temperature 1.3590084
# Epoch 108/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2605
# mean max of probabilities: 0.010312466 - temperature 1.3338945
# Epoch 109/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.2551
# mean max of probabilities: 0.01032315 - temperature 1.3092445
# Epoch 110/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2545
# mean max of probabilities: 0.010330474 - temperature 1.2850498
# Epoch 111/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2554
# mean max of probabilities: 0.010361513 - temperature 1.2613022
# Epoch 112/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2571
# mean max of probabilities: 0.010438923 - temperature 1.2379937
# Epoch 113/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2565
# mean max of probabilities: 0.010475365 - temperature 1.2151159
# Epoch 114/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2568
# mean max of probabilities: 0.010519691 - temperature 1.1926609
# Epoch 115/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2568
# mean max of probabilities: 0.010547563 - temperature 1.1706207
# Epoch 116/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2597
# mean max of probabilities: 0.010579751 - temperature 1.1489881
# Epoch 117/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2544
# mean max of probabilities: 0.010504441 - temperature 1.1277554
# Epoch 118/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2552
# mean max of probabilities: 0.010522892 - temperature 1.1069155
# Epoch 119/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2535
# mean max of probabilities: 0.010594907 - temperature 1.0864598
# Epoch 120/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2509
# mean max of probabilities: 0.01071524 - temperature 1.0663822
# Epoch 121/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2501
# mean max of probabilities: 0.010714975 - temperature 1.0466757
# Epoch 122/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.2549
# mean max of probabilities: 0.010722503 - temperature 1.0273333
# Epoch 123/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2533
# mean max of probabilities: 0.010807931 - temperature 1.0083485
# Epoch 124/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2548
# mean max of probabilities: 0.010888876 - temperature 0.98971456
# Epoch 125/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2537
# mean max of probabilities: 0.010956181 - temperature 0.971425
# Epoch 126/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2530
# mean max of probabilities: 0.011054805 - temperature 0.95347327
# Epoch 127/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2514
# mean max of probabilities: 0.011017073 - temperature 0.93585336
# Epoch 128/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2516
# mean max of probabilities: 0.011119432 - temperature 0.9185591
# Epoch 129/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2522
# mean max of probabilities: 0.011213513 - temperature 0.9015844
# Epoch 130/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2546
# mean max of probabilities: 0.011292071 - temperature 0.8849234
# Epoch 131/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2533
# mean max of probabilities: 0.011279918 - temperature 0.86857027
# Epoch 132/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2537
# mean max of probabilities: 0.011293996 - temperature 0.85251933
# Epoch 133/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2496 - val_loss: 0.2529
# mean max of probabilities: 0.011278877 - temperature 0.836765
# Epoch 134/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2545
# mean max of probabilities: 0.011307886 - temperature 0.8213018
# Epoch 135/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.011311206 - temperature 0.80612445
# Epoch 136/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2525
# mean max of probabilities: 0.0113288835 - temperature 0.7912275
# Epoch 137/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2495 - val_loss: 0.2520
# mean max of probabilities: 0.01133686 - temperature 0.7766059
# Epoch 138/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.011328691 - temperature 0.7622544
# Epoch 139/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2526
# mean max of probabilities: 0.011333937 - temperature 0.7481678
# Epoch 140/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2522
# mean max of probabilities: 0.011338013 - temperature 0.7343417
# Epoch 141/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2523
# mean max of probabilities: 0.011369522 - temperature 0.72077125
# Epoch 142/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2537
# mean max of probabilities: 0.011443098 - temperature 0.7074516
# Epoch 143/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2530
# mean max of probabilities: 0.011438649 - temperature 0.69437814
# Epoch 144/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2523
# mean max of probabilities: 0.011454601 - temperature 0.6815462
# Epoch 145/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2525
# mean max of probabilities: 0.0114499 - temperature 0.66895145
# Epoch 146/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2522
# mean max of probabilities: 0.01147412 - temperature 0.6565894
# Epoch 147/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.011504019 - temperature 0.64445585
# Epoch 148/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2524
# mean max of probabilities: 0.011479969 - temperature 0.63254637
# Epoch 149/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2537
# mean max of probabilities: 0.011531334 - temperature 0.6208571
# Epoch 150/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2525
# mean max of probabilities: 0.0114883 - temperature 0.6093838
# Epoch 151/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2534
# mean max of probabilities: 0.01157947 - temperature 0.5981226
# Epoch 152/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2522
# mean max of probabilities: 0.011674557 - temperature 0.58706945
# Epoch 153/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2515
# mean max of probabilities: 0.011703264 - temperature 0.57622045
# Epoch 154/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.011677273 - temperature 0.56557226
# Epoch 155/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2520
# mean max of probabilities: 0.011718521 - temperature 0.5551209
# Epoch 156/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.011767784 - temperature 0.5448624
# Epoch 157/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2525
# mean max of probabilities: 0.011818744 - temperature 0.5347935
# Epoch 158/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2516
# mean max of probabilities: 0.011880629 - temperature 0.5249107
# Epoch 159/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2524
# mean max of probabilities: 0.011900868 - temperature 0.51521045
# Epoch 160/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2520
# mean max of probabilities: 0.011852929 - temperature 0.50568956
# Epoch 161/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.01183292 - temperature 0.4963446
# Epoch 162/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2516
# mean max of probabilities: 0.011890449 - temperature 0.4871723
# Epoch 163/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.011876529 - temperature 0.47816944
# Epoch 164/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.011874404 - temperature 0.469333
# Epoch 165/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2519
# mean max of probabilities: 0.011879254 - temperature 0.46065983
# Epoch 166/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2517
# mean max of probabilities: 0.011925198 - temperature 0.45214692
# Epoch 167/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2518
# mean max of probabilities: 0.011926999 - temperature 0.44379142
# Epoch 168/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.011951237 - temperature 0.4355903
# Epoch 169/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.011897428 - temperature 0.4275407
# Epoch 170/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2518
# mean max of probabilities: 0.01189602 - temperature 0.41963986
# Epoch 171/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2517
# mean max of probabilities: 0.012019273 - temperature 0.41188508
# Epoch 172/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2513
# mean max of probabilities: 0.012096034 - temperature 0.40427354
# Epoch 173/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.012101045 - temperature 0.3968027
# Epoch 174/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2512
# mean max of probabilities: 0.012092067 - temperature 0.38946986
# Epoch 175/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.012075106 - temperature 0.38227254
# Epoch 176/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.012127134 - temperature 0.37520817
# Epoch 177/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2518
# mean max of probabilities: 0.0121350465 - temperature 0.36827427
# Epoch 178/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.012160969 - temperature 0.36146867
# Epoch 179/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.012143677 - temperature 0.35478884
# Epoch 180/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.012130015 - temperature 0.34823245
# Epoch 181/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012144862 - temperature 0.34179723
# Epoch 182/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.012198339 - temperature 0.3354809
# Epoch 183/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2515
# mean max of probabilities: 0.012216801 - temperature 0.3292813
# Epoch 184/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.012108633 - temperature 0.32319623
# Epoch 185/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2515
# mean max of probabilities: 0.012083537 - temperature 0.31722364
# Epoch 186/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012095594 - temperature 0.31136146
# Epoch 187/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.012063434 - temperature 0.30560762
# Epoch 188/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012126951 - temperature 0.29996008
# Epoch 189/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.012126263 - temperature 0.29441693
# Epoch 190/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2517
# mean max of probabilities: 0.01210123 - temperature 0.2889762
# Epoch 191/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2518
# mean max of probabilities: 0.012136292 - temperature 0.283636
# Epoch 192/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.0121225435 - temperature 0.27839464
# Epoch 193/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.01214245 - temperature 0.27324998
# Epoch 194/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2519
# mean max of probabilities: 0.012136329 - temperature 0.2682004
# Epoch 195/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.012036769 - temperature 0.26324412
# Epoch 196/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.0120608695 - temperature 0.25837946
# Epoch 197/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012030907 - temperature 0.2536047
# Epoch 198/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012063875 - temperature 0.24891822
# Epoch 199/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2495 - val_loss: 0.2522
# mean max of probabilities: 0.012013584 - temperature 0.24431825
# Epoch 200/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2495 - val_loss: 0.2520
# mean max of probabilities: 0.011933971 - temperature 0.23980331
# Epoch 201/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2514
# mean max of probabilities: 0.012046918 - temperature 0.23537181
# Epoch 202/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2517
# mean max of probabilities: 0.012025533 - temperature 0.23102221
# Epoch 203/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2511
# mean max of probabilities: 0.011986383 - temperature 0.22675298
# Epoch 204/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2514
# mean max of probabilities: 0.012045277 - temperature 0.22256266
# Epoch 205/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2515
# mean max of probabilities: 0.012015948 - temperature 0.21844976
# Epoch 206/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.011983492 - temperature 0.21441287
# Epoch 207/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.011960273 - temperature 0.21045059
# Epoch 208/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2521
# mean max of probabilities: 0.011910819 - temperature 0.20656154
# Epoch 209/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2510
# mean max of probabilities: 0.012017218 - temperature 0.20274432
# Epoch 210/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2521
# mean max of probabilities: 0.012274139 - temperature 0.19899763
# Epoch 211/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2512
# mean max of probabilities: 0.012342924 - temperature 0.1953202
# Epoch 212/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2513
# mean max of probabilities: 0.012378867 - temperature 0.19171074
# Epoch 213/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2510
# mean max of probabilities: 0.01240938 - temperature 0.18816796
# Epoch 214/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2514
# mean max of probabilities: 0.0125187915 - temperature 0.18469061
# Epoch 215/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.01252698 - temperature 0.18127757
# Epoch 216/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012500917 - temperature 0.1779276
# Epoch 217/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2512
# mean max of probabilities: 0.012518135 - temperature 0.17463955
# Epoch 218/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2516
# mean max of probabilities: 0.012503897 - temperature 0.17141226
# Epoch 219/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2514
# mean max of probabilities: 0.012491283 - temperature 0.16824457
# Epoch 220/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2517
# mean max of probabilities: 0.012459056 - temperature 0.16513543
# Epoch 221/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2514
# mean max of probabilities: 0.012386054 - temperature 0.16208376
# Epoch 222/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2514
# mean max of probabilities: 0.012320772 - temperature 0.15908849
# Epoch 223/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2516
# mean max of probabilities: 0.012349494 - temperature 0.15614857
# Epoch 224/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2514
# mean max of probabilities: 0.012403948 - temperature 0.15326299
# Epoch 225/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012409457 - temperature 0.15043072
# Epoch 226/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2514
# mean max of probabilities: 0.012422357 - temperature 0.1476508
# Epoch 227/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2515
# mean max of probabilities: 0.012440151 - temperature 0.14492226
# Epoch 228/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.012432984 - temperature 0.1422441
# Epoch 229/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2517
# mean max of probabilities: 0.0124966595 - temperature 0.13961557
# Epoch 230/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2521
# mean max of probabilities: 0.012670984 - temperature 0.13703555
# Epoch 231/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.01269643 - temperature 0.13450316
# Epoch 232/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.0127450945 - temperature 0.13201758
# Epoch 233/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.012739596 - temperature 0.12957793
# Epoch 234/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2517
# mean max of probabilities: 0.012702944 - temperature 0.12718338
# Epoch 235/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012713956 - temperature 0.12483306
# Epoch 236/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2513
# mean max of probabilities: 0.012771597 - temperature 0.122526176
# Epoch 237/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2520
# mean max of probabilities: 0.012767993 - temperature 0.12026193
# Epoch 238/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2515
# mean max of probabilities: 0.012869788 - temperature 0.118039526
# Epoch 239/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012865877 - temperature 0.1158582
# Epoch 240/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2516
# mean max of probabilities: 0.012899071 - temperature 0.113717176
# Epoch 241/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2511
# mean max of probabilities: 0.0128441425 - temperature 0.11161572
# Epoch 242/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2512
# mean max of probabilities: 0.0128985075 - temperature 0.10955309
# Epoch 243/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2510
# mean max of probabilities: 0.013003375 - temperature 0.107528575
# Epoch 244/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2519
# mean max of probabilities: 0.013023279 - temperature 0.10554148
# Epoch 245/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2520
# mean max of probabilities: 0.013041446 - temperature 0.103591114
# Epoch 246/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2519
# mean max of probabilities: 0.013034251 - temperature 0.101676784
# Epoch 247/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2518
# mean max of probabilities: 0.013107699 - temperature 0.1
# Epoch 248/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2517
# mean max of probabilities: 0.013115279 - temperature 0.1
# Epoch 249/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2516
# mean max of probabilities: 0.013147312 - temperature 0.1
# Epoch 250/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2496 - val_loss: 0.2506

# %%
unsupervised_selector = ConcreteAutoencoderFeatureSelector(K=nk, output_function=f, num_epochs=nepochs, tryout_limit=tryoutlimit, batch_size=batchsize)
unsupervised_selector.fit(x_train, x_train, x_test, x_test)
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 500)]             0
#
#  concrete_select (ConcreteSe  (None, 4)                2001
#  lect)
#
#  dense_27 (Dense)            (None, 200)               1000
#
#  dense_28 (Dense)            (None, 200)               40200
#
#  dense_29 (Dense)            (None, 500)               100500
#
# =================================================================
# Total params: 143,701
# Trainable params: 143,700
# Non-trainable params: 1
# _________________________________________________________________
# None
# mean max of probabilities: 0.0023003034 - temperature 10.0
# Epoch 1/250
# 80/80 [==============================] - 1s 5ms/step - loss: 0.9995 - val_loss: 1.0965
# mean max of probabilities: 0.0023038518 - temperature 9.815204
# Epoch 2/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9987 - val_loss: 1.2101
# mean max of probabilities: 0.0023169997 - temperature 9.6338215
# Epoch 3/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9986 - val_loss: 1.2206
# mean max of probabilities: 0.0023422192 - temperature 9.4557905
# Epoch 4/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9986 - val_loss: 1.2424
# mean max of probabilities: 0.0023722185 - temperature 9.281052
# Epoch 5/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9986 - val_loss: 1.2492
# mean max of probabilities: 0.0024075168 - temperature 9.10954
# Epoch 6/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.2597
# mean max of probabilities: 0.0024608977 - temperature 8.941198
# Epoch 7/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.2734
# mean max of probabilities: 0.0025253126 - temperature 8.775969
# Epoch 8/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.2980
# mean max of probabilities: 0.0025857242 - temperature 8.613791
# Epoch 9/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.2937
# mean max of probabilities: 0.0026561143 - temperature 8.454611
# Epoch 10/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.3020
# mean max of probabilities: 0.002727953 - temperature 8.298373
# Epoch 11/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.2991
# mean max of probabilities: 0.0028095134 - temperature 8.1450205
# Epoch 12/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.3371
# mean max of probabilities: 0.0028926935 - temperature 7.994502
# Epoch 13/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.3185
# mean max of probabilities: 0.0029811421 - temperature 7.8467665
# Epoch 14/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.3644
# mean max of probabilities: 0.0030749294 - temperature 7.7017603
# Epoch 15/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.3746
# mean max of probabilities: 0.003179614 - temperature 7.5594344
# Epoch 16/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.3802
# mean max of probabilities: 0.003286805 - temperature 7.419739
# Epoch 17/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.4112
# mean max of probabilities: 0.0034080143 - temperature 7.2826233
# Epoch 18/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.4213
# mean max of probabilities: 0.0035197046 - temperature 7.1480412
# Epoch 19/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.4661
# mean max of probabilities: 0.0036506779 - temperature 7.015947
# Epoch 20/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.4591
# mean max of probabilities: 0.0037789657 - temperature 6.8862944
# Epoch 21/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.5068
# mean max of probabilities: 0.003911919 - temperature 6.759037
# Epoch 22/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.5115
# mean max of probabilities: 0.004041711 - temperature 6.63413
# Epoch 23/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.5296
# mean max of probabilities: 0.0042012655 - temperature 6.511533
# Epoch 24/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.5515
# mean max of probabilities: 0.00436015 - temperature 6.391201
# Epoch 25/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.5701
# mean max of probabilities: 0.0045192074 - temperature 6.2730927
# Epoch 26/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.5777
# mean max of probabilities: 0.0046848543 - temperature 6.1571674
# Epoch 27/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.6423
# mean max of probabilities: 0.004863724 - temperature 6.0433846
# Epoch 28/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.6419
# mean max of probabilities: 0.0050101667 - temperature 5.9317064
# Epoch 29/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9984 - val_loss: 1.6475
# mean max of probabilities: 0.0051800096 - temperature 5.82209
# Epoch 30/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.7159
# mean max of probabilities: 0.005372499 - temperature 5.7145
# Epoch 31/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.7269
# mean max of probabilities: 0.005540504 - temperature 5.608897
# Epoch 32/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.8304
# mean max of probabilities: 0.005770734 - temperature 5.505246
# Epoch 33/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.6920
# mean max of probabilities: 0.0060126837 - temperature 5.403511
# Epoch 34/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.7356
# mean max of probabilities: 0.006262611 - temperature 5.303656
# Epoch 35/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.7738
# mean max of probabilities: 0.0065319743 - temperature 5.205646
# Epoch 36/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.8161
# mean max of probabilities: 0.006877588 - temperature 5.109448
# Epoch 37/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 1.8483
# mean max of probabilities: 0.0073360885 - temperature 5.015027
# Epoch 38/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9982 - val_loss: 1.8592
# mean max of probabilities: 0.007878786 - temperature 4.9223495
# Epoch 39/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9982 - val_loss: 1.9097
# mean max of probabilities: 0.008636618 - temperature 4.831385
# Epoch 40/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9981 - val_loss: 1.9156
# mean max of probabilities: 0.0096769985 - temperature 4.7421026
# Epoch 41/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9980 - val_loss: 2.0391
# mean max of probabilities: 0.010896932 - temperature 4.654469
# Epoch 42/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 2.1171
# mean max of probabilities: 0.012359294 - temperature 4.5684547
# Epoch 43/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9977 - val_loss: 2.2585
# mean max of probabilities: 0.013944511 - temperature 4.4840326
# Epoch 44/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9975 - val_loss: 2.3443
# mean max of probabilities: 0.015239855 - temperature 4.4011693
# Epoch 45/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9973 - val_loss: 2.4192
# mean max of probabilities: 0.016580224 - temperature 4.319837
# Epoch 46/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9972 - val_loss: 2.4820
# mean max of probabilities: 0.017807407 - temperature 4.2400074
# Epoch 47/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9970 - val_loss: 2.5530
# mean max of probabilities: 0.018863743 - temperature 4.1616535
# Epoch 48/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9969 - val_loss: 2.5753
# mean max of probabilities: 0.02002497 - temperature 4.084747
# Epoch 49/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9967 - val_loss: 2.6554
# mean max of probabilities: 0.02091248 - temperature 4.009262
# Epoch 50/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9966 - val_loss: 2.6315
# mean max of probabilities: 0.021996459 - temperature 3.9351718
# Epoch 51/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9965 - val_loss: 2.7075
# mean max of probabilities: 0.023183264 - temperature 3.8624508
# Epoch 52/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9964 - val_loss: 2.7870
# mean max of probabilities: 0.024587711 - temperature 3.7910738
# Epoch 53/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9963 - val_loss: 2.9707
# mean max of probabilities: 0.02621174 - temperature 3.7210162
# Epoch 54/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9962 - val_loss: 2.7611
# mean max of probabilities: 0.02759565 - temperature 3.6522527
# Epoch 55/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9963 - val_loss: 2.6928
# mean max of probabilities: 0.029432954 - temperature 3.58476
# Epoch 56/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9961 - val_loss: 2.6748
# mean max of probabilities: 0.031430177 - temperature 3.5185146
# Epoch 57/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9960 - val_loss: 2.7312
# mean max of probabilities: 0.03269701 - temperature 3.453493
# Epoch 58/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9960 - val_loss: 2.7255
# mean max of probabilities: 0.033598796 - temperature 3.3896737
# Epoch 59/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9959 - val_loss: 2.7377
# mean max of probabilities: 0.0346822 - temperature 3.3270326
# Epoch 60/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9958 - val_loss: 2.6849
# mean max of probabilities: 0.035855882 - temperature 3.2655501
# Epoch 61/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9959 - val_loss: 2.8768
# mean max of probabilities: 0.036858834 - temperature 3.2052035
# Epoch 62/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9960 - val_loss: 2.6152
# mean max of probabilities: 0.03832222 - temperature 3.1459723
# Epoch 63/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9958 - val_loss: 2.7892
# mean max of probabilities: 0.039784405 - temperature 3.0878353
# Epoch 64/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9959 - val_loss: 2.6334
# mean max of probabilities: 0.04069941 - temperature 3.030773
# Epoch 65/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9959 - val_loss: 2.6296
# mean max of probabilities: 0.041672416 - temperature 2.9747655
# Epoch 66/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9960 - val_loss: 2.5072
# mean max of probabilities: 0.042429987 - temperature 2.9197924
# Epoch 67/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9959 - val_loss: 2.4688
# mean max of probabilities: 0.043729737 - temperature 2.8658352
# Epoch 68/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9958 - val_loss: 2.4872
# mean max of probabilities: 0.045024186 - temperature 2.8128753
# Epoch 69/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9960 - val_loss: 2.2782
# mean max of probabilities: 0.04585395 - temperature 2.760894
# Epoch 70/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9961 - val_loss: 2.1670
# mean max of probabilities: 0.04740154 - temperature 2.7098737
# Epoch 71/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9960 - val_loss: 2.1315
# mean max of probabilities: 0.048891615 - temperature 2.6597965
# Epoch 72/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9962 - val_loss: 2.0187
# mean max of probabilities: 0.050346076 - temperature 2.610644
# Epoch 73/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9962 - val_loss: 1.9041
# mean max of probabilities: 0.051063992 - temperature 2.5624006
# Epoch 74/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9961 - val_loss: 1.9599
# mean max of probabilities: 0.05168777 - temperature 2.515048
# Epoch 75/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9963 - val_loss: 1.7507
# mean max of probabilities: 0.0527899 - temperature 2.4685702
# Epoch 76/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9965 - val_loss: 1.6852
# mean max of probabilities: 0.054081433 - temperature 2.4229515
# Epoch 77/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9963 - val_loss: 1.6355
# mean max of probabilities: 0.05526647 - temperature 2.378176
# Epoch 78/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9964 - val_loss: 1.3825
# mean max of probabilities: 0.05656194 - temperature 2.334228
# Epoch 79/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9965 - val_loss: 1.4529
# mean max of probabilities: 0.05790983 - temperature 2.291092
# Epoch 80/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9967 - val_loss: 1.3947
# mean max of probabilities: 0.058997102 - temperature 2.2487538
# Epoch 81/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9966 - val_loss: 1.2858
# mean max of probabilities: 0.060550373 - temperature 2.207198
# Epoch 82/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9967 - val_loss: 1.2326
# mean max of probabilities: 0.061835445 - temperature 2.1664093
# Epoch 83/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9968 - val_loss: 1.2241
# mean max of probabilities: 0.063696325 - temperature 2.1263747
# Epoch 84/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9968 - val_loss: 1.2419
# mean max of probabilities: 0.065468 - temperature 2.0870795
# Epoch 85/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9969 - val_loss: 1.2380
# mean max of probabilities: 0.06657827 - temperature 2.048511
# Epoch 86/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9969 - val_loss: 1.1552
# mean max of probabilities: 0.06755066 - temperature 2.010655
# Epoch 87/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9971 - val_loss: 1.1603
# mean max of probabilities: 0.06920186 - temperature 1.9734986
# Epoch 88/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9972 - val_loss: 1.1185
# mean max of probabilities: 0.07048117 - temperature 1.9370288
# Epoch 89/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9972 - val_loss: 1.1259
# mean max of probabilities: 0.072072476 - temperature 1.9012331
# Epoch 90/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9976 - val_loss: 1.0781
# mean max of probabilities: 0.07361744 - temperature 1.8660985
# Epoch 91/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9975 - val_loss: 1.0641
# mean max of probabilities: 0.075669244 - temperature 1.8316135
# Epoch 92/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9976 - val_loss: 1.0603
# mean max of probabilities: 0.0771813 - temperature 1.7977657
# Epoch 93/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9976 - val_loss: 1.0495
# mean max of probabilities: 0.07912027 - temperature 1.7645434
# Epoch 94/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 1.0403
# mean max of probabilities: 0.08100828 - temperature 1.731935
# Epoch 95/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 1.0368
# mean max of probabilities: 0.08361244 - temperature 1.6999295
# Epoch 96/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9978 - val_loss: 1.0283
# mean max of probabilities: 0.08646811 - temperature 1.6685151
# Epoch 97/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9980 - val_loss: 1.0223
# mean max of probabilities: 0.08828844 - temperature 1.6376812
# Epoch 98/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9982 - val_loss: 1.0208
# mean max of probabilities: 0.089992076 - temperature 1.6074175
# Epoch 99/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9981 - val_loss: 1.0184
# mean max of probabilities: 0.09167889 - temperature 1.5777129
# Epoch 100/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9981 - val_loss: 1.0163
# mean max of probabilities: 0.09333022 - temperature 1.5485573
# Epoch 101/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9983 - val_loss: 1.0168
# mean max of probabilities: 0.09583618 - temperature 1.5199404
# Epoch 102/250
# 80/80 [==============================] - 0s 5ms/step - loss: 0.9985 - val_loss: 1.0133
# mean max of probabilities: 0.09868873 - temperature 1.4918525
# Epoch 103/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9984 - val_loss: 1.0078
# mean max of probabilities: 0.10156705 - temperature 1.4642832
# Epoch 104/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.0076
# mean max of probabilities: 0.10470182 - temperature 1.4372237
# Epoch 105/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 1.0083
# mean max of probabilities: 0.10832441 - temperature 1.4106642
# Epoch 106/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9986 - val_loss: 1.0049
# mean max of probabilities: 0.11152449 - temperature 1.3845954
# Epoch 107/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9986 - val_loss: 1.0041
# mean max of probabilities: 0.11554464 - temperature 1.3590084
# Epoch 108/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9986 - val_loss: 1.0056
# mean max of probabilities: 0.11982145 - temperature 1.3338945
# Epoch 109/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9987 - val_loss: 1.0040
# mean max of probabilities: 0.12434441 - temperature 1.3092445
# Epoch 110/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9989 - val_loss: 1.0026
# mean max of probabilities: 0.12833071 - temperature 1.2850498
# Epoch 111/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9987 - val_loss: 1.0025
# mean max of probabilities: 0.13256606 - temperature 1.2613022
# Epoch 112/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9988 - val_loss: 1.0026
# mean max of probabilities: 0.13719249 - temperature 1.2379937
# Epoch 113/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9988 - val_loss: 1.0033
# mean max of probabilities: 0.14430073 - temperature 1.2151159
# Epoch 114/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9989 - val_loss: 1.0025
# mean max of probabilities: 0.15078637 - temperature 1.1926609
# Epoch 115/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9989 - val_loss: 1.0021
# mean max of probabilities: 0.15875542 - temperature 1.1706207
# Epoch 116/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9990 - val_loss: 1.0015
# mean max of probabilities: 0.16752589 - temperature 1.1489881
# Epoch 117/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9989 - val_loss: 1.0018
# mean max of probabilities: 0.17611685 - temperature 1.1277554
# Epoch 118/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9988 - val_loss: 1.0016
# mean max of probabilities: 0.18733028 - temperature 1.1069155
# Epoch 119/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9992 - val_loss: 1.0016
# mean max of probabilities: 0.1974406 - temperature 1.0864598
# Epoch 120/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9989 - val_loss: 1.0012
# mean max of probabilities: 0.20934045 - temperature 1.0663822
# Epoch 121/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9988 - val_loss: 1.0010
# mean max of probabilities: 0.22235596 - temperature 1.0466757
# Epoch 122/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9990 - val_loss: 1.0007
# mean max of probabilities: 0.23430303 - temperature 1.0273333
# Epoch 123/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9989 - val_loss: 1.0002
# mean max of probabilities: 0.24790664 - temperature 1.0083485
# Epoch 124/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9989 - val_loss: 1.0000
# mean max of probabilities: 0.2631235 - temperature 0.98971456
# Epoch 125/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9987 - val_loss: 0.9997
# mean max of probabilities: 0.27986956 - temperature 0.971425
# Epoch 126/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9987 - val_loss: 0.9998
# mean max of probabilities: 0.297268 - temperature 0.95347327
# Epoch 127/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 0.9991
# mean max of probabilities: 0.31503215 - temperature 0.93585336
# Epoch 128/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9987 - val_loss: 0.9991
# mean max of probabilities: 0.33527365 - temperature 0.9185591
# Epoch 129/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9985 - val_loss: 0.9989
# mean max of probabilities: 0.35865113 - temperature 0.9015844
# Epoch 130/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9983 - val_loss: 0.9987
# mean max of probabilities: 0.38229597 - temperature 0.8849234
# Epoch 131/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 0.9982
# mean max of probabilities: 0.40475532 - temperature 0.86857027
# Epoch 132/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9980 - val_loss: 0.9979
# mean max of probabilities: 0.42706135 - temperature 0.85251933
# Epoch 133/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 0.9977
# mean max of probabilities: 0.45009595 - temperature 0.836765
# Epoch 134/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9977 - val_loss: 0.9975
# mean max of probabilities: 0.47363243 - temperature 0.8213018
# Epoch 135/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 0.9973
# mean max of probabilities: 0.49582848 - temperature 0.80612445
# Epoch 136/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9974 - val_loss: 0.9970
# mean max of probabilities: 0.51907456 - temperature 0.7912275
# Epoch 137/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9972 - val_loss: 0.9971
# mean max of probabilities: 0.5397725 - temperature 0.7766059
# Epoch 138/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9972 - val_loss: 0.9969
# mean max of probabilities: 0.5609054 - temperature 0.7622544
# Epoch 139/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9969 - val_loss: 0.9964
# mean max of probabilities: 0.5814508 - temperature 0.7481678
# Epoch 140/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9966 - val_loss: 0.9965
# mean max of probabilities: 0.60183203 - temperature 0.7343417
# Epoch 141/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9961 - val_loss: 0.9963
# mean max of probabilities: 0.61854327 - temperature 0.72077125
# Epoch 142/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9958 - val_loss: 0.9963
# mean max of probabilities: 0.6340546 - temperature 0.7074516
# Epoch 143/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9958 - val_loss: 0.9962
# mean max of probabilities: 0.6473689 - temperature 0.69437814
# Epoch 144/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9957 - val_loss: 0.9963
# mean max of probabilities: 0.6607609 - temperature 0.6815462
# Epoch 145/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9956 - val_loss: 0.9963
# mean max of probabilities: 0.67471796 - temperature 0.66895145
# Epoch 146/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9952 - val_loss: 0.9961
# mean max of probabilities: 0.68568313 - temperature 0.6565894
# Epoch 147/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9956 - val_loss: 0.9961
# mean max of probabilities: 0.6961941 - temperature 0.64445585
# Epoch 148/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9954 - val_loss: 0.9961
# mean max of probabilities: 0.70573163 - temperature 0.63254637
# Epoch 149/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9950 - val_loss: 0.9959
# mean max of probabilities: 0.71477646 - temperature 0.6208571
# Epoch 150/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9949 - val_loss: 0.9959
# mean max of probabilities: 0.7231778 - temperature 0.6093838
# Epoch 151/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9945 - val_loss: 0.9959
# mean max of probabilities: 0.73138887 - temperature 0.5981226
# Epoch 152/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9948 - val_loss: 0.9959
# mean max of probabilities: 0.7384298 - temperature 0.58706945
# Epoch 153/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9952 - val_loss: 0.9959
# mean max of probabilities: 0.7463429 - temperature 0.57622045
# Epoch 154/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9944 - val_loss: 0.9959
# mean max of probabilities: 0.7523248 - temperature 0.56557226
# Epoch 155/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9943 - val_loss: 0.9959
# mean max of probabilities: 0.75896394 - temperature 0.5551209
# Epoch 156/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9942 - val_loss: 0.9959
# mean max of probabilities: 0.76403785 - temperature 0.5448624
# Epoch 157/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9942 - val_loss: 0.9959
# mean max of probabilities: 0.76986676 - temperature 0.5347935
# Epoch 158/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9943 - val_loss: 0.9959
# mean max of probabilities: 0.7762881 - temperature 0.5249107
# Epoch 159/250
# 80/80 [==============================] - 0s 5ms/step - loss: 0.9940 - val_loss: 0.9960
# mean max of probabilities: 0.7800808 - temperature 0.51521045
# Epoch 160/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9936 - val_loss: 0.9960
# mean max of probabilities: 0.78415287 - temperature 0.50568956
# Epoch 161/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9937 - val_loss: 0.9960
# mean max of probabilities: 0.78706336 - temperature 0.4963446
# Epoch 162/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9938 - val_loss: 0.9959
# mean max of probabilities: 0.7902676 - temperature 0.4871723
# Epoch 163/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9939 - val_loss: 0.9960
# mean max of probabilities: 0.79313636 - temperature 0.47816944
# Epoch 164/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9938 - val_loss: 0.9960
# mean max of probabilities: 0.7966091 - temperature 0.469333
# Epoch 165/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9940 - val_loss: 0.9959
# mean max of probabilities: 0.79923165 - temperature 0.46065983
# Epoch 166/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9937 - val_loss: 0.9960
# mean max of probabilities: 0.8032033 - temperature 0.45214692
# Epoch 167/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9936 - val_loss: 0.9960
# mean max of probabilities: 0.8059661 - temperature 0.44379142
# Epoch 168/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9937 - val_loss: 0.9960
# mean max of probabilities: 0.8094717 - temperature 0.4355903
# Epoch 169/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9932 - val_loss: 0.9961
# mean max of probabilities: 0.81311524 - temperature 0.4275407
# Epoch 170/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9938 - val_loss: 0.9961
# mean max of probabilities: 0.81499594 - temperature 0.41963986
# Epoch 171/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9936 - val_loss: 0.9960
# mean max of probabilities: 0.8182923 - temperature 0.41188508
# Epoch 172/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9937 - val_loss: 0.9961
# mean max of probabilities: 0.8214026 - temperature 0.40427354
# Epoch 173/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9933 - val_loss: 0.9961
# mean max of probabilities: 0.8238423 - temperature 0.3968027
# Epoch 174/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9933 - val_loss: 0.9962
# mean max of probabilities: 0.82659745 - temperature 0.38946986
# Epoch 175/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9931 - val_loss: 0.9960
# mean max of probabilities: 0.8302725 - temperature 0.38227254
# Epoch 176/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9931 - val_loss: 0.9961
# mean max of probabilities: 0.8325947 - temperature 0.37520817
# Epoch 177/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9928 - val_loss: 0.9961
# mean max of probabilities: 0.8349095 - temperature 0.36827427
# Epoch 178/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9931 - val_loss: 0.9961
# mean max of probabilities: 0.8382065 - temperature 0.36146867
# Epoch 179/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9932 - val_loss: 0.9961
# mean max of probabilities: 0.840357 - temperature 0.35478884
# Epoch 180/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9933 - val_loss: 0.9962
# mean max of probabilities: 0.8437381 - temperature 0.34823245
# Epoch 181/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9933 - val_loss: 0.9961
# mean max of probabilities: 0.84643996 - temperature 0.34179723
# Epoch 182/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9932 - val_loss: 0.9961
# mean max of probabilities: 0.8487729 - temperature 0.3354809
# Epoch 183/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9933 - val_loss: 0.9962
# mean max of probabilities: 0.8515996 - temperature 0.3292813
# Epoch 184/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9934 - val_loss: 0.9961
# mean max of probabilities: 0.8555734 - temperature 0.32319623
# Epoch 185/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9931 - val_loss: 0.9961
# mean max of probabilities: 0.8587879 - temperature 0.31722364
# Epoch 186/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9924 - val_loss: 0.9961
# mean max of probabilities: 0.8607395 - temperature 0.31136146
# Epoch 187/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9928 - val_loss: 0.9961
# mean max of probabilities: 0.8641299 - temperature 0.30560762
# Epoch 188/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9931 - val_loss: 0.9961
# mean max of probabilities: 0.8681239 - temperature 0.29996008
# Epoch 189/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9932 - val_loss: 0.9961
# mean max of probabilities: 0.8709453 - temperature 0.29441693
# Epoch 190/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9927 - val_loss: 0.9961
# mean max of probabilities: 0.8747352 - temperature 0.2889762
# Epoch 191/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9926 - val_loss: 0.9961
# mean max of probabilities: 0.8783945 - temperature 0.283636
# Epoch 192/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9928 - val_loss: 0.9961
# mean max of probabilities: 0.88293785 - temperature 0.27839464
# Epoch 193/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9928 - val_loss: 0.9961
# mean max of probabilities: 0.8870705 - temperature 0.27324998
# Epoch 194/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9927 - val_loss: 0.9961
# mean max of probabilities: 0.8898468 - temperature 0.2682004
# Epoch 195/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9923 - val_loss: 0.9960
# mean max of probabilities: 0.89369494 - temperature 0.26324412
# Epoch 196/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9923 - val_loss: 0.9960
# mean max of probabilities: 0.89786315 - temperature 0.25837946
# Epoch 197/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9922 - val_loss: 0.9959
# mean max of probabilities: 0.90027446 - temperature 0.2536047
# Epoch 198/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9920 - val_loss: 0.9960
# mean max of probabilities: 0.90463066 - temperature 0.24891822
# Epoch 199/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9921 - val_loss: 0.9960
# mean max of probabilities: 0.9104718 - temperature 0.24431825
# Epoch 200/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9921 - val_loss: 0.9959
# mean max of probabilities: 0.9133066 - temperature 0.23980331
# Epoch 201/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9921 - val_loss: 0.9960
# mean max of probabilities: 0.91555876 - temperature 0.23537181
# Epoch 202/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9918 - val_loss: 0.9959
# mean max of probabilities: 0.91744065 - temperature 0.23102221
# Epoch 203/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9924 - val_loss: 0.9959
# mean max of probabilities: 0.92046237 - temperature 0.22675298
# Epoch 204/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9923 - val_loss: 0.9959
# mean max of probabilities: 0.9227369 - temperature 0.22256266
# Epoch 205/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9924 - val_loss: 0.9960
# mean max of probabilities: 0.9261749 - temperature 0.21844976
# Epoch 206/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9920 - val_loss: 0.9960
# mean max of probabilities: 0.92908186 - temperature 0.21441287
# Epoch 207/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9918 - val_loss: 0.9960
# mean max of probabilities: 0.9307844 - temperature 0.21045059
# Epoch 208/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9921 - val_loss: 0.9960
# mean max of probabilities: 0.93232435 - temperature 0.20656154
# Epoch 209/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9919 - val_loss: 0.9960
# mean max of probabilities: 0.93568265 - temperature 0.20274432
# Epoch 210/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9920 - val_loss: 0.9960
# mean max of probabilities: 0.9382514 - temperature 0.19899763
# Epoch 211/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9916 - val_loss: 0.9960
# mean max of probabilities: 0.9402975 - temperature 0.1953202
# Epoch 212/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9917 - val_loss: 0.9960
# mean max of probabilities: 0.9421278 - temperature 0.19171074
# Epoch 213/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9915 - val_loss: 0.9961
# mean max of probabilities: 0.94357353 - temperature 0.18816796
# Epoch 214/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9917 - val_loss: 0.9960
# mean max of probabilities: 0.94577956 - temperature 0.18469061
# Epoch 215/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9915 - val_loss: 0.9961
# mean max of probabilities: 0.94708997 - temperature 0.18127757
# Epoch 216/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9915 - val_loss: 0.9962
# mean max of probabilities: 0.94860184 - temperature 0.1779276
# Epoch 217/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9917 - val_loss: 0.9961
# mean max of probabilities: 0.9506427 - temperature 0.17463955
# Epoch 218/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9915 - val_loss: 0.9961
# mean max of probabilities: 0.95255464 - temperature 0.17141226
# Epoch 219/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9918 - val_loss: 0.9962
# mean max of probabilities: 0.9532783 - temperature 0.16824457
# Epoch 220/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9917 - val_loss: 0.9961
# mean max of probabilities: 0.9550949 - temperature 0.16513543
# Epoch 221/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9912 - val_loss: 0.9961
# mean max of probabilities: 0.95631313 - temperature 0.16208376
# Epoch 222/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9915 - val_loss: 0.9962
# mean max of probabilities: 0.9572171 - temperature 0.15908849
# Epoch 223/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9913 - val_loss: 0.9962
# mean max of probabilities: 0.95816994 - temperature 0.15614857
# Epoch 224/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9910 - val_loss: 0.9962
# mean max of probabilities: 0.9590075 - temperature 0.15326299
# Epoch 225/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9915 - val_loss: 0.9961
# mean max of probabilities: 0.96021795 - temperature 0.15043072
# Epoch 226/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9910 - val_loss: 0.9961
# mean max of probabilities: 0.96073 - temperature 0.1476508
# Epoch 227/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9911 - val_loss: 0.9962
# mean max of probabilities: 0.9612818 - temperature 0.14492226
# Epoch 228/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9912 - val_loss: 0.9961
# mean max of probabilities: 0.9620342 - temperature 0.1422441
# Epoch 229/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9912 - val_loss: 0.9962
# mean max of probabilities: 0.9622772 - temperature 0.13961557
# Epoch 230/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9911 - val_loss: 0.9962
# mean max of probabilities: 0.96278214 - temperature 0.13703555
# Epoch 231/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9915 - val_loss: 0.9962
# mean max of probabilities: 0.963454 - temperature 0.13450316
# Epoch 232/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9909 - val_loss: 0.9962
# mean max of probabilities: 0.9641326 - temperature 0.13201758
# Epoch 233/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9915 - val_loss: 0.9962
# mean max of probabilities: 0.96512926 - temperature 0.12957793
# Epoch 234/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9913 - val_loss: 0.9962
# mean max of probabilities: 0.96589243 - temperature 0.12718338
# Epoch 235/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9913 - val_loss: 0.9961
# mean max of probabilities: 0.96640384 - temperature 0.12483306
# Epoch 236/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9912 - val_loss: 0.9962
# mean max of probabilities: 0.9668531 - temperature 0.122526176
# Epoch 237/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9909 - val_loss: 0.9963
# mean max of probabilities: 0.96714723 - temperature 0.12026193
# Epoch 238/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9909 - val_loss: 0.9962
# mean max of probabilities: 0.9678204 - temperature 0.118039526
# Epoch 239/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9910 - val_loss: 0.9963
# mean max of probabilities: 0.9683833 - temperature 0.1158582
# Epoch 240/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9912 - val_loss: 0.9962
# mean max of probabilities: 0.9689312 - temperature 0.113717176
# Epoch 241/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9911 - val_loss: 0.9963
# mean max of probabilities: 0.96933913 - temperature 0.11161572
# Epoch 242/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9907 - val_loss: 0.9963
# mean max of probabilities: 0.9699378 - temperature 0.10955309
# Epoch 243/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9906 - val_loss: 0.9964
# mean max of probabilities: 0.9701942 - temperature 0.107528575
# Epoch 244/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9909 - val_loss: 0.9963
# mean max of probabilities: 0.9702763 - temperature 0.10554148
# Epoch 245/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9910 - val_loss: 0.9963
# mean max of probabilities: 0.97059715 - temperature 0.103591114
# Epoch 246/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9909 - val_loss: 0.9963
# mean max of probabilities: 0.9708408 - temperature 0.101676784
# Epoch 247/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9909 - val_loss: 0.9964
# mean max of probabilities: 0.971087 - temperature 0.1
# Epoch 248/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9910 - val_loss: 0.9963
# mean max of probabilities: 0.971467 - temperature 0.1
# Epoch 249/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9907 - val_loss: 0.9963
# mean max of probabilities: 0.971732 - temperature 0.1
# Epoch 250/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9908 - val_loss: 0.9961

# %% [markdown]
# # Evaluate Models

# %%
y_pred = supervised_selector.model(x_test)
y_pred = tf.math.argmax(y_pred, axis=-1)
acc = 100*np.mean((y_pred==y_test_).numpy())

x_pred = unsupervised_selector.model(x_test)
reconstruction_error = np.mean((x_pred.numpy() - x_test)**2)

# %%
supervised_selected = supervised_selector.get_indices()
unsupervised_selected = unsupervised_selector.get_indices()

selected = np.unique(supervised_selected)
tpr, fdr = tpr_fdr(true_groups, [selected])
group_similarity, num_true_groups, num_discovered_groups = gsim(true_groups, [selected])

print('Supervised:')
print('Accuracy: {:.3f}%'.format(acc))
print('Selected features: {}'.format(selected))
print('TPR: {:.3f}%'.format(tpr))
print('FDR: {:.3f}%'.format(fdr))
print('Gsim: {:.3f}'.format(group_similarity))
print('Num True Groups: {}'.format(num_true_groups))
print('Num Discovered Groups: {}'.format(num_discovered_groups))


selected = np.unique(unsupervised_selected)
tpr, fdr = tpr_fdr(true_groups, [selected])
group_similarity, num_true_groups, num_discovered_groups = gsim(true_groups, [selected])

print('\nUnsupervised:')
print('Reconstruction Error: {:.3f}'.format(reconstruction_error))
print('Selected features: {}'.format(selected))
print('TPR: {:.3f}%'.format(tpr))
print('FDR: {:.3f}%'.format(fdr))
print('Gsim: {:.3f}'.format(group_similarity))
print('Num True Groups: {}'.format(num_true_groups))
print('Num Discovered Groups: {}'.format(num_discovered_groups))
# Out:
# Supervised:
# Accuracy: 47.500%
# Selected features: [162 272 310]
# TPR: 0.000%
# FDR: 100.000%
# Gsim: 0.000
# Num True Groups: 2
# Num Discovered Groups: 1
#
# Unsupervised:
# Reconstruction Error: 0.996
# Selected features: [104 184 225 285]
# TPR: 0.000%
# FDR: 100.000%
# Gsim: 0.000
# Num True Groups: 2
# Num Discovered Groups: 1
