# %% [markdown]
# # CAE

# %%
import math

from keras import backend as K
from keras import Model
from keras.layers import Layer, Softmax, Input
from keras.callbacks import EarlyStopping
from keras.initializers import Constant, glorot_normal
from tensorflow.keras.optimizers import Adam



class ConcreteSelect(Layer):
    
    def __init__(self, output_dim, start_temp = 10.0, min_temp = 0.1, alpha = 0.99999, **kwargs):
        self.output_dim = output_dim
        self.start_temp = start_temp
        self.min_temp = K.constant(min_temp)
        self.alpha = K.constant(alpha)
        super(ConcreteSelect, self).__init__(**kwargs)
        
    def build(self, input_shape):
        self.temp = self.add_weight(name = 'temp', shape = [], initializer = Constant(self.start_temp), trainable = False)
        self.logits = self.add_weight(name = 'logits', shape = [self.output_dim, input_shape[1]], initializer = glorot_normal(), trainable = True)
        super(ConcreteSelect, self).build(input_shape)
        
    def call(self, X, training=None):
        uniform = K.random_uniform(self.logits.shape, K.epsilon(), 1.0)
        gumbel = -K.log(-K.log(uniform))
        temp = K.update(self.temp, K.maximum(self.min_temp, self.temp * self.alpha))
        noisy_logits = (self.logits + gumbel) / temp
        samples = K.softmax(noisy_logits)
        
        discrete_logits = K.one_hot(K.argmax(self.logits), self.logits.shape[1])
        
        self.selections = K.in_train_phase(samples, discrete_logits, training)
        Y = K.dot(X, K.transpose(self.selections))
        
        return Y
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)
    
class StopperCallback(EarlyStopping):
    
    def __init__(self, mean_max_target = 0.998):
        self.mean_max_target = mean_max_target
        super(StopperCallback, self).__init__(monitor = '', patience = float('inf'), verbose = 1, mode = 'max', baseline = self.mean_max_target)
    
    def on_epoch_begin(self, epoch, logs = None):
        print('mean max of probabilities:', self.get_monitor_value(logs), '- temperature', K.get_value(self.model.get_layer('concrete_select').temp))
        #print( K.get_value(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        #print(K.get_value(K.max(self.model.get_layer('concrete_select').selections, axis = -1)))
    
    def get_monitor_value(self, logs):
        monitor_value = K.get_value(K.mean(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        return monitor_value


class ConcreteAutoencoderFeatureSelector():
    
    def __init__(self, K, output_function, num_epochs = 300, batch_size = None, learning_rate = 0.001, start_temp = 10.0, min_temp = 0.1, tryout_limit = 5):
        self.K = K
        self.output_function = output_function
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.start_temp = start_temp
        self.min_temp = min_temp
        self.tryout_limit = tryout_limit
        
    def fit(self, X, Y = None, val_X = None, val_Y = None):
        if Y is None:
            Y = X
        assert len(X) == len(Y)
        validation_data = None
        if val_X is not None and val_Y is not None:
            assert len(val_X) == len(val_Y)
            validation_data = (val_X, val_Y)
        
        if self.batch_size is None:
            self.batch_size = max(len(X) // 256, 16)
        
        num_epochs = self.num_epochs
        steps_per_epoch = (len(X) + self.batch_size - 1) // self.batch_size
        
        for i in range(self.tryout_limit):
            
            K.set_learning_phase(1)
            
            inputs = Input(shape = X.shape[1:])

            alpha = math.exp(math.log(self.min_temp / self.start_temp) / (num_epochs * steps_per_epoch))
            
            self.concrete_select = ConcreteSelect(self.K, self.start_temp, self.min_temp, alpha, name = 'concrete_select')

            selected_features = self.concrete_select(inputs)

            outputs = self.output_function(selected_features)

            self.model = Model(inputs, outputs)

            self.model.compile(Adam(self.learning_rate), loss = 'mean_squared_error')
            
            print(self.model.summary())
            
            stopper_callback = StopperCallback()
            
            hist = self.model.fit(X, Y, self.batch_size, num_epochs, verbose = 1, callbacks = [stopper_callback], validation_data = validation_data)#, validation_freq = 10)
            
            if K.get_value(K.mean(K.max(K.softmax(self.concrete_select.logits, axis = -1)))) >= stopper_callback.mean_max_target:
                break
            
            num_epochs *= 2
        
        self.probabilities = K.get_value(K.softmax(self.model.get_layer('concrete_select').logits))
        self.indices = K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
            
        return self
    
    def get_indices(self):
        return K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
    
    def get_mask(self):
        return K.get_value(K.sum(K.one_hot(K.argmax(self.model.get_layer('concrete_select').logits), self.model.get_layer('concrete_select').logits.shape[1]), axis = 0))
    
    def transform(self, X):
        return X[self.get_indices()]
    
    def fit_transform(self, X, y):
        self.fit(X, y)
        return self.transform(X)
    
    def get_support(self, indices = False):
        return self.get_indices() if indices else self.get_mask()
    
    def get_params(self):
        return self.model

# %% [markdown]
# # Experiment

# %%
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Softmax
import numpy as np

from functools import reduce

# %%
import torch
from torch.distributions.normal import Normal
from torch.distributions.multivariate_normal import MultivariateNormal


def gauss_rule1(x):
    return ((x[0] > 0.55) or (x[1] > 0.55))

def gauss_rule2(x):
    return ((x[0]*x[1] > 0.30) or (x[2]*x[3] > 0.30))

def gauss_rule3(x):
    return ((x[0]*x[1] > 0.30) or (x[0]*x[2] > 0.30))

def gauss_rule4(x):
    return (x[0]*x[3] > 0.30) or (x[6]*x[9] > 0.30)

def gauss_sample(nfeatures):
    return torch.randn(nfeatures)

n_correlated = 3
correlation_value = 0.99
cov_correlated = (1-correlation_value)*torch.eye(n_correlated) + torch.full([n_correlated, n_correlated], correlation_value)
dist_correlated = MultivariateNormal(loc=torch.full([n_correlated], 0.0), covariance_matrix=cov_correlated)
def gauss_sample_correlated(nfeatures):
    noise = torch.randn((nfeatures-4*n_correlated))
    return torch.cat([dist_correlated.sample(), dist_correlated.sample(), dist_correlated.sample(), dist_correlated.sample(), noise], dim=-1)

gauss_rules = {1: gauss_rule1, 2: gauss_rule2, 3: gauss_rule3, 4: gauss_rule4}
gauss_groups = {1: [np.array([0]), np.array([1])], 2: [np.array([0, 1]), np.array([2, 3])],
                3: [np.array([0, 1]), np.array([0, 2])], 4: [np.array([0, 3]), np.array([6, 9])]}
gauss_dists = {1: gauss_sample, 2: gauss_sample, 3: gauss_sample, 4: gauss_sample_correlated}
gauss_oracle_features = {1: np.array([0, 1]), 2: np.array([0, 1, 2, 3]),
                         3: np.array([0, 1, 2]), 4: np.array([0, 3, 6, 9])}



def make_syn_data(rule, num_data, nfeatures=500, train=True):
    sampler = gauss_dists[rule]
    selection_rule = gauss_rules[rule]
    n0 = 0
    n1 = 0
    x_data = torch.empty((num_data, nfeatures))
    y_data = torch.empty((num_data))
    for i in range(num_data):
        x = sampler(nfeatures)
        if selection_rule(x):
            y = torch.tensor(1).long()
            n1 += 1
        else:
            y = torch.tensor(0).long()
            n0 += 1
        x_data[i] = x
        y_data[i] = y

    is_train = '\nTrain' if train else 'Test '
    print(is_train+' Data Proportions:  0: {:.3f}, 1: {:.3f}'.format(n0/num_data, n1/num_data))
    x_data = x_data.numpy()
    y_data = y_data.numpy()
    return x_data, y_data


def set_seed(x):
    # set a consistent seed, so we can run across different runs
    x *= 10000
    np.random.seed(x)
    tf.random.set_seed(x)
    torch.manual_seed(x)
    torch.cuda.manual_seed(x)
    torch.cuda.manual_seed_all(x)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
def get_jaccard_score(true_groups, predicted_groups):
    # get jaccard similarity score for a model
    jaccard_score = 0
    if len(true_groups) == 0: # i.e. we don't know the ground truth
       return -1, len(true_groups), len(predicted_groups)
    if len(predicted_groups)>0:
      for g in true_groups:
         current_max = 0
         for g_hat in predicted_groups:
            jac = np.intersect1d(g, g_hat).size / np.union1d(g, g_hat).size
            if jac == 1:
               current_max = 1
               break
            if jac > current_max:
               current_max = jac
         jaccard_score += current_max
      jaccard_score /= len(true_groups)
      return jaccard_score, len(true_groups), len(predicted_groups)
    else:   # we didn't find anything
      return 0, len(true_groups), len(predicted_groups)


def tpr_fdr(true_groups, predicted_groups):
   # true positive rate and false discovery rate
   
   if len(true_groups) == 0:  # ground truth not known
      return -1, -1
   if len(predicted_groups) == 0:
      return 0.0, 0.0

   predicted_features = np.unique(reduce(np.union1d, predicted_groups))
   true_features = np.unique(reduce(np.union1d, true_groups))

   overlap = np.intersect1d(predicted_features, true_features).size
   tpr = 100*overlap/len(true_features)
   fdr = 100*(len(predicted_features)-overlap)/len(predicted_features) #if len(predicted_features) != 0 else 0.0
   return tpr, fdr

# %%
experiment_no = 10
experiment_choice = 4
train_size = 20000
test_size = 200
nfeatures = 500
nhidden = 200
batchsize = 250
lr = 0.001
nepochs = 250
tryoutlimit = 1
nk = len(gauss_oracle_features[experiment_choice])
set_seed(experiment_no)

x_train, y_train_ = make_syn_data(experiment_choice, train_size, nfeatures=nfeatures, train=True)
x_test, y_test_ = make_syn_data(experiment_choice, test_size, nfeatures=nfeatures, train=False)
y_train = to_categorical(y_train_)
y_test = to_categorical(y_test_)     # to_categorical turns to one-hot encoding
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Train Data Proportions:  0: 0.521, 1: 0.478
# Test  Data Proportions:  0: 0.505, 1: 0.495
# (20000, 500)
# (20000, 2)
# (200, 500)
# (200, 2)

# %%
def f(x):
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nfeatures)(x)
    return x

def g(x):
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(nhidden, activation='relu')(x)
    x = Dense(2)(x)
    x = Softmax()(x)
    return x

# %%
supervised_selector = ConcreteAutoencoderFeatureSelector(K=nk, output_function=g, num_epochs=nepochs, tryout_limit=tryoutlimit, batch_size=batchsize)
supervised_selector.fit(x_train, y_train, x_test, y_test)
# Out:
# Model: "model_129"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_131 (InputLayer)      [(None, 500)]             0
#
#  concrete_select (ConcreteSe  (None, 4)                2001
#  lect)
#
#  dense_1657 (Dense)          (None, 200)               1000
#
#  dense_1658 (Dense)          (None, 200)               40200
#
#  dense_1659 (Dense)          (None, 2)                 402
#
#  softmax_404 (Softmax)       (None, 2)                 0
#
# =================================================================
# Total params: 43,603
# Trainable params: 43,602
# Non-trainable params: 1
# _________________________________________________________________
# None
# mean max of probabilities: 0.0022958862 - temperature 10.0
# Epoch 1/250
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 80/80 [==============================] - 1s 4ms/step - loss: 0.2497 - val_loss: 0.2524
# mean max of probabilities: 0.002304283 - temperature 9.815204
# Epoch 2/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2446
# mean max of probabilities: 0.0023825637 - temperature 9.6338215
# Epoch 3/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.2413
# mean max of probabilities: 0.002557949 - temperature 9.4557905
# Epoch 4/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2528
# mean max of probabilities: 0.0027683375 - temperature 9.281052
# Epoch 5/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2621
# mean max of probabilities: 0.0029642715 - temperature 9.10954
# Epoch 6/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2866
# mean max of probabilities: 0.0032197807 - temperature 8.941198
# Epoch 7/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.2977
# mean max of probabilities: 0.0034129159 - temperature 8.775969
# Epoch 8/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3198
# mean max of probabilities: 0.003659349 - temperature 8.613791
# Epoch 9/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3371
# mean max of probabilities: 0.003990921 - temperature 8.454611
# Epoch 10/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3258
# mean max of probabilities: 0.0043614362 - temperature 8.298373
# Epoch 11/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2492 - val_loss: 0.3434
# mean max of probabilities: 0.0046702893 - temperature 8.1450205
# Epoch 12/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2493 - val_loss: 0.3569
# mean max of probabilities: 0.005000039 - temperature 7.994502
# Epoch 13/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3667
# mean max of probabilities: 0.005435537 - temperature 7.8467665
# Epoch 14/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.3647
# mean max of probabilities: 0.0059262016 - temperature 7.7017603
# Epoch 15/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3839
# mean max of probabilities: 0.0063675437 - temperature 7.5594344
# Epoch 16/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3773
# mean max of probabilities: 0.006954329 - temperature 7.419739
# Epoch 17/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.3792
# mean max of probabilities: 0.0075533674 - temperature 7.2826233
# Epoch 18/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.3884
# mean max of probabilities: 0.008114018 - temperature 7.1480412
# Epoch 19/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2490 - val_loss: 0.3847
# mean max of probabilities: 0.008883658 - temperature 7.015947
# Epoch 20/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2488 - val_loss: 0.3964
# mean max of probabilities: 0.009684911 - temperature 6.8862944
# Epoch 21/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2489 - val_loss: 0.3904
# mean max of probabilities: 0.010519449 - temperature 6.759037
# Epoch 22/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2487 - val_loss: 0.4021
# mean max of probabilities: 0.0114732105 - temperature 6.63413
# Epoch 23/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2488 - val_loss: 0.4003
# mean max of probabilities: 0.012468143 - temperature 6.511533
# Epoch 24/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2487 - val_loss: 0.4048
# mean max of probabilities: 0.013453256 - temperature 6.391201
# Epoch 25/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2486 - val_loss: 0.4110
# mean max of probabilities: 0.014471784 - temperature 6.2730927
# Epoch 26/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2486 - val_loss: 0.4129
# mean max of probabilities: 0.015785545 - temperature 6.1571674
# Epoch 27/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2485 - val_loss: 0.4053
# mean max of probabilities: 0.017275112 - temperature 6.0433846
# Epoch 28/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2484 - val_loss: 0.3998
# mean max of probabilities: 0.018840112 - temperature 5.9317064
# Epoch 29/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2485 - val_loss: 0.3977
# mean max of probabilities: 0.020282112 - temperature 5.82209
# Epoch 30/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2482 - val_loss: 0.4090
# mean max of probabilities: 0.021840416 - temperature 5.7145
# Epoch 31/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2480 - val_loss: 0.4090
# mean max of probabilities: 0.023772083 - temperature 5.608897
# Epoch 32/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2479 - val_loss: 0.4198
# mean max of probabilities: 0.025602555 - temperature 5.505246
# Epoch 33/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2476 - val_loss: 0.4182
# mean max of probabilities: 0.027829176 - temperature 5.403511
# Epoch 34/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2477 - val_loss: 0.4460
# mean max of probabilities: 0.030231044 - temperature 5.303656
# Epoch 35/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2473 - val_loss: 0.4509
# mean max of probabilities: 0.032805905 - temperature 5.205646
# Epoch 36/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2473 - val_loss: 0.4473
# mean max of probabilities: 0.035380457 - temperature 5.109448
# Epoch 37/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2469 - val_loss: 0.4542
# mean max of probabilities: 0.037945125 - temperature 5.015027
# Epoch 38/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2467 - val_loss: 0.4508
# mean max of probabilities: 0.040895164 - temperature 4.9223495
# Epoch 39/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2462 - val_loss: 0.4543
# mean max of probabilities: 0.04398308 - temperature 4.831385
# Epoch 40/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2460 - val_loss: 0.4575
# mean max of probabilities: 0.047136173 - temperature 4.7421026
# Epoch 41/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2453 - val_loss: 0.4428
# mean max of probabilities: 0.050489705 - temperature 4.654469
# Epoch 42/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2449 - val_loss: 0.4475
# mean max of probabilities: 0.05359699 - temperature 4.5684547
# Epoch 43/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2441 - val_loss: 0.4503
# mean max of probabilities: 0.056845587 - temperature 4.4840326
# Epoch 44/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2437 - val_loss: 0.4537
# mean max of probabilities: 0.060399666 - temperature 4.4011693
# Epoch 45/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2427 - val_loss: 0.4551
# mean max of probabilities: 0.06353302 - temperature 4.319837
# Epoch 46/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2417 - val_loss: 0.4567
# mean max of probabilities: 0.066399604 - temperature 4.2400074
# Epoch 47/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2410 - val_loss: 0.4648
# mean max of probabilities: 0.06942487 - temperature 4.1616535
# Epoch 48/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2394 - val_loss: 0.4465
# mean max of probabilities: 0.0720399 - temperature 4.084747
# Epoch 49/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2388 - val_loss: 0.4452
# mean max of probabilities: 0.07413748 - temperature 4.009262
# Epoch 50/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2362 - val_loss: 0.4453
# mean max of probabilities: 0.07655834 - temperature 3.9351718
# Epoch 51/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2349 - val_loss: 0.4478
# mean max of probabilities: 0.07849541 - temperature 3.8624508
# Epoch 52/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2329 - val_loss: 0.4492
# mean max of probabilities: 0.08026103 - temperature 3.7910738
# Epoch 53/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2309 - val_loss: 0.4409
# mean max of probabilities: 0.08112724 - temperature 3.7210162
# Epoch 54/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2287 - val_loss: 0.4560
# mean max of probabilities: 0.08149469 - temperature 3.6522527
# Epoch 55/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2258 - val_loss: 0.4634
# mean max of probabilities: 0.08094219 - temperature 3.58476
# Epoch 56/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2212 - val_loss: 0.4550
# mean max of probabilities: 0.08032331 - temperature 3.5185146
# Epoch 57/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2188 - val_loss: 0.4646
# mean max of probabilities: 0.08010934 - temperature 3.453493
# Epoch 58/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2162 - val_loss: 0.4687
# mean max of probabilities: 0.07973945 - temperature 3.3896737
# Epoch 59/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2143 - val_loss: 0.4636
# mean max of probabilities: 0.08005299 - temperature 3.3270326
# Epoch 60/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2120 - val_loss: 0.4618
# mean max of probabilities: 0.07948746 - temperature 3.2655501
# Epoch 61/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2095 - val_loss: 0.4592
# mean max of probabilities: 0.07932026 - temperature 3.2052035
# Epoch 62/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2100 - val_loss: 0.4524
# mean max of probabilities: 0.07968554 - temperature 3.1459723
# Epoch 63/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2071 - val_loss: 0.4405
# mean max of probabilities: 0.07972832 - temperature 3.0878353
# Epoch 64/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2055 - val_loss: 0.4334
# mean max of probabilities: 0.07960225 - temperature 3.030773
# Epoch 65/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2055 - val_loss: 0.4365
# mean max of probabilities: 0.08039251 - temperature 2.9747655
# Epoch 66/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2038 - val_loss: 0.4345
# mean max of probabilities: 0.080764204 - temperature 2.9197924
# Epoch 67/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2025 - val_loss: 0.4290
# mean max of probabilities: 0.08031445 - temperature 2.8658352
# Epoch 68/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2023 - val_loss: 0.4167
# mean max of probabilities: 0.080359995 - temperature 2.8128753
# Epoch 69/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2014 - val_loss: 0.4104
# mean max of probabilities: 0.0805151 - temperature 2.760894
# Epoch 70/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2004 - val_loss: 0.4075
# mean max of probabilities: 0.080934174 - temperature 2.7098737
# Epoch 71/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1996 - val_loss: 0.4129
# mean max of probabilities: 0.080991454 - temperature 2.6597965
# Epoch 72/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1981 - val_loss: 0.4039
# mean max of probabilities: 0.08115676 - temperature 2.610644
# Epoch 73/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1973 - val_loss: 0.4029
# mean max of probabilities: 0.080677584 - temperature 2.5624006
# Epoch 74/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1972 - val_loss: 0.3972
# mean max of probabilities: 0.08112163 - temperature 2.515048
# Epoch 75/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1959 - val_loss: 0.4035
# mean max of probabilities: 0.08140259 - temperature 2.4685702
# Epoch 76/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1958 - val_loss: 0.4008
# mean max of probabilities: 0.08132752 - temperature 2.4229515
# Epoch 77/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1974 - val_loss: 0.3638
# mean max of probabilities: 0.08201243 - temperature 2.378176
# Epoch 78/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1963 - val_loss: 0.3753
# mean max of probabilities: 0.08209659 - temperature 2.334228
# Epoch 79/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1956 - val_loss: 0.3857
# mean max of probabilities: 0.08191921 - temperature 2.291092
# Epoch 80/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1936 - val_loss: 0.3563
# mean max of probabilities: 0.08163868 - temperature 2.2487538
# Epoch 81/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1943 - val_loss: 0.3625
# mean max of probabilities: 0.08262412 - temperature 2.207198
# Epoch 82/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1946 - val_loss: 0.3575
# mean max of probabilities: 0.08357002 - temperature 2.1664093
# Epoch 83/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1951 - val_loss: 0.3570
# mean max of probabilities: 0.083364256 - temperature 2.1263747
# Epoch 84/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1931 - val_loss: 0.3279
# mean max of probabilities: 0.08347955 - temperature 2.0870795
# Epoch 85/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1936 - val_loss: 0.3156
# mean max of probabilities: 0.08350344 - temperature 2.048511
# Epoch 86/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1938 - val_loss: 0.3159
# mean max of probabilities: 0.083079174 - temperature 2.010655
# Epoch 87/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1936 - val_loss: 0.3173
# mean max of probabilities: 0.08323279 - temperature 1.9734986
# Epoch 88/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1946 - val_loss: 0.2556
# mean max of probabilities: 0.08354525 - temperature 1.9370288
# Epoch 89/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1933 - val_loss: 0.2527
# mean max of probabilities: 0.08429029 - temperature 1.9012331
# Epoch 90/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1926 - val_loss: 0.2892
# mean max of probabilities: 0.085104406 - temperature 1.8660985
# Epoch 91/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1913 - val_loss: 0.3030
# mean max of probabilities: 0.08646269 - temperature 1.8316135
# Epoch 92/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1921 - val_loss: 0.3009
# mean max of probabilities: 0.08736516 - temperature 1.7977657
# Epoch 93/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1941 - val_loss: 0.2992
# mean max of probabilities: 0.088376135 - temperature 1.7645434
# Epoch 94/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1934 - val_loss: 0.2547
# mean max of probabilities: 0.08847365 - temperature 1.731935
# Epoch 95/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1925 - val_loss: 0.2295
# mean max of probabilities: 0.08983961 - temperature 1.6999295
# Epoch 96/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1915 - val_loss: 0.2270
# mean max of probabilities: 0.0903734 - temperature 1.6685151
# Epoch 97/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1958 - val_loss: 0.2238
# mean max of probabilities: 0.09094356 - temperature 1.6376812
# Epoch 98/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1927 - val_loss: 0.2304
# mean max of probabilities: 0.09211615 - temperature 1.6074175
# Epoch 99/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1966 - val_loss: 0.2242
# mean max of probabilities: 0.092888 - temperature 1.5777129
# Epoch 100/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1941 - val_loss: 0.2393
# mean max of probabilities: 0.09357642 - temperature 1.5485573
# Epoch 101/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1970 - val_loss: 0.2424
# mean max of probabilities: 0.093797415 - temperature 1.5199404
# Epoch 102/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1951 - val_loss: 0.2387
# mean max of probabilities: 0.094204605 - temperature 1.4918525
# Epoch 103/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1903 - val_loss: 0.2144
# mean max of probabilities: 0.094588384 - temperature 1.4642832
# Epoch 104/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1947 - val_loss: 0.2180
# mean max of probabilities: 0.095589675 - temperature 1.4372237
# Epoch 105/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1918 - val_loss: 0.2085
# mean max of probabilities: 0.09645066 - temperature 1.4106642
# Epoch 106/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1919 - val_loss: 0.2128
# mean max of probabilities: 0.097673535 - temperature 1.3845954
# Epoch 107/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1949 - val_loss: 0.2019
# mean max of probabilities: 0.099106774 - temperature 1.3590084
# Epoch 108/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1935 - val_loss: 0.2172
# mean max of probabilities: 0.1009713 - temperature 1.3338945
# Epoch 109/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1927 - val_loss: 0.2092
# mean max of probabilities: 0.10322325 - temperature 1.3092445
# Epoch 110/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1944 - val_loss: 0.2160
# mean max of probabilities: 0.10468939 - temperature 1.2850498
# Epoch 111/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1954 - val_loss: 0.2001
# mean max of probabilities: 0.104978725 - temperature 1.2613022
# Epoch 112/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1940 - val_loss: 0.2045
# mean max of probabilities: 0.10613234 - temperature 1.2379937
# Epoch 113/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1958 - val_loss: 0.2062
# mean max of probabilities: 0.108139105 - temperature 1.2151159
# Epoch 114/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1932 - val_loss: 0.2022
# mean max of probabilities: 0.109727345 - temperature 1.1926609
# Epoch 115/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1936 - val_loss: 0.2194
# mean max of probabilities: 0.111556575 - temperature 1.1706207
# Epoch 116/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1946 - val_loss: 0.2281
# mean max of probabilities: 0.11225401 - temperature 1.1489881
# Epoch 117/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1943 - val_loss: 0.2339
# mean max of probabilities: 0.11429982 - temperature 1.1277554
# Epoch 118/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1934 - val_loss: 0.2231
# mean max of probabilities: 0.11761542 - temperature 1.1069155
# Epoch 119/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1954 - val_loss: 0.2276
# mean max of probabilities: 0.12084077 - temperature 1.0864598
# Epoch 120/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1944 - val_loss: 0.2108
# mean max of probabilities: 0.12203178 - temperature 1.0663822
# Epoch 121/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1927 - val_loss: 0.2064
# mean max of probabilities: 0.12425934 - temperature 1.0466757
# Epoch 122/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1959 - val_loss: 0.1962
# mean max of probabilities: 0.12652385 - temperature 1.0273333
# Epoch 123/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1977 - val_loss: 0.1802
# mean max of probabilities: 0.12992446 - temperature 1.0083485
# Epoch 124/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1914 - val_loss: 0.1720
# mean max of probabilities: 0.13186339 - temperature 0.98971456
# Epoch 125/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1912 - val_loss: 0.1844
# mean max of probabilities: 0.13419661 - temperature 0.971425
# Epoch 126/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1911 - val_loss: 0.2206
# mean max of probabilities: 0.1366025 - temperature 0.95347327
# Epoch 127/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1924 - val_loss: 0.1672
# mean max of probabilities: 0.13988113 - temperature 0.93585336
# Epoch 128/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1920 - val_loss: 0.1619
# mean max of probabilities: 0.14203905 - temperature 0.9185591
# Epoch 129/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1900 - val_loss: 0.2067
# mean max of probabilities: 0.14525586 - temperature 0.9015844
# Epoch 130/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1906 - val_loss: 0.1982
# mean max of probabilities: 0.14814119 - temperature 0.8849234
# Epoch 131/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1908 - val_loss: 0.1619
# mean max of probabilities: 0.1497783 - temperature 0.86857027
# Epoch 132/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1913 - val_loss: 0.1733
# mean max of probabilities: 0.1525131 - temperature 0.85251933
# Epoch 133/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1897 - val_loss: 0.1659
# mean max of probabilities: 0.1542463 - temperature 0.836765
# Epoch 134/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1899 - val_loss: 0.1558
# mean max of probabilities: 0.15655518 - temperature 0.8213018
# Epoch 135/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1865 - val_loss: 0.1634
# mean max of probabilities: 0.1607239 - temperature 0.80612445
# Epoch 136/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1941 - val_loss: 0.1523
# mean max of probabilities: 0.16317178 - temperature 0.7912275
# Epoch 137/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1862 - val_loss: 0.1969
# mean max of probabilities: 0.16498125 - temperature 0.7766059
# Epoch 138/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1891 - val_loss: 0.1621
# mean max of probabilities: 0.16622776 - temperature 0.7622544
# Epoch 139/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1880 - val_loss: 0.1676
# mean max of probabilities: 0.16817112 - temperature 0.7481678
# Epoch 140/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1927 - val_loss: 0.1614
# mean max of probabilities: 0.16967294 - temperature 0.7343417
# Epoch 141/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1876 - val_loss: 0.1535
# mean max of probabilities: 0.17271768 - temperature 0.72077125
# Epoch 142/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1883 - val_loss: 0.1638
# mean max of probabilities: 0.17492686 - temperature 0.7074516
# Epoch 143/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1870 - val_loss: 0.1528
# mean max of probabilities: 0.17743254 - temperature 0.69437814
# Epoch 144/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1989 - val_loss: 0.1480
# mean max of probabilities: 0.1800645 - temperature 0.6815462
# Epoch 145/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1900 - val_loss: 0.1476
# mean max of probabilities: 0.1821963 - temperature 0.66895145
# Epoch 146/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1901 - val_loss: 0.1575
# mean max of probabilities: 0.18414381 - temperature 0.6565894
# Epoch 147/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1913 - val_loss: 0.1540
# mean max of probabilities: 0.18527849 - temperature 0.64445585
# Epoch 148/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1901 - val_loss: 0.1565
# mean max of probabilities: 0.1875268 - temperature 0.63254637
# Epoch 149/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1893 - val_loss: 0.1482
# mean max of probabilities: 0.19002572 - temperature 0.6208571
# Epoch 150/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1862 - val_loss: 0.1322
# mean max of probabilities: 0.19163807 - temperature 0.6093838
# Epoch 151/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1832 - val_loss: 0.1419
# mean max of probabilities: 0.19400015 - temperature 0.5981226
# Epoch 152/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1934 - val_loss: 0.1458
# mean max of probabilities: 0.19494444 - temperature 0.58706945
# Epoch 153/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1881 - val_loss: 0.1399
# mean max of probabilities: 0.19635218 - temperature 0.57622045
# Epoch 154/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1889 - val_loss: 0.1525
# mean max of probabilities: 0.19923136 - temperature 0.56557226
# Epoch 155/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1898 - val_loss: 0.1392
# mean max of probabilities: 0.20037815 - temperature 0.5551209
# Epoch 156/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1896 - val_loss: 0.1506
# mean max of probabilities: 0.20292327 - temperature 0.5448624
# Epoch 157/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1859 - val_loss: 0.1377
# mean max of probabilities: 0.20442535 - temperature 0.5347935
# Epoch 158/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1879 - val_loss: 0.1525
# mean max of probabilities: 0.20485288 - temperature 0.5249107
# Epoch 159/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1972 - val_loss: 0.1647
# mean max of probabilities: 0.2056197 - temperature 0.51521045
# Epoch 160/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1878 - val_loss: 0.1407
# mean max of probabilities: 0.20778067 - temperature 0.50568956
# Epoch 161/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1879 - val_loss: 0.1412
# mean max of probabilities: 0.21057385 - temperature 0.4963446
# Epoch 162/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1882 - val_loss: 0.1379
# mean max of probabilities: 0.21457809 - temperature 0.4871723
# Epoch 163/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1913 - val_loss: 0.1334
# mean max of probabilities: 0.2172288 - temperature 0.47816944
# Epoch 164/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2001 - val_loss: 0.1532
# mean max of probabilities: 0.21982263 - temperature 0.469333
# Epoch 165/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1940 - val_loss: 0.1459
# mean max of probabilities: 0.22236715 - temperature 0.46065983
# Epoch 166/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1941 - val_loss: 0.1394
# mean max of probabilities: 0.22506106 - temperature 0.45214692
# Epoch 167/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1792 - val_loss: 0.1268
# mean max of probabilities: 0.22805762 - temperature 0.44379142
# Epoch 168/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1875 - val_loss: 0.1234
# mean max of probabilities: 0.23102285 - temperature 0.4355903
# Epoch 169/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1921 - val_loss: 0.1264
# mean max of probabilities: 0.23406167 - temperature 0.4275407
# Epoch 170/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1933 - val_loss: 0.1412
# mean max of probabilities: 0.2360982 - temperature 0.41963986
# Epoch 171/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1979 - val_loss: 0.1316
# mean max of probabilities: 0.23793143 - temperature 0.41188508
# Epoch 172/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1827 - val_loss: 0.1324
# mean max of probabilities: 0.23916191 - temperature 0.40427354
# Epoch 173/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1926 - val_loss: 0.1444
# mean max of probabilities: 0.2434809 - temperature 0.3968027
# Epoch 174/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1940 - val_loss: 0.1368
# mean max of probabilities: 0.24518825 - temperature 0.38946986
# Epoch 175/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1910 - val_loss: 0.1286
# mean max of probabilities: 0.2463158 - temperature 0.38227254
# Epoch 176/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1892 - val_loss: 0.1229
# mean max of probabilities: 0.24781568 - temperature 0.37520817
# Epoch 177/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1955 - val_loss: 0.1282
# mean max of probabilities: 0.24849826 - temperature 0.36827427
# Epoch 178/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1942 - val_loss: 0.1385
# mean max of probabilities: 0.25021756 - temperature 0.36146867
# Epoch 179/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1955 - val_loss: 0.1354
# mean max of probabilities: 0.25230837 - temperature 0.35478884
# Epoch 180/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1908 - val_loss: 0.1308
# mean max of probabilities: 0.25679466 - temperature 0.34823245
# Epoch 181/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1980 - val_loss: 0.1372
# mean max of probabilities: 0.25865066 - temperature 0.34179723
# Epoch 182/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1958 - val_loss: 0.1348
# mean max of probabilities: 0.26006192 - temperature 0.3354809
# Epoch 183/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1910 - val_loss: 0.1187
# mean max of probabilities: 0.26270288 - temperature 0.3292813
# Epoch 184/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1901 - val_loss: 0.1218
# mean max of probabilities: 0.26575488 - temperature 0.32319623
# Epoch 185/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1972 - val_loss: 0.1382
# mean max of probabilities: 0.26766935 - temperature 0.31722364
# Epoch 186/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2005 - val_loss: 0.1372
# mean max of probabilities: 0.27007037 - temperature 0.31136146
# Epoch 187/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1922 - val_loss: 0.1282
# mean max of probabilities: 0.27219436 - temperature 0.30560762
# Epoch 188/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1871 - val_loss: 0.1156
# mean max of probabilities: 0.2756148 - temperature 0.29996008
# Epoch 189/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1830 - val_loss: 0.1170
# mean max of probabilities: 0.2806874 - temperature 0.29441693
# Epoch 190/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1983 - val_loss: 0.1199
# mean max of probabilities: 0.2832588 - temperature 0.2889762
# Epoch 191/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1964 - val_loss: 0.1223
# mean max of probabilities: 0.28687257 - temperature 0.283636
# Epoch 192/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1912 - val_loss: 0.1158
# mean max of probabilities: 0.2897007 - temperature 0.27839464
# Epoch 193/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1848 - val_loss: 0.1213
# mean max of probabilities: 0.29154402 - temperature 0.27324998
# Epoch 194/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1949 - val_loss: 0.1182
# mean max of probabilities: 0.29376924 - temperature 0.2682004
# Epoch 195/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1849 - val_loss: 0.1207
# mean max of probabilities: 0.2972273 - temperature 0.26324412
# Epoch 196/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1936 - val_loss: 0.1348
# mean max of probabilities: 0.30057484 - temperature 0.25837946
# Epoch 197/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1905 - val_loss: 0.1191
# mean max of probabilities: 0.3022067 - temperature 0.2536047
# Epoch 198/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1854 - val_loss: 0.1177
# mean max of probabilities: 0.30611682 - temperature 0.24891822
# Epoch 199/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1884 - val_loss: 0.1225
# mean max of probabilities: 0.3097164 - temperature 0.24431825
# Epoch 200/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1872 - val_loss: 0.1135
# mean max of probabilities: 0.31184274 - temperature 0.23980331
# Epoch 201/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1789 - val_loss: 0.1066
# mean max of probabilities: 0.31383482 - temperature 0.23537181
# Epoch 202/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1878 - val_loss: 0.1093
# mean max of probabilities: 0.31653884 - temperature 0.23102221
# Epoch 203/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1864 - val_loss: 0.1128
# mean max of probabilities: 0.31888962 - temperature 0.22675298
# Epoch 204/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1902 - val_loss: 0.1208
# mean max of probabilities: 0.32204503 - temperature 0.22256266
# Epoch 205/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1784 - val_loss: 0.1050
# mean max of probabilities: 0.3272345 - temperature 0.21844976
# Epoch 206/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1867 - val_loss: 0.1074
# mean max of probabilities: 0.3292487 - temperature 0.21441287
# Epoch 207/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1862 - val_loss: 0.1061
# mean max of probabilities: 0.33042374 - temperature 0.21045059
# Epoch 208/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1843 - val_loss: 0.1036
# mean max of probabilities: 0.33496246 - temperature 0.20656154
# Epoch 209/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1776 - val_loss: 0.0930
# mean max of probabilities: 0.33989418 - temperature 0.20274432
# Epoch 210/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1876 - val_loss: 0.1083
# mean max of probabilities: 0.34388515 - temperature 0.19899763
# Epoch 211/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1749 - val_loss: 0.0974
# mean max of probabilities: 0.3470398 - temperature 0.1953202
# Epoch 212/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1849 - val_loss: 0.1048
# mean max of probabilities: 0.35119674 - temperature 0.19171074
# Epoch 213/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1628 - val_loss: 0.0887
# mean max of probabilities: 0.35551167 - temperature 0.18816796
# Epoch 214/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1802 - val_loss: 0.0967
# mean max of probabilities: 0.35938364 - temperature 0.18469061
# Epoch 215/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1728 - val_loss: 0.0992
# mean max of probabilities: 0.36242533 - temperature 0.18127757
# Epoch 216/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1718 - val_loss: 0.0946
# mean max of probabilities: 0.36730993 - temperature 0.1779276
# Epoch 217/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1658 - val_loss: 0.0903
# mean max of probabilities: 0.36879903 - temperature 0.17463955
# Epoch 218/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1767 - val_loss: 0.0928
# mean max of probabilities: 0.3728937 - temperature 0.17141226
# Epoch 219/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1866 - val_loss: 0.1036
# mean max of probabilities: 0.37803507 - temperature 0.16824457
# Epoch 220/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1728 - val_loss: 0.0937
# mean max of probabilities: 0.3817145 - temperature 0.16513543
# Epoch 221/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1725 - val_loss: 0.0918
# mean max of probabilities: 0.38554755 - temperature 0.16208376
# Epoch 222/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1681 - val_loss: 0.0878
# mean max of probabilities: 0.38937533 - temperature 0.15908849
# Epoch 223/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1656 - val_loss: 0.0930
# mean max of probabilities: 0.3949352 - temperature 0.15614857
# Epoch 224/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1683 - val_loss: 0.0867
# mean max of probabilities: 0.39811477 - temperature 0.15326299
# Epoch 225/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1686 - val_loss: 0.0865
# mean max of probabilities: 0.40112662 - temperature 0.15043072
# Epoch 226/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1832 - val_loss: 0.0951
# mean max of probabilities: 0.403633 - temperature 0.1476508
# Epoch 227/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1652 - val_loss: 0.0870
# mean max of probabilities: 0.40658805 - temperature 0.14492226
# Epoch 228/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1601 - val_loss: 0.0860
# mean max of probabilities: 0.40974665 - temperature 0.1422441
# Epoch 229/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1701 - val_loss: 0.0896
# mean max of probabilities: 0.41082856 - temperature 0.13961557
# Epoch 230/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1599 - val_loss: 0.0866
# mean max of probabilities: 0.41294992 - temperature 0.13703555
# Epoch 231/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1719 - val_loss: 0.0941
# mean max of probabilities: 0.4161837 - temperature 0.13450316
# Epoch 232/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1696 - val_loss: 0.0843
# mean max of probabilities: 0.41991803 - temperature 0.13201758
# Epoch 233/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1580 - val_loss: 0.0821
# mean max of probabilities: 0.4219157 - temperature 0.12957793
# Epoch 234/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1509 - val_loss: 0.0789
# mean max of probabilities: 0.4250423 - temperature 0.12718338
# Epoch 235/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1523 - val_loss: 0.0772
# mean max of probabilities: 0.43022913 - temperature 0.12483306
# Epoch 236/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1748 - val_loss: 0.0846
# mean max of probabilities: 0.43388075 - temperature 0.122526176
# Epoch 237/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1655 - val_loss: 0.0776
# mean max of probabilities: 0.4377382 - temperature 0.12026193
# Epoch 238/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1609 - val_loss: 0.0854
# mean max of probabilities: 0.43743724 - temperature 0.118039526
# Epoch 239/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1554 - val_loss: 0.0795
# mean max of probabilities: 0.43950027 - temperature 0.1158582
# Epoch 240/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1492 - val_loss: 0.0774
# mean max of probabilities: 0.44262195 - temperature 0.113717176
# Epoch 241/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1640 - val_loss: 0.0806
# mean max of probabilities: 0.4441241 - temperature 0.11161572
# Epoch 242/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1589 - val_loss: 0.0853
# mean max of probabilities: 0.4466254 - temperature 0.10955309
# Epoch 243/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1570 - val_loss: 0.0818
# mean max of probabilities: 0.45079023 - temperature 0.107528575
# Epoch 244/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1603 - val_loss: 0.0809
# mean max of probabilities: 0.4524741 - temperature 0.10554148
# Epoch 245/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1418 - val_loss: 0.0657
# mean max of probabilities: 0.456619 - temperature 0.103591114
# Epoch 246/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1615 - val_loss: 0.0828
# mean max of probabilities: 0.46040797 - temperature 0.101676784
# Epoch 247/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1457 - val_loss: 0.0650
# mean max of probabilities: 0.4632532 - temperature 0.1
# Epoch 248/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1549 - val_loss: 0.0765
# mean max of probabilities: 0.46628225 - temperature 0.1
# Epoch 249/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1500 - val_loss: 0.0713
# mean max of probabilities: 0.46849513 - temperature 0.1
# Epoch 250/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1321 - val_loss: 0.0678

# %%
unsupervised_selector = ConcreteAutoencoderFeatureSelector(K=nk, output_function=f, num_epochs=nepochs, tryout_limit=tryoutlimit, batch_size=batchsize)
unsupervised_selector.fit(x_train, x_train, x_test, x_test)
# Out:
# Model: "model_130"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_132 (InputLayer)      [(None, 500)]             0
#
#  concrete_select (ConcreteSe  (None, 4)                2001
#  lect)
#
#  dense_1660 (Dense)          (None, 200)               1000
#
#  dense_1661 (Dense)          (None, 200)               40200
#
#  dense_1662 (Dense)          (None, 500)               100500
#
# =================================================================
# Total params: 143,701
# Trainable params: 143,700
# Non-trainable params: 1
# _________________________________________________________________
# None
# mean max of probabilities: 0.0022949143 - temperature 10.0
# Epoch 1/250
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 80/80 [==============================] - 1s 4ms/step - loss: 0.9989 - val_loss: 1.1025
# mean max of probabilities: 0.0023053172 - temperature 9.815204
# Epoch 2/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9980 - val_loss: 1.1736
# mean max of probabilities: 0.002418059 - temperature 9.6338215
# Epoch 3/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9980 - val_loss: 1.2079
# mean max of probabilities: 0.0026144832 - temperature 9.4557905
# Epoch 4/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 1.2282
# mean max of probabilities: 0.0028299056 - temperature 9.281052
# Epoch 5/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 1.2466
# mean max of probabilities: 0.0030675326 - temperature 9.10954
# Epoch 6/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 1.3995
# mean max of probabilities: 0.0033288493 - temperature 8.941198
# Epoch 7/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 1.2637
# mean max of probabilities: 0.003618824 - temperature 8.775969
# Epoch 8/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9979 - val_loss: 1.2856
# mean max of probabilities: 0.0039321044 - temperature 8.613791
# Epoch 9/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9978 - val_loss: 1.2803
# mean max of probabilities: 0.0042811623 - temperature 8.454611
# Epoch 10/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9978 - val_loss: 1.2954
# mean max of probabilities: 0.004670392 - temperature 8.298373
# Epoch 11/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9978 - val_loss: 1.3045
# mean max of probabilities: 0.005096977 - temperature 8.1450205
# Epoch 12/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9978 - val_loss: 1.3210
# mean max of probabilities: 0.005552999 - temperature 7.994502
# Epoch 13/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9978 - val_loss: 1.3220
# mean max of probabilities: 0.006066421 - temperature 7.8467665
# Epoch 14/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9977 - val_loss: 1.3611
# mean max of probabilities: 0.006651733 - temperature 7.7017603
# Epoch 15/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9977 - val_loss: 1.3738
# mean max of probabilities: 0.0072679697 - temperature 7.5594344
# Epoch 16/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9977 - val_loss: 1.6749
# mean max of probabilities: 0.007968627 - temperature 7.419739
# Epoch 17/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9977 - val_loss: 1.7077
# mean max of probabilities: 0.008737676 - temperature 7.2826233
# Epoch 18/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9977 - val_loss: 1.7105
# mean max of probabilities: 0.009566806 - temperature 7.1480412
# Epoch 19/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9976 - val_loss: 1.7861
# mean max of probabilities: 0.010493372 - temperature 7.015947
# Epoch 20/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9976 - val_loss: 1.8034
# mean max of probabilities: 0.01150966 - temperature 6.8862944
# Epoch 21/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9976 - val_loss: 1.8016
# mean max of probabilities: 0.012630621 - temperature 6.759037
# Epoch 22/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9976 - val_loss: 1.8646
# mean max of probabilities: 0.013830566 - temperature 6.63413
# Epoch 23/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9976 - val_loss: 1.8769
# mean max of probabilities: 0.015170526 - temperature 6.511533
# Epoch 24/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9975 - val_loss: 1.9318
# mean max of probabilities: 0.016672311 - temperature 6.391201
# Epoch 25/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9975 - val_loss: 1.9605
# mean max of probabilities: 0.018201217 - temperature 6.2730927
# Epoch 26/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9975 - val_loss: 1.9588
# mean max of probabilities: 0.019928377 - temperature 6.1571674
# Epoch 27/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9975 - val_loss: 2.0317
# mean max of probabilities: 0.021776922 - temperature 6.0433846
# Epoch 28/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9974 - val_loss: 2.0639
# mean max of probabilities: 0.023720076 - temperature 5.9317064
# Epoch 29/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9974 - val_loss: 2.1033
# mean max of probabilities: 0.02581965 - temperature 5.82209
# Epoch 30/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9973 - val_loss: 2.1585
# mean max of probabilities: 0.028027158 - temperature 5.7145
# Epoch 31/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9973 - val_loss: 2.1521
# mean max of probabilities: 0.030321606 - temperature 5.608897
# Epoch 32/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9973 - val_loss: 2.1522
# mean max of probabilities: 0.03269375 - temperature 5.505246
# Epoch 33/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9972 - val_loss: 2.2312
# mean max of probabilities: 0.035088524 - temperature 5.403511
# Epoch 34/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9972 - val_loss: 2.2810
# mean max of probabilities: 0.037450634 - temperature 5.303656
# Epoch 35/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9971 - val_loss: 2.1589
# mean max of probabilities: 0.03969009 - temperature 5.205646
# Epoch 36/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9970 - val_loss: 2.2721
# mean max of probabilities: 0.04179142 - temperature 5.109448
# Epoch 37/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9969 - val_loss: 2.2169
# mean max of probabilities: 0.042998943 - temperature 5.015027
# Epoch 38/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9966 - val_loss: 2.4481
# mean max of probabilities: 0.0435341 - temperature 4.9223495
# Epoch 39/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9959 - val_loss: 2.7771
# mean max of probabilities: 0.04383041 - temperature 4.831385
# Epoch 40/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9952 - val_loss: 2.4569
# mean max of probabilities: 0.044364356 - temperature 4.7421026
# Epoch 41/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9949 - val_loss: 4.1523
# mean max of probabilities: 0.04505577 - temperature 4.654469
# Epoch 42/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9945 - val_loss: 4.6265
# mean max of probabilities: 0.045663256 - temperature 4.5684547
# Epoch 43/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9944 - val_loss: 3.6422
# mean max of probabilities: 0.046062596 - temperature 4.4840326
# Epoch 44/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9940 - val_loss: 2.8406
# mean max of probabilities: 0.046476454 - temperature 4.4011693
# Epoch 45/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9939 - val_loss: 2.8736
# mean max of probabilities: 0.047023438 - temperature 4.319837
# Epoch 46/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9938 - val_loss: 2.9098
# mean max of probabilities: 0.04802898 - temperature 4.2400074
# Epoch 47/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9937 - val_loss: 2.9609
# mean max of probabilities: 0.048756268 - temperature 4.1616535
# Epoch 48/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9935 - val_loss: 2.9401
# mean max of probabilities: 0.04873404 - temperature 4.084747
# Epoch 49/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9934 - val_loss: 2.7768
# mean max of probabilities: 0.049360737 - temperature 4.009262
# Epoch 50/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9933 - val_loss: 2.8351
# mean max of probabilities: 0.04971783 - temperature 3.9351718
# Epoch 51/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9932 - val_loss: 2.8636
# mean max of probabilities: 0.05030507 - temperature 3.8624508
# Epoch 52/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9933 - val_loss: 2.7586
# mean max of probabilities: 0.051062945 - temperature 3.7910738
# Epoch 53/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9932 - val_loss: 2.7080
# mean max of probabilities: 0.0513612 - temperature 3.7210162
# Epoch 54/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9932 - val_loss: 2.6637
# mean max of probabilities: 0.0521983 - temperature 3.6522527
# Epoch 55/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9931 - val_loss: 2.6755
# mean max of probabilities: 0.05324897 - temperature 3.58476
# Epoch 56/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9931 - val_loss: 2.6076
# mean max of probabilities: 0.054315675 - temperature 3.5185146
# Epoch 57/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9930 - val_loss: 2.7427
# mean max of probabilities: 0.05530343 - temperature 3.453493
# Epoch 58/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9930 - val_loss: 2.5352
# mean max of probabilities: 0.05680409 - temperature 3.3896737
# Epoch 59/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9929 - val_loss: 2.3557
# mean max of probabilities: 0.058422357 - temperature 3.3270326
# Epoch 60/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9928 - val_loss: 2.4711
# mean max of probabilities: 0.060087353 - temperature 3.2655501
# Epoch 61/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9928 - val_loss: 2.4499
# mean max of probabilities: 0.061955813 - temperature 3.2052035
# Epoch 62/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9925 - val_loss: 2.3789
# mean max of probabilities: 0.06526924 - temperature 3.1459723
# Epoch 63/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9924 - val_loss: 2.3247
# mean max of probabilities: 0.0719359 - temperature 3.0878353
# Epoch 64/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9919 - val_loss: 2.2506
# mean max of probabilities: 0.08165326 - temperature 3.030773
# Epoch 65/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9913 - val_loss: 2.2755
# mean max of probabilities: 0.09062457 - temperature 2.9747655
# Epoch 66/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9907 - val_loss: 2.2629
# mean max of probabilities: 0.09783235 - temperature 2.9197924
# Epoch 67/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9903 - val_loss: 2.0159
# mean max of probabilities: 0.104400165 - temperature 2.8658352
# Epoch 68/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9900 - val_loss: 1.9535
# mean max of probabilities: 0.10968716 - temperature 2.8128753
# Epoch 69/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9894 - val_loss: 1.8452
# mean max of probabilities: 0.11400068 - temperature 2.760894
# Epoch 70/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9895 - val_loss: 1.8243
# mean max of probabilities: 0.11865241 - temperature 2.7098737
# Epoch 71/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9889 - val_loss: 1.9642
# mean max of probabilities: 0.12108476 - temperature 2.6597965
# Epoch 72/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9896 - val_loss: 1.9030
# mean max of probabilities: 0.1246293 - temperature 2.610644
# Epoch 73/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9889 - val_loss: 1.6501
# mean max of probabilities: 0.12674011 - temperature 2.5624006
# Epoch 74/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9887 - val_loss: 1.6189
# mean max of probabilities: 0.12903593 - temperature 2.515048
# Epoch 75/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9893 - val_loss: 1.5720
# mean max of probabilities: 0.13152884 - temperature 2.4685702
# Epoch 76/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9887 - val_loss: 1.5771
# mean max of probabilities: 0.13369188 - temperature 2.4229515
# Epoch 77/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9888 - val_loss: 1.5030
# mean max of probabilities: 0.13579823 - temperature 2.378176
# Epoch 78/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9885 - val_loss: 1.4386
# mean max of probabilities: 0.13714798 - temperature 2.334228
# Epoch 79/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9886 - val_loss: 1.4294
# mean max of probabilities: 0.13886209 - temperature 2.291092
# Epoch 80/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9888 - val_loss: 1.1906
# mean max of probabilities: 0.14050254 - temperature 2.2487538
# Epoch 81/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9886 - val_loss: 1.2009
# mean max of probabilities: 0.14097604 - temperature 2.207198
# Epoch 82/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9889 - val_loss: 1.1704
# mean max of probabilities: 0.14259654 - temperature 2.1664093
# Epoch 83/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9885 - val_loss: 1.1580
# mean max of probabilities: 0.14300057 - temperature 2.1263747
# Epoch 84/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9889 - val_loss: 1.1087
# mean max of probabilities: 0.14416096 - temperature 2.0870795
# Epoch 85/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9891 - val_loss: 1.0883
# mean max of probabilities: 0.14525864 - temperature 2.048511
# Epoch 86/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9889 - val_loss: 1.0731
# mean max of probabilities: 0.14598736 - temperature 2.010655
# Epoch 87/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9891 - val_loss: 1.0637
# mean max of probabilities: 0.1472063 - temperature 1.9734986
# Epoch 88/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9889 - val_loss: 1.0489
# mean max of probabilities: 0.14895907 - temperature 1.9370288
# Epoch 89/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9887 - val_loss: 1.0383
# mean max of probabilities: 0.15068452 - temperature 1.9012331
# Epoch 90/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9887 - val_loss: 1.0419
# mean max of probabilities: 0.15236527 - temperature 1.8660985
# Epoch 91/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9886 - val_loss: 1.0383
# mean max of probabilities: 0.15294333 - temperature 1.8316135
# Epoch 92/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9890 - val_loss: 1.0311
# mean max of probabilities: 0.15533587 - temperature 1.7977657
# Epoch 93/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9884 - val_loss: 1.0300
# mean max of probabilities: 0.1569121 - temperature 1.7645434
# Epoch 94/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9885 - val_loss: 1.0262
# mean max of probabilities: 0.15869065 - temperature 1.731935
# Epoch 95/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9887 - val_loss: 1.0113
# mean max of probabilities: 0.1597123 - temperature 1.6999295
# Epoch 96/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9886 - val_loss: 1.0178
# mean max of probabilities: 0.1606295 - temperature 1.6685151
# Epoch 97/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9888 - val_loss: 1.0140
# mean max of probabilities: 0.16175662 - temperature 1.6376812
# Epoch 98/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9889 - val_loss: 1.0132
# mean max of probabilities: 0.16401371 - temperature 1.6074175
# Epoch 99/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9885 - val_loss: 1.0095
# mean max of probabilities: 0.16606465 - temperature 1.5777129
# Epoch 100/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9887 - val_loss: 1.0078
# mean max of probabilities: 0.16800115 - temperature 1.5485573
# Epoch 101/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9892 - val_loss: 1.0073
# mean max of probabilities: 0.1706439 - temperature 1.5199404
# Epoch 102/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9886 - val_loss: 1.0045
# mean max of probabilities: 0.17355475 - temperature 1.4918525
# Epoch 103/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9886 - val_loss: 1.0061
# mean max of probabilities: 0.17590725 - temperature 1.4642832
# Epoch 104/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9883 - val_loss: 1.0034
# mean max of probabilities: 0.17723298 - temperature 1.4372237
# Epoch 105/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9882 - val_loss: 1.0011
# mean max of probabilities: 0.17920235 - temperature 1.4106642
# Epoch 106/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9884 - val_loss: 0.9999
# mean max of probabilities: 0.18196987 - temperature 1.3845954
# Epoch 107/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9884 - val_loss: 0.9995
# mean max of probabilities: 0.18415736 - temperature 1.3590084
# Epoch 108/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9886 - val_loss: 0.9994
# mean max of probabilities: 0.18606055 - temperature 1.3338945
# Epoch 109/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9877 - val_loss: 0.9978
# mean max of probabilities: 0.1888023 - temperature 1.3092445
# Epoch 110/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9884 - val_loss: 0.9982
# mean max of probabilities: 0.19115998 - temperature 1.2850498
# Epoch 111/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9879 - val_loss: 0.9966
# mean max of probabilities: 0.19410485 - temperature 1.2613022
# Epoch 112/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9882 - val_loss: 0.9964
# mean max of probabilities: 0.19730242 - temperature 1.2379937
# Epoch 113/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9878 - val_loss: 0.9959
# mean max of probabilities: 0.20086586 - temperature 1.2151159
# Epoch 114/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9873 - val_loss: 0.9954
# mean max of probabilities: 0.20512429 - temperature 1.1926609
# Epoch 115/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9871 - val_loss: 0.9958
# mean max of probabilities: 0.20969865 - temperature 1.1706207
# Epoch 116/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9871 - val_loss: 0.9949
# mean max of probabilities: 0.21379882 - temperature 1.1489881
# Epoch 117/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9871 - val_loss: 0.9943
# mean max of probabilities: 0.21747279 - temperature 1.1277554
# Epoch 118/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9867 - val_loss: 0.9949
# mean max of probabilities: 0.22074455 - temperature 1.1069155
# Epoch 119/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9871 - val_loss: 0.9939
# mean max of probabilities: 0.2242918 - temperature 1.0864598
# Epoch 120/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9863 - val_loss: 0.9943
# mean max of probabilities: 0.22831543 - temperature 1.0663822
# Epoch 121/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9868 - val_loss: 0.9945
# mean max of probabilities: 0.23298705 - temperature 1.0466757
# Epoch 122/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9861 - val_loss: 0.9938
# mean max of probabilities: 0.23674956 - temperature 1.0273333
# Epoch 123/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9859 - val_loss: 0.9937
# mean max of probabilities: 0.24084553 - temperature 1.0083485
# Epoch 124/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9861 - val_loss: 0.9937
# mean max of probabilities: 0.24400225 - temperature 0.98971456
# Epoch 125/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9860 - val_loss: 0.9939
# mean max of probabilities: 0.24809204 - temperature 0.971425
# Epoch 126/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9852 - val_loss: 0.9935
# mean max of probabilities: 0.25136793 - temperature 0.95347327
# Epoch 127/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9854 - val_loss: 0.9935
# mean max of probabilities: 0.2557877 - temperature 0.93585336
# Epoch 128/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9854 - val_loss: 0.9934
# mean max of probabilities: 0.2601617 - temperature 0.9185591
# Epoch 129/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9849 - val_loss: 0.9934
# mean max of probabilities: 0.26500657 - temperature 0.9015844
# Epoch 130/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9849 - val_loss: 0.9935
# mean max of probabilities: 0.26946163 - temperature 0.8849234
# Epoch 131/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9845 - val_loss: 0.9933
# mean max of probabilities: 0.27411664 - temperature 0.86857027
# Epoch 132/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9837 - val_loss: 0.9940
# mean max of probabilities: 0.27761787 - temperature 0.85251933
# Epoch 133/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9848 - val_loss: 0.9934
# mean max of probabilities: 0.2798506 - temperature 0.836765
# Epoch 134/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9840 - val_loss: 0.9936
# mean max of probabilities: 0.28389755 - temperature 0.8213018
# Epoch 135/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9843 - val_loss: 0.9932
# mean max of probabilities: 0.28810835 - temperature 0.80612445
# Epoch 136/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9836 - val_loss: 0.9932
# mean max of probabilities: 0.29164335 - temperature 0.7912275
# Epoch 137/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9835 - val_loss: 0.9934
# mean max of probabilities: 0.29564413 - temperature 0.7766059
# Epoch 138/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9834 - val_loss: 0.9934
# mean max of probabilities: 0.2986647 - temperature 0.7622544
# Epoch 139/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9834 - val_loss: 0.9932
# mean max of probabilities: 0.30170172 - temperature 0.7481678
# Epoch 140/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9831 - val_loss: 0.9933
# mean max of probabilities: 0.30448776 - temperature 0.7343417
# Epoch 141/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9830 - val_loss: 0.9931
# mean max of probabilities: 0.3081006 - temperature 0.72077125
# Epoch 142/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9826 - val_loss: 0.9932
# mean max of probabilities: 0.31163347 - temperature 0.7074516
# Epoch 143/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9823 - val_loss: 0.9932
# mean max of probabilities: 0.31558716 - temperature 0.69437814
# Epoch 144/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9836 - val_loss: 0.9932
# mean max of probabilities: 0.32060745 - temperature 0.6815462
# Epoch 145/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9825 - val_loss: 0.9934
# mean max of probabilities: 0.32228214 - temperature 0.66895145
# Epoch 146/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9824 - val_loss: 0.9933
# mean max of probabilities: 0.32482392 - temperature 0.6565894
# Epoch 147/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9826 - val_loss: 0.9933
# mean max of probabilities: 0.32945794 - temperature 0.64445585
# Epoch 148/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9822 - val_loss: 0.9932
# mean max of probabilities: 0.33398378 - temperature 0.63254637
# Epoch 149/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9819 - val_loss: 0.9934
# mean max of probabilities: 0.3395614 - temperature 0.6208571
# Epoch 150/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9823 - val_loss: 0.9932
# mean max of probabilities: 0.34473094 - temperature 0.6093838
# Epoch 151/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9816 - val_loss: 0.9932
# mean max of probabilities: 0.348791 - temperature 0.5981226
# Epoch 152/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9819 - val_loss: 0.9934
# mean max of probabilities: 0.35512024 - temperature 0.58706945
# Epoch 153/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9820 - val_loss: 0.9935
# mean max of probabilities: 0.36189553 - temperature 0.57622045
# Epoch 154/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9811 - val_loss: 0.9934
# mean max of probabilities: 0.36745664 - temperature 0.56557226
# Epoch 155/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9819 - val_loss: 0.9935
# mean max of probabilities: 0.37324005 - temperature 0.5551209
# Epoch 156/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9814 - val_loss: 0.9934
# mean max of probabilities: 0.3811307 - temperature 0.5448624
# Epoch 157/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9812 - val_loss: 0.9933
# mean max of probabilities: 0.3881461 - temperature 0.5347935
# Epoch 158/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9807 - val_loss: 0.9934
# mean max of probabilities: 0.39544845 - temperature 0.5249107
# Epoch 159/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9806 - val_loss: 0.9933
# mean max of probabilities: 0.40360606 - temperature 0.51521045
# Epoch 160/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9806 - val_loss: 0.9933
# mean max of probabilities: 0.4104748 - temperature 0.50568956
# Epoch 161/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9814 - val_loss: 0.9929
# mean max of probabilities: 0.42154452 - temperature 0.4963446
# Epoch 162/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9814 - val_loss: 0.9929
# mean max of probabilities: 0.42916647 - temperature 0.4871723
# Epoch 163/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9806 - val_loss: 0.9928
# mean max of probabilities: 0.43885815 - temperature 0.47816944
# Epoch 164/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9804 - val_loss: 0.9928
# mean max of probabilities: 0.44655526 - temperature 0.469333
# Epoch 165/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9802 - val_loss: 0.9929
# mean max of probabilities: 0.45365644 - temperature 0.46065983
# Epoch 166/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9798 - val_loss: 0.9930
# mean max of probabilities: 0.46114433 - temperature 0.45214692
# Epoch 167/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9808 - val_loss: 0.9928
# mean max of probabilities: 0.4680468 - temperature 0.44379142
# Epoch 168/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9801 - val_loss: 0.9928
# mean max of probabilities: 0.47397906 - temperature 0.4355903
# Epoch 169/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9798 - val_loss: 0.9926
# mean max of probabilities: 0.47968322 - temperature 0.4275407
# Epoch 170/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9796 - val_loss: 0.9928
# mean max of probabilities: 0.4852156 - temperature 0.41963986
# Epoch 171/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9797 - val_loss: 0.9929
# mean max of probabilities: 0.49157077 - temperature 0.41188508
# Epoch 172/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9790 - val_loss: 0.9929
# mean max of probabilities: 0.49638206 - temperature 0.40427354
# Epoch 173/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9806 - val_loss: 0.9928
# mean max of probabilities: 0.4995069 - temperature 0.3968027
# Epoch 174/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9795 - val_loss: 0.9928
# mean max of probabilities: 0.5026183 - temperature 0.38946986
# Epoch 175/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9790 - val_loss: 0.9930
# mean max of probabilities: 0.50637025 - temperature 0.38227254
# Epoch 176/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9790 - val_loss: 0.9929
# mean max of probabilities: 0.51152396 - temperature 0.37520817
# Epoch 177/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9794 - val_loss: 0.9932
# mean max of probabilities: 0.51520336 - temperature 0.36827427
# Epoch 178/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9794 - val_loss: 0.9931
# mean max of probabilities: 0.5185298 - temperature 0.36146867
# Epoch 179/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9795 - val_loss: 0.9931
# mean max of probabilities: 0.5217927 - temperature 0.35478884
# Epoch 180/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9789 - val_loss: 0.9930
# mean max of probabilities: 0.5263387 - temperature 0.34823245
# Epoch 181/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9791 - val_loss: 0.9932
# mean max of probabilities: 0.52831906 - temperature 0.34179723
# Epoch 182/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9788 - val_loss: 0.9932
# mean max of probabilities: 0.53067374 - temperature 0.3354809
# Epoch 183/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9789 - val_loss: 0.9931
# mean max of probabilities: 0.53357387 - temperature 0.3292813
# Epoch 184/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9790 - val_loss: 0.9930
# mean max of probabilities: 0.5364306 - temperature 0.32319623
# Epoch 185/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9786 - val_loss: 0.9933
# mean max of probabilities: 0.53969157 - temperature 0.31722364
# Epoch 186/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9791 - val_loss: 0.9934
# mean max of probabilities: 0.543182 - temperature 0.31136146
# Epoch 187/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9784 - val_loss: 0.9934
# mean max of probabilities: 0.5443256 - temperature 0.30560762
# Epoch 188/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9786 - val_loss: 0.9935
# mean max of probabilities: 0.54658854 - temperature 0.29996008
# Epoch 189/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9778 - val_loss: 0.9934
# mean max of probabilities: 0.5477984 - temperature 0.29441693
# Epoch 190/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9780 - val_loss: 0.9933
# mean max of probabilities: 0.5493705 - temperature 0.2889762
# Epoch 191/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9784 - val_loss: 0.9934
# mean max of probabilities: 0.55225086 - temperature 0.283636
# Epoch 192/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9782 - val_loss: 0.9934
# mean max of probabilities: 0.5539737 - temperature 0.27839464
# Epoch 193/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9787 - val_loss: 0.9934
# mean max of probabilities: 0.55493903 - temperature 0.27324998
# Epoch 194/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9776 - val_loss: 0.9935
# mean max of probabilities: 0.5561433 - temperature 0.2682004
# Epoch 195/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9780 - val_loss: 0.9935
# mean max of probabilities: 0.5573126 - temperature 0.26324412
# Epoch 196/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9781 - val_loss: 0.9935
# mean max of probabilities: 0.55728734 - temperature 0.25837946
# Epoch 197/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9782 - val_loss: 0.9937
# mean max of probabilities: 0.55701965 - temperature 0.2536047
# Epoch 198/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9786 - val_loss: 0.9935
# mean max of probabilities: 0.5587255 - temperature 0.24891822
# Epoch 199/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9781 - val_loss: 0.9934
# mean max of probabilities: 0.5597243 - temperature 0.24431825
# Epoch 200/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9783 - val_loss: 0.9935
# mean max of probabilities: 0.5609848 - temperature 0.23980331
# Epoch 201/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9773 - val_loss: 0.9936
# mean max of probabilities: 0.56143403 - temperature 0.23537181
# Epoch 202/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9776 - val_loss: 0.9936
# mean max of probabilities: 0.5628618 - temperature 0.23102221
# Epoch 203/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9784 - val_loss: 0.9938
# mean max of probabilities: 0.5650386 - temperature 0.22675298
# Epoch 204/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9779 - val_loss: 0.9936
# mean max of probabilities: 0.565565 - temperature 0.22256266
# Epoch 205/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9783 - val_loss: 0.9935
# mean max of probabilities: 0.567096 - temperature 0.21844976
# Epoch 206/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9777 - val_loss: 0.9936
# mean max of probabilities: 0.5701987 - temperature 0.21441287
# Epoch 207/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9783 - val_loss: 0.9939
# mean max of probabilities: 0.57118446 - temperature 0.21045059
# Epoch 208/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9784 - val_loss: 0.9935
# mean max of probabilities: 0.57396245 - temperature 0.20656154
# Epoch 209/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9777 - val_loss: 0.9939
# mean max of probabilities: 0.57600176 - temperature 0.20274432
# Epoch 210/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9777 - val_loss: 0.9934
# mean max of probabilities: 0.57712364 - temperature 0.19899763
# Epoch 211/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9774 - val_loss: 0.9937
# mean max of probabilities: 0.5782262 - temperature 0.1953202
# Epoch 212/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9773 - val_loss: 0.9937
# mean max of probabilities: 0.5791354 - temperature 0.19171074
# Epoch 213/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9773 - val_loss: 0.9939
# mean max of probabilities: 0.5794544 - temperature 0.18816796
# Epoch 214/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9775 - val_loss: 0.9939
# mean max of probabilities: 0.5830027 - temperature 0.18469061
# Epoch 215/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9776 - val_loss: 0.9936
# mean max of probabilities: 0.5847681 - temperature 0.18127757
# Epoch 216/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9778 - val_loss: 0.9939
# mean max of probabilities: 0.5877925 - temperature 0.1779276
# Epoch 217/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9774 - val_loss: 0.9939
# mean max of probabilities: 0.58864146 - temperature 0.17463955
# Epoch 218/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9773 - val_loss: 0.9939
# mean max of probabilities: 0.58916295 - temperature 0.17141226
# Epoch 219/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9770 - val_loss: 0.9940
# mean max of probabilities: 0.5911503 - temperature 0.16824457
# Epoch 220/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9770 - val_loss: 0.9939
# mean max of probabilities: 0.5929014 - temperature 0.16513543
# Epoch 221/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9775 - val_loss: 0.9940
# mean max of probabilities: 0.5946227 - temperature 0.16208376
# Epoch 222/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9769 - val_loss: 0.9941
# mean max of probabilities: 0.594365 - temperature 0.15908849
# Epoch 223/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9776 - val_loss: 0.9939
# mean max of probabilities: 0.5950302 - temperature 0.15614857
# Epoch 224/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9763 - val_loss: 0.9940
# mean max of probabilities: 0.59531987 - temperature 0.15326299
# Epoch 225/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9777 - val_loss: 0.9939
# mean max of probabilities: 0.5948195 - temperature 0.15043072
# Epoch 226/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9773 - val_loss: 0.9942
# mean max of probabilities: 0.5943495 - temperature 0.1476508
# Epoch 227/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9769 - val_loss: 0.9941
# mean max of probabilities: 0.59567696 - temperature 0.14492226
# Epoch 228/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9769 - val_loss: 0.9944
# mean max of probabilities: 0.59593827 - temperature 0.1422441
# Epoch 229/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9772 - val_loss: 0.9942
# mean max of probabilities: 0.5954036 - temperature 0.13961557
# Epoch 230/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9770 - val_loss: 0.9941
# mean max of probabilities: 0.5960895 - temperature 0.13703555
# Epoch 231/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9768 - val_loss: 0.9940
# mean max of probabilities: 0.5964012 - temperature 0.13450316
# Epoch 232/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9772 - val_loss: 0.9941
# mean max of probabilities: 0.59715587 - temperature 0.13201758
# Epoch 233/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9770 - val_loss: 0.9941
# mean max of probabilities: 0.59811133 - temperature 0.12957793
# Epoch 234/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9769 - val_loss: 0.9940
# mean max of probabilities: 0.5993979 - temperature 0.12718338
# Epoch 235/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9771 - val_loss: 0.9943
# mean max of probabilities: 0.59915924 - temperature 0.12483306
# Epoch 236/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9764 - val_loss: 0.9943
# mean max of probabilities: 0.5998906 - temperature 0.122526176
# Epoch 237/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9769 - val_loss: 0.9944
# mean max of probabilities: 0.600917 - temperature 0.12026193
# Epoch 238/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9771 - val_loss: 0.9944
# mean max of probabilities: 0.6024853 - temperature 0.118039526
# Epoch 239/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9766 - val_loss: 0.9942
# mean max of probabilities: 0.6040343 - temperature 0.1158582
# Epoch 240/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9773 - val_loss: 0.9944
# mean max of probabilities: 0.60426056 - temperature 0.113717176
# Epoch 241/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9761 - val_loss: 0.9941
# mean max of probabilities: 0.60475767 - temperature 0.11161572
# Epoch 242/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9769 - val_loss: 0.9942
# mean max of probabilities: 0.60552645 - temperature 0.10955309
# Epoch 243/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9761 - val_loss: 0.9944
# mean max of probabilities: 0.6054777 - temperature 0.107528575
# Epoch 244/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9766 - val_loss: 0.9944
# mean max of probabilities: 0.60642314 - temperature 0.10554148
# Epoch 245/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9763 - val_loss: 0.9944
# mean max of probabilities: 0.6062866 - temperature 0.103591114
# Epoch 246/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9758 - val_loss: 0.9945
# mean max of probabilities: 0.6073868 - temperature 0.101676784
# Epoch 247/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9763 - val_loss: 0.9948
# mean max of probabilities: 0.6083424 - temperature 0.1
# Epoch 248/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9766 - val_loss: 0.9943
# mean max of probabilities: 0.6084001 - temperature 0.1
# Epoch 249/250
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9765 - val_loss: 0.9943
# mean max of probabilities: 0.60901475 - temperature 0.1
# Epoch 250/250
# 80/80 [==============================] - 0s 4ms/step - loss: 0.9766 - val_loss: 0.9944

# %% [markdown]
# # Test Models

# %%
y_pred = supervised_selector.model(x_test)
y_pred = tf.math.argmax(y_pred, axis=-1)
acc = 100*np.mean((y_pred==y_test_).numpy())

x_pred = unsupervised_selector.model(x_test)
reconstruction_error = np.mean((x_pred.numpy() - x_test)**2)

# %%
supervised_selected = supervised_selector.get_indices()
unsupervised_selected = unsupervised_selector.get_indices()

selected = supervised_selected
tpr, fdr = tpr_fdr(gauss_groups[experiment_choice], [selected])

print('Supervised:')
print(get_jaccard_score(gauss_groups[experiment_choice], [selected]))
print(acc)
print(selected)
print(tpr)
print(fdr)


selected = unsupervised_selected
tpr, fdr = tpr_fdr(gauss_groups[experiment_choice], [selected])

print('\nUnsupervised:')
print(get_jaccard_score(gauss_groups[experiment_choice], [selected]))
print(reconstruction_error)
print(selected)
print(tpr)
print(fdr)
# Out:
# Supervised:
# (0.35, 2, 1)
# 91.0
# [5 9 6 0]
# 75.0
# 25.0
#
# Unsupervised:
# (0.0, 2, 1)
# 0.9942412
# [  7 222   1   4]
# 0.0
# 100.0
